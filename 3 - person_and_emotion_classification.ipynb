# %% [markdown]
# # Import packages

# %%
from deepface import DeepFace
from common_functionality import *
import numpy as np
import contextlib
import os
import sys
import pandas as pd
from scipy.stats import entropy
import cv2
import json
# Out:
# WARNING:tensorflow:From c:\Users\mvass\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
@contextlib.contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr

# %% [markdown]
# # Saving and Prediction functionality

# %% [markdown]
# ## Emotion Classification

# %%
# Function which writes dominant emotion for a given image
def write_emotion_detected(data_path, base_img_name, roi_name, emotion_det):
    with open(data_path, 'r+') as f:
        processed_data = json.load(f)
        if 'frames_list' in processed_data.keys():
            for index_f, frame in enumerate(processed_data['frames_list']):
                if frame['frame_num'] == base_img_name:
                    frame_dict = frame.copy()
                    frame_pos = index_f
                    break
                
            for index_r, roi in enumerate(processed_data['frames_list'][frame_pos]['rois_list']):
                if roi['roi_num'] == roi_name:
                    roi_dict = roi.copy()
                    roi_pos = index_r
                    break
            
            #print("Before:", roi_dict)
            roi_dict['emotion_classified'] = emotion_det
            #print("After:",roi_dict)

            processed_data['frames_list'][frame_pos]['rois_list'][roi_pos] = roi_dict
            f.seek(0)
            json.dump(processed_data, f, indent=4)
            f.truncate()  # This prevents leftover characters from previous write

# Function which writes emotion probabilities for a given image
def write_emotion_probs(data_path, base_img_name, roi_name, emotion_probs):
    with open(data_path, 'r+') as f:
        processed_data = json.load(f)
        if 'frames_list' in processed_data.keys():
            for index_f, frame in enumerate(processed_data['frames_list']):
                if frame['frame_num'] == base_img_name:
                    frame_dict = frame.copy()
                    frame_pos = index_f
                    break
                
            for index_r, roi in enumerate(processed_data['frames_list'][frame_pos]['rois_list']):
                if roi['roi_num'] == roi_name:
                    roi_dict = roi.copy()
                    roi_pos = index_r
                    break
            
            #print("Before:", roi_dict)
            roi_dict['emotion_probabilities'] = emotion_probs
            #print("After:",roi_dict)

            processed_data['frames_list'][frame_pos]['rois_list'][roi_pos] = roi_dict
            f.seek(0)
            json.dump(processed_data, f, indent=4)
            f.truncate()  # This prevents leftover characters from previous write

# Function which writes entropy from emotion probabilities for a given image
def write_emotion_entropy(data_path, base_img_name, roi_name, entropy_val):
    with open(data_path, 'r+') as f:
        processed_data = json.load(f)
        if 'frames_list' in processed_data.keys():
            for index_f, frame in enumerate(processed_data['frames_list']):
                if frame['frame_num'] == base_img_name:
                    frame_dict = frame.copy()
                    frame_pos = index_f
                    break
                
            for index_r, roi in enumerate(processed_data['frames_list'][frame_pos]['rois_list']):
                if roi['roi_num'] == roi_name:
                    roi_dict = roi.copy()
                    roi_pos = index_r
                    break
            
            #print("Before:", roi_dict)
            roi_dict['entropy'] = entropy_val
            #print("After:",roi_dict)

            processed_data['frames_list'][frame_pos]['rois_list'][roi_pos] = roi_dict
            f.seek(0)
            json.dump(processed_data, f, indent=4)
            f.truncate()  # This prevents leftover characters from previous write

# Function which writes predicted arousal and valence values for a given image
def write_av_values(data_path, base_img_name, roi_name, arousal_value, valence_value):
    with open(data_path, 'r+') as f:
        processed_data = json.load(f)
        if 'frames_list' in processed_data.keys():
            for index_f, frame in enumerate(processed_data['frames_list']):
                if frame['frame_num'] == base_img_name:
                    frame_dict = frame.copy()
                    frame_pos = index_f
                    break
                
            for index_r, roi in enumerate(processed_data['frames_list'][frame_pos]['rois_list']):
                if roi['roi_num'] == roi_name:
                    roi_dict = roi.copy()
                    roi_pos = index_r
                    break
            
            #print("Before:", roi_dict)
            roi_dict['predicted_arousal'] = arousal_value
            roi_dict['predicted_valence'] = valence_value
            #print("After:",roi_dict)

            processed_data['frames_list'][frame_pos]['rois_list'][roi_pos] = roi_dict
            f.seek(0)
            json.dump(processed_data, f, indent=4)
            f.truncate()  # This prevents leftover characters from previous write

# %%
# Function which predicts the dominant emotion displayed in a given image
def predict_emotion(snapshot_path, snapshot_img_name, vid_emotion_categories, backend_detector):
    with suppress_stdout():
        result = DeepFace.analyze(snapshot_path, actions=['emotion'], detector_backend=backend_detector, enforce_detection=False)
    #result = DeepFace.analyze(snapshot_path, actions=['emotion'], detector_backend="yolov8", enforce_detection=False)

    # Initialise emotion category dictionary if empty
    if not bool(vid_emotion_categories):
        for category in result[0]['emotion'].keys():
            vid_emotion_categories[category] = []
    #         os.mkdir(os.path.join(imgs_path, category))
    emotion_displayed = result[0]['dominant_emotion']
    emotion_probs = result[0]['emotion']
    vid_emotion_categories[emotion_displayed].append(snapshot_img_name)
    emotion_probs_df = pd.DataFrame([emotion_probs])
    entropy_value = emotion_probs_df.apply(entropy, axis=1).iloc[0]

    return emotion_displayed, emotion_probs, entropy_value

# Function which computes arousal and valence from predicted emotion probabilities from a given image
def calculate_av(emotion_probs):
    emotion_av_values = {
        'happy': {'valence': 0.8, 'arousal': 0.7},
        'sad': {'valence': -0.6, 'arousal': -0.4},
        'neutral': {'valence': 0.0, 'arousal': 0.0},
        'angry': {'valence': -0.7, 'arousal': 0.6},
        'fear': {'valence': -0.6, 'arousal': 0.7},
        'surprise': {'valence': 0.4, 'arousal': 0.8},
        'disgust': {'valence': -0.7, 'arousal': 0.3}
    }

    arousal_predicted = 0
    valence_predicted = 0

    for emotion, prob in emotion_probs.items():
        if emotion in emotion_av_values:
            arousal_predicted += prob/100 * emotion_av_values[emotion]['arousal']
            valence_predicted += prob/100 * emotion_av_values[emotion]['valence']

    return arousal_predicted, valence_predicted

# %% [markdown]
# ## Person Classification

# %%
# Function which writes detected person label for a given image
def write_person_detected(data_path, base_img_name, roi_name, person_det):
    with open(data_path, 'r+') as f:
        processed_data = json.load(f)
        if 'frames_list' in processed_data.keys():
            for index_f, frame in enumerate(processed_data['frames_list']):
                if frame['frame_num'] == base_img_name:
                    frame_dict = frame.copy()
                    frame_pos = index_f
                    break
                
            for index_r, roi in enumerate(processed_data['frames_list'][frame_pos]['rois_list']):
                if roi['roi_num'] == roi_name:
                    roi_dict = roi.copy()
                    roi_pos = index_r
                    break
            
            #print("Before:",roi_dict)
            roi_dict['person_classified'] = person_det
            #print("After:", roi_dict)

            processed_data['frames_list'][frame_pos]['rois_list'][roi_pos] = roi_dict
            f.seek(0)
            json.dump(processed_data, f, indent=4)
            f.truncate()  # This prevents leftover characters from previous write

# Function which writes person classification distance for a given image
def write_person_score(data_path, base_img_name, roi_name, person_score):
    with open(data_path, 'r+') as f:
        processed_data = json.load(f)
        if 'frames_list' in processed_data.keys():
            for index_f, frame in enumerate(processed_data['frames_list']):
                if frame['frame_num'] == base_img_name:
                    frame_dict = frame.copy()
                    frame_pos = index_f
                    break
                
            for index_r, roi in enumerate(processed_data['frames_list'][frame_pos]['rois_list']):
                if roi['roi_num'] == roi_name:
                    roi_dict = roi.copy()
                    roi_pos = index_r
                    break
            
            #print("Before:",roi_dict)
            roi_dict['person_score'] = person_score
            #print("After:", roi_dict)

            processed_data['frames_list'][frame_pos]['rois_list'][roi_pos] = roi_dict
            f.seek(0)
            json.dump(processed_data, f, indent=4)
            f.truncate()  # This prevents leftover characters from previous write

# %%
# Function which compares interviewer and interviewee images and assigns person label
def compare_person_new(snapshot_to_compare, interviewer_refs, interviewee_refs, facial_rec_model, custom_threshold='auto'):
    best_match = "Unknown"
    best_distance = float('inf')

    # Compare with interviewer
    cat1, dist1 = get_best_match(snapshot_to_compare, interviewer_refs, "Interviewer", facial_rec_model, threshold=custom_threshold)
    
    # Compare with interviewee
    cat2, dist2 = get_best_match(snapshot_to_compare, interviewee_refs, "Interviewee", facial_rec_model, threshold=custom_threshold)

    # Decide best match
    if dist1 is not None and dist2 is not None:
        if dist1 < dist2:
            best_match, best_distance = cat1, dist1
        else:
            best_match, best_distance = cat2, dist2
    elif dist1 is not None:
        best_match, best_distance = cat1, dist1
    elif dist2 is not None:
        best_match, best_distance = cat2, dist2
    else:
        best_match = "Unknown"

    return best_match, best_distance if best_match != "Unknown" else None


# Helper to process all views for one person
def get_best_match(snapshot, reference_imgs, category_label, model, threshold='auto'):
    min_dist = float('inf')
    matched = False

    for ref in reference_imgs:
        try:
            with suppress_stdout():
                if threshold == 'auto':
                    result = DeepFace.verify(snapshot, ref, model_name=model, detector_backend='mtcnn', distance_metric='euclidean_l2', silent=True)
                else:
                    result = DeepFace.verify(snapshot, ref, model_name=model, detector_backend='mtcnn', distance_metric='euclidean_l2', threshold=threshold, silent=True)
            #print(f"{category_label} comparison: {result}")
            if result["verified"] and result["distance"] < min_dist:
                min_dist = result["distance"]
                matched = True
        except Exception as e:
            #print(f"Error comparing with {category_label} reference: {e}")
            continue
    
    return (category_label if matched else "Unknown", min_dist if matched else None)

# %% [markdown]
# # Other functionality

# %%
# Function which returns list of all ROIs under which each person label in a given video is assigned to 
def load_person_categories(data_path):
    person_categories = dict()
    with open(data_path, 'r+') as f:
        processed_data = json.load(f)
        if 'frames_list' in processed_data.keys():
            for index_f, frame in enumerate(processed_data['frames_list']):              
                for index_r, roi in enumerate(processed_data['frames_list'][index_f]['rois_list']):
                    if 'person_classified' in roi.keys():
                        if roi['person_classified'] not in person_categories.keys():
                            person_categories[roi['person_classified']] = []
                        person_categories[roi['person_classified']].append(roi['roi_num']+".png")
            
    
    return person_categories

# Function which returns list of all ROIs under which each emotion label in a given video is assigned to 
def load_emotion_categories(data_path):
    emotion_categories = dict()
    with open(data_path, 'r+') as f:
        processed_data = json.load(f)
        if 'frames_list' in processed_data.keys():
            for index_f, frame in enumerate(processed_data['frames_list']):              
                for index_r, roi in enumerate(processed_data['frames_list'][index_f]['rois_list']):
                    if 'emotion_classified' in roi.keys():
                        if roi['emotion_classified'] not in emotion_categories.keys():
                            emotion_categories[roi['emotion_classified']] = []
                        emotion_categories[roi['emotion_classified']].append(roi['roi_num']+".png")
            
    
    return emotion_categories

# %% [markdown]
# ## Select ROIs database folder (Jon Mallia or Mark Lawrence Zammit)

# %%
#vid_frames_folders = [folder for folder in os.listdir(".") if os.path.isdir(os.path.join(".", folder)) and folder.startswith("vid_frames")]

rois_folders = [folder for folder in os.listdir(".") if os.path.isdir(os.path.join(".", folder)) and folder.startswith("face_rois_dt")]

for index, rois_dir in enumerate(rois_folders):
    print(f'{index+1}: {rois_dir}')
# Out:
# 1: face_rois_dt
# 2: face_rois_dt_ml

# %%
valid_choice = False
while not valid_choice:
    index_choice = input('Enter index of facial ROIs folder: ')

    if index_choice.isnumeric():
        if int(index_choice) > len(rois_folders) or int(index_choice) <= 0:
            valid_choice = False
            print('Invalid choice!')
        else:
            valid_choice = True
            #frames_dir = vid_frames_folders[int(index_choice)-1]
            rois_dir_chosen = rois_folders[int(index_choice)-1]
            #rois_dir_chosen = f'face_rois_dt_{"_".join(frames_dir.split("_")[2:])}' if frames_dir != "vid_frames" else "face_rois_dt"
            video_data_path = os.path.join('data', f'video_data_{"_".join(rois_dir_chosen.split("_")[-1:])}') if rois_dir_chosen != "face_rois_dt" else os.path.join('data', 'video_data')
            interviewee_data_path = 'data/interviewee_names_data_ml.json' if rois_dir_chosen != "face_rois_dt" else 'data/interviewee_names_data.json'
            interviewer_data_path = 'data/interviewer_names_data_ml.json' if rois_dir_chosen != "face_rois_dt" else 'data/interviewer_names_data.json'

            print("ROIs Folder selected:", rois_dir_chosen)
            #print(rois_dir_chosen)
            print(video_data_path)

    else:
        valid_choice = False
        print("Index entered is not numeric!")
# Out:
# ROIs Folder selected: face_rois_dt
# data\video_data

# %% [markdown]
# ## Load interviewer and interviewee names from their respective data files

# %%
if os.path.exists(interviewee_data_path):
    with open(interviewee_data_path, 'r') as f:
        interviewee_data = json.load(f)

if os.path.exists(interviewer_data_path):
    with open(interviewer_data_path, 'r') as f:
        interviewer_data = json.load(f)

# %% [markdown]
# # Asking user for directory of video to process

# %%
frames_subDirs = []

print('List of available of videos with extracted ROIs:')
for root, dirs, files in os.walk(rois_dir_chosen, topdown=True):
    for subDir in dirs:
        frames_subDirs.append(subDir)

frames_subDirs_sorted = sorted(frames_subDirs, key=lambda x: int(x.split('_')[-1]))

for index, subDir in enumerate(frames_subDirs_sorted):
    print(f'{index+1}: {os.path.join(rois_dir_chosen, subDir)}')
# Out:
# List of available of videos with extracted ROIs:
# 1: face_rois_dt\video_1
# 2: face_rois_dt\video_2
# 3: face_rois_dt\video_3
# 4: face_rois_dt\video_4
# 5: face_rois_dt\video_5
# 6: face_rois_dt\video_6
# 7: face_rois_dt\video_7
# 8: face_rois_dt\video_8
# 9: face_rois_dt\video_9
# 10: face_rois_dt\video_10
# 11: face_rois_dt\video_11
# 12: face_rois_dt\video_12
# 13: face_rois_dt\video_13
# 14: face_rois_dt\video_14
# 15: face_rois_dt\video_15
# 16: face_rois_dt\video_16
# 17: face_rois_dt\video_17
# 18: face_rois_dt\video_18
# 19: face_rois_dt\video_19
# 20: face_rois_dt\video_20
# 21: face_rois_dt\video_21
# 22: face_rois_dt\video_22

# %%
valid_choice = False
dir_chosen = ""
dir_chosen_full_path = ""
while not valid_choice:
    index_choice = input('Enter index of directory that you want to perform classification: ')

    if index_choice.isnumeric():
        if int(index_choice) > len(frames_subDirs_sorted) or int(index_choice) <= 0:
            valid_choice = False
            print('Invalid choice!')
        else:
            valid_choice = True
            dir_chosen = frames_subDirs_sorted[int(index_choice)-1]
            dir_chosen_full_path = os.path.join(rois_dir_chosen, dir_chosen)
            chosen_video_data_path = os.path.join(video_data_path, f'{dir_chosen}.json')
            print("Directory selected:", dir_chosen_full_path)
    else:
        valid_choice = False
        print("Index entered is not numeric!")
# Out:
# Directory selected: face_rois_dt\video_14

# %% [markdown]
# # Validate if video data exists

# %%
# Check if data file for selected video exists in the data folder
video_data_file_exists = check_if_data_file_exists(dir_chosen)

if not video_data_file_exists:
    raise Exception(f'Data file for {dir_chosen} does not exist in {video_data_path}!')
    exit(0)

print(chosen_video_data_path)

# Check if there is a list of extracted ROIs in the selected video data file
roi_list_exists_in_file = validate_roi_list_exists(chosen_video_data_path)

if not roi_list_exists_in_file:
    raise Exception(f'Please ensure that all facial ROIs from {dir_chosen} have been extracted before running this!')
    exit(0)

print("Chosen video data file is valid!")
# Out:
# data\video_data\video_14.json
# Chosen video data file is valid!

# %% [markdown]
# # Main execution

# %% [markdown]
# ## Initialisation of Parameters for Reviewing Results after Execution

# %%
video_emotions_categorized = dict()
video_person_categorized = dict()

# %%
print([file for file in os.listdir(dir_chosen_full_path)])  # TESTING PURPOSES
# Out:
# ['frame_0009_00.png', 'frame_0010_00.png', 'frame_0011_00.png', 'frame_0012_00.png', 'frame_0013_00.png', 'frame_0014_00.png', 'frame_0015_00.png', 'frame_0016_00.png', 'frame_0016_01.png', 'frame_0017_00.png', 'frame_0018_00.png', 'frame_0019_00.png', 'frame_0020_00.png', 'frame_0020_01.png', 'frame_0021_00.png', 'frame_0021_01.png', 'frame_0022_00.png', 'frame_0023_00.png', 'frame_0024_00.png', 'frame_0025_00.png', 'frame_0026_00.png', 'frame_0027_00.png', 'frame_0028_00.png', 'frame_0029_00.png', 'frame_0030_00.png', 'frame_0031_00.png', 'frame_0032_00.png', 'frame_0032_01.png', 'frame_0033_00.png', 'frame_0033_01.png', 'frame_0034_00.png', 'frame_0035_00.png', 'frame_0036_00.png', 'frame_0037_00.png', 'frame_0038_00.png', 'frame_0039_00.png', 'frame_0040_00.png', 'frame_0041_00.png', 'frame_0042_00.png', 'frame_0043_00.png', 'frame_0044_00.png', 'frame_0045_00.png', 'frame_0046_00.png', 'frame_0047_00.png', 'frame_0048_00.png', 'frame_0049_00.png', 'frame_0050_00.png', 'frame_0051_00.png', 'frame_0052_00.png', 'frame_0053_00.png', 'frame_0054_00.png', 'frame_0055_00.png', 'frame_0056_00.png', 'frame_0057_00.png', 'frame_0058_00.png', 'frame_0058_01.png', 'frame_0060_00.png', 'frame_0060_01.png', 'frame_0061_00.png', 'frame_0062_00.png', 'frame_0063_00.png', 'frame_0064_00.png', 'frame_0065_00.png', 'frame_0066_00.png', 'frame_0067_00.png', 'frame_0068_00.png', 'frame_0069_00.png', 'frame_0070_00.png', 'frame_0071_00.png', 'frame_0072_00.png', 'frame_0073_00.png', 'frame_0074_00.png', 'frame_0075_00.png', 'frame_0076_00.png', 'frame_0077_00.png', 'frame_0078_00.png', 'frame_0079_00.png', 'frame_0080_00.png', 'frame_0081_00.png', 'frame_0082_00.png', 'frame_0083_00.png', 'frame_0084_00.png', 'frame_0085_00.png', 'frame_0086_00.png', 'frame_0087_00.png', 'frame_0088_00.png', 'frame_0089_00.png', 'frame_0090_00.png', 'frame_0091_00.png', 'frame_0092_00.png', 'frame_0093_00.png', 'frame_0094_00.png', 'frame_0094_01.png', 'frame_0095_00.png', 'frame_0096_00.png', 'frame_0097_00.png', 'frame_0098_00.png', 'frame_0099_00.png', 'frame_0100_00.png', 'frame_0101_00.png', 'frame_0102_00.png', 'frame_0103_00.png', 'frame_0104_00.png', 'frame_0105_00.png', 'frame_0106_00.png', 'frame_0107_00.png', 'frame_0108_00.png', 'frame_0109_00.png', 'frame_0110_00.png', 'frame_0111_00.png', 'frame_0112_00.png', 'frame_0113_00.png', 'frame_0114_00.png', 'frame_0115_00.png', 'frame_0116_00.png', 'frame_0117_00.png', 'frame_0118_00.png', 'frame_0119_00.png', 'frame_0120_00.png', 'frame_0121_00.png', 'frame_0122_00.png', 'frame_0123_00.png', 'frame_0124_00.png', 'frame_0125_00.png', 'frame_0126_00.png', 'frame_0127_00.png', 'frame_0128_00.png', 'frame_0129_00.png', 'frame_0130_00.png', 'frame_0131_00.png', 'frame_0132_00.png', 'frame_0133_00.png', 'frame_0134_00.png', 'frame_0135_00.png', 'frame_0136_00.png', 'frame_0137_00.png', 'frame_0138_00.png', 'frame_0139_00.png', 'frame_0140_00.png', 'frame_0141_00.png', 'frame_0142_00.png', 'frame_0143_00.png', 'frame_0144_00.png', 'frame_0145_00.png', 'frame_0146_00.png', 'frame_0147_00.png', 'frame_0148_00.png', 'frame_0149_00.png', 'frame_0150_00.png', 'frame_0151_00.png', 'frame_0152_00.png', 'frame_0153_00.png', 'frame_0154_00.png', 'frame_0155_00.png', 'frame_0156_00.png', 'frame_0157_00.png', 'frame_0158_00.png', 'frame_0158_01.png', 'frame_0159_00.png', 'frame_0160_00.png', 'frame_0161_00.png', 'frame_0162_00.png', 'frame_0163_00.png', 'frame_0164_00.png', 'frame_0165_00.png', 'frame_0166_00.png', 'frame_0167_00.png', 'frame_0168_00.png', 'frame_0169_00.png', 'frame_0170_00.png', 'frame_0170_01.png', 'frame_0171_00.png', 'frame_0172_00.png', 'frame_0173_00.png', 'frame_0174_00.png', 'frame_0174_01.png', 'frame_0175_00.png', 'frame_0176_00.png', 'frame_0177_00.png', 'frame_0178_00.png', 'frame_0179_00.png', 'frame_0180_00.png', 'frame_0181_00.png', 'frame_0182_00.png', 'frame_0183_00.png', 'frame_0184_00.png', 'frame_0185_00.png', 'frame_0186_00.png', 'frame_0187_00.png', 'frame_0188_00.png', 'frame_01 ...

# %% [markdown]
# ## Execution of Person Classification

# %%
# Loading of interviewer and interviewee names
interviewee_name = ""

if dir_chosen in interviewee_data.keys():
    interviewee_name = interviewee_data[dir_chosen]

interviewee_name_lc = interviewee_name.lower()
interviewee_name_ns = interviewee_name_lc.replace(" ", "-")

if not os.path.exists(f'reference_imgs/interviewees/{interviewee_name_ns}.png'):
    reference_img_interviewee = f'reference_imgs/interviewees/{interviewee_name_ns}.jpg'
else:
    reference_img_interviewee = f'reference_imgs/interviewees/{interviewee_name_ns}.png'

if not os.path.exists(f'reference_imgs/interviewees/{interviewee_name_ns}-side.png'):
    reference_img_interviewee_side = f'reference_imgs/interviewees/{interviewee_name_ns}-side.jpg'
else:
    reference_img_interviewee_side = f'reference_imgs/interviewees/{interviewee_name_ns}-side.png'

if not os.path.exists(f'reference_imgs/interviewees/{interviewee_name_ns}-side-flipped.png'):
    reference_img_interviewee_side_flipped = f'reference_imgs/interviewees/{interviewee_name_ns}-side-flipped.jpg'
else:
    reference_img_interviewee_side_flipped = f'reference_imgs/interviewees/{interviewee_name_ns}-side-flipped.png'

print(reference_img_interviewee, "-", os.path.exists(reference_img_interviewee))
print(reference_img_interviewee_side, "-", os.path.exists(reference_img_interviewee_side))
print(reference_img_interviewee_side_flipped, "-", os.path.exists(reference_img_interviewee_side_flipped))

interviewer_name = ""

if dir_chosen in interviewer_data.keys():
    interviewer_name = interviewer_data[dir_chosen]

interviewer_name_lc = interviewer_name.lower()
interviewer_name_ns = interviewer_name_lc.replace(" ", "-")

reference_img_interviewer = ''
reference_img_interviewer_side = ""
reference_img_interviewer_side_flipped = ""

if not os.path.exists(f'reference_imgs/interviewer/{interviewer_name_ns}.png'):
    reference_img_interviewer = f'reference_imgs/interviewer/{interviewer_name_ns}.jpg'
else:
    reference_img_interviewer = f'reference_imgs/interviewer/{interviewer_name_ns}.png'

if not os.path.exists(f'reference_imgs/interviewer/{interviewer_name_ns}-side.png'):
    reference_img_interviewer_side = f'reference_imgs/interviewer/{interviewer_name_ns}-side.jpg'
else:
    reference_img_interviewer_side = f'reference_imgs/interviewer/{interviewer_name_ns}-side.png'

if not os.path.exists(f'reference_imgs/interviewer/{interviewer_name_ns}-side-flipped.png'):
    reference_img_interviewer_side_flipped = f'reference_imgs/interviewer/{interviewer_name_ns}-side-flipped.jpg'
else:
    reference_img_interviewer_side_flipped = f'reference_imgs/interviewer/{interviewer_name_ns}-side-flipped.png'

print(reference_img_interviewer, "-", os.path.exists(reference_img_interviewer))
print(reference_img_interviewer_side, "-", os.path.exists(reference_img_interviewer_side))
print(reference_img_interviewer_side_flipped, "-", os.path.exists(reference_img_interviewer_side_flipped))
# Out:
# reference_imgs/interviewees/raphael-pace.png - True
# reference_imgs/interviewees/raphael-pace-side.png - True
# reference_imgs/interviewees/raphael-pace-side-flipped.png - True
# reference_imgs/interviewer/jon-mallia.jpg - True
# reference_imgs/interviewer/jon-mallia-side.jpg - True
# reference_imgs/interviewer/jon-mallia-side-flipped.jpg - True

# %%
if roi_list_exists_in_file:
    # Initialise person category dictionary if empty
    if not bool(video_person_categorized):
        for person_category in ["interviewer", "interviewee", "unknown"]:
            video_person_categorized[person_category] = []

    for snapshot_img in os.listdir(dir_chosen_full_path):
        #if os.path.isfile(snapshot_img):
        if snapshot_img.endswith('.jpg') or snapshot_img.endswith('.png'):
            base_img_name = os.path.splitext(snapshot_img)[0][:-3]
            snapshot_path = os.path.join(dir_chosen_full_path, snapshot_img)
            try:
                with suppress_stdout():
                    #snapshot_encodings = DeepFace.represent(snapshot_path, model_name='ArcFace', detector_backend='mtcnn')
                    #snapshot_encodings = DeepFace.represent(snapshot_path, model_name='VGG-Face', detector_backend='mtcnn')
                    snapshot_encodings = DeepFace.represent(snapshot_path, model_name='Facenet512', detector_backend='mtcnn')
            except:
                print(f'No face detected in {snapshot_img}!')
                video_person_categorized["unknown"].append(snapshot_img)
                write_person_detected(chosen_video_data_path, base_img_name, os.path.splitext(snapshot_img)[0], "unknown")
                continue
            
            try:
                category = "Unknown"
                #category, conf_score  = compare_person_new(snapshot_path, [reference_img_interviewer, reference_img_interviewer_side, reference_img_interviewer_side_flipped], [reference_img_interviewee, reference_img_interviewee_side, reference_img_interviewee_side_flipped], facial_rec_model='ArcFace', custom_threshold=1.2)
                #category, conf_score = compare_person_new(snapshot_path, [reference_img_interviewer, reference_img_interviewer_side, reference_img_interviewer_side_flipped], [reference_img_interviewee, reference_img_interviewee_side, reference_img_interviewee_side_flipped], facial_rec_model='VGG-Face', custom_threshold=1.2)
                category, conf_score  = compare_person_new(snapshot_path, [reference_img_interviewer, reference_img_interviewer_side, reference_img_interviewer_side_flipped], [reference_img_interviewee, reference_img_interviewee_side, reference_img_interviewee_side_flipped], facial_rec_model='Facenet512', custom_threshold=1.2)
                

                if category == "Interviewee":
                    if interviewee_name != "":
                        print(f"{interviewee_name} (Interviewee) is detected in {snapshot_img}")
                    else:
                        print(f"Interviewee is detected in {snapshot_img}")
                elif category == "Interviewer":
                    if interviewer_name != "":
                        print(f"{interviewer_name} (Interviewer) is detected in {snapshot_img}")
                    else:
                        print(f"Interviewer is detected in {snapshot_img}")
                else:
                    print(f"Face not recognized in {snapshot_img} — person not found in the database.")
                
                video_person_categorized[category.lower()].append(snapshot_img)
                write_person_detected(chosen_video_data_path, base_img_name, os.path.splitext(snapshot_img)[0], category.lower())
                if category != "Unknown":
                    write_person_score(chosen_video_data_path, base_img_name, os.path.splitext(snapshot_img)[0], conf_score)
                #print(f"{snapshot_img} belongs to {category}")
            except Exception as e:
                print(f"Error processing {snapshot_img}: {e}")
    print(f"Person Classification process for {dir_chosen} has finished!")
else:
    raise Exception(f'Please ensure that all facial ROIs from {dir_chosen} have been extracted before running this!')
# Out:
# Raphael Pace (Interviewee) is detected in frame_0009_00.png
# Raphael Pace (Interviewee) is detected in frame_0010_00.png
# Raphael Pace (Interviewee) is detected in frame_0011_00.png
# Raphael Pace (Interviewee) is detected in frame_0012_00.png
# Raphael Pace (Interviewee) is detected in frame_0013_00.png
# Raphael Pace (Interviewee) is detected in frame_0014_00.png
# Jon Mallia (Interviewer) is detected in frame_0015_00.png
# Jon Mallia (Interviewer) is detected in frame_0016_00.png
# Raphael Pace (Interviewee) is detected in frame_0016_01.png
# Jon Mallia (Interviewer) is detected in frame_0017_00.png
# Raphael Pace (Interviewee) is detected in frame_0018_00.png
# Raphael Pace (Interviewee) is detected in frame_0019_00.png
# Jon Mallia (Interviewer) is detected in frame_0020_00.png
# Raphael Pace (Interviewee) is detected in frame_0020_01.png
# Raphael Pace (Interviewee) is detected in frame_0021_00.png
# Jon Mallia (Interviewer) is detected in frame_0021_01.png
# Jon Mallia (Interviewer) is detected in frame_0022_00.png
# Raphael Pace (Interviewee) is detected in frame_0023_00.png
# Jon Mallia (Interviewer) is detected in frame_0024_00.png
# Jon Mallia (Interviewer) is detected in frame_0025_00.png
# Jon Mallia (Interviewer) is detected in frame_0026_00.png
# Raphael Pace (Interviewee) is detected in frame_0027_00.png
# Raphael Pace (Interviewee) is detected in frame_0028_00.png
# Raphael Pace (Interviewee) is detected in frame_0029_00.png
# Raphael Pace (Interviewee) is detected in frame_0030_00.png
# Jon Mallia (Interviewer) is detected in frame_0031_00.png
# Jon Mallia (Interviewer) is detected in frame_0032_00.png
# Raphael Pace (Interviewee) is detected in frame_0032_01.png
# Jon Mallia (Interviewer) is detected in frame_0033_00.png
# Raphael Pace (Interviewee) is detected in frame_0033_01.png
# Jon Mallia (Interviewer) is detected in frame_0034_00.png
# Jon Mallia (Interviewer) is detected in frame_0035_00.png
# Jon Mallia (Interviewer) is detected in frame_0036_00.png
# Raphael Pace (Interviewee) is detected in frame_0037_00.png
# Raphael Pace (Interviewee) is detected in frame_0038_00.png
# Raphael Pace (Interviewee) is detected in frame_0039_00.png
# Raphael Pace (Interviewee) is detected in frame_0040_00.png
# Jon Mallia (Interviewer) is detected in frame_0041_00.png
# Raphael Pace (Interviewee) is detected in frame_0042_00.png
# Raphael Pace (Interviewee) is detected in frame_0043_00.png
# Jon Mallia (Interviewer) is detected in frame_0044_00.png
# Raphael Pace (Interviewee) is detected in frame_0045_00.png
# Jon Mallia (Interviewer) is detected in frame_0046_00.png
# Raphael Pace (Interviewee) is detected in frame_0047_00.png
# Raphael Pace (Interviewee) is detected in frame_0048_00.png
# Raphael Pace (Interviewee) is detected in frame_0049_00.png
# Raphael Pace (Interviewee) is detected in frame_0050_00.png
# Raphael Pace (Interviewee) is detected in frame_0051_00.png
# Raphael Pace (Interviewee) is detected in frame_0052_00.png
# Raphael Pace (Interviewee) is detected in frame_0053_00.png
# Jon Mallia (Interviewer) is detected in frame_0054_00.png
# Raphael Pace (Interviewee) is detected in frame_0055_00.png
# Raphael Pace (Interviewee) is detected in frame_0056_00.png
# Raphael Pace (Interviewee) is detected in frame_0057_00.png
# Raphael Pace (Interviewee) is detected in frame_0058_00.png
# Jon Mallia (Interviewer) is detected in frame_0058_01.png
# Raphael Pace (Interviewee) is detected in frame_0059_00.png
# Jon Mallia (Interviewer) is detected in frame_0059_01.png
# Raphael Pace (Interviewee) is detected in frame_0060_00.png
# Jon Mallia (Interviewer) is detected in frame_0060_01.png
# Raphael Pace (Interviewee) is detected in frame_0061_00.png
# Raphael Pace (Interviewee) is detected in frame_0062_00.png
# Raphael Pace (Interviewee) is detected in frame_0063_00.png
# Raphael Pace (Interviewee) is detected in frame_0064_00.png
# Jon Mallia (Interviewer) is detected in frame_0065_00.png
# Jon Mallia (Interviewer) is detected in frame_0066_00.png
# Raphael Pace (Interviewee) is detected in frame_0067_00.png
# Raphael Pace (Interviewee) is detected in frame_0068_00.png
# Raphael Pace (Interviewee) is detected in frame_0069_00.png
# Raphael Pace (Interviewee) is detected in frame_0070_00.png
# Raphael Pace (Interviewee) is detected in frame_0071_00.png
# Raphael Pace (Interviewee) is detected in frame_0072_00.png
# Jon Mallia (Interviewer) is detected in frame_0073_00.png
# Raphael Pace (Interviewee) is detected in frame_0074_00.png
# Raphael Pace (Interviewee) is detected in frame_0075_00.png
# Raphael Pace (Interviewee) is detected in frame_0076_00.png
# Raphael Pace (Interviewee) is detected in frame_0077_00.png
# Raphael Pace (Interviewee) is detected in frame_0078_00.png
# Raphael Pace (Interviewee) is detected in frame_0079_00.png
# Raphael Pace (Interviewee) is detected in frame_0080_00.png
# Raphael Pace (Interviewee) is detected in frame_0081_00.png
# Raphael Pace (Interviewee) is detected in frame_0082_00.png
# Raphael Pace (Interviewee) is detected in frame_0083_00.png
# Raphael Pace (Interviewee) is detected in frame_0084_00.png
# Raphael Pace (Interviewee) is detected in frame_0085_00.png
# Raphael Pace (Interviewee) is detected in frame_0086_00.png
# Raphael Pace (Interviewee) is detected in frame_0087_00.png
# Raphael Pace (Interviewee) is detected in frame_0088_00.png
# Raphael Pace (Interviewee) is detected in frame_0089_00.png
# Jon Mallia (Interviewer) is detected in frame_0090_00.png
# Jon Mallia (Interviewer) is detected in frame_0091_00.png
# Raphael Pace (Interviewee) is detected in frame_0092_00.png
# Raphael Pace (Interviewee) is detected in frame_0093_00.png
# Jon Mallia (Interviewer) is detected in frame_0094_00.png
# Raphael Pace (Interviewee) is detected in frame_0094_01.png
# Raphael Pace (Interviewee) is detected in frame_0095_00.png
# Jon Mallia (Interviewer) is detected in frame_0096_00.png
# Raphael Pace (Interviewee) is detected in frame_0097_00.png
# Jon Mallia (Interviewer) is detected in frame_0098_00.png
# Raphael Pace (Interviewee) is detected in frame_0099_00.png
# Jon Mallia (Interviewer) is detected in frame_0100_00.png
# Raphael Pace (Interviewee) is detected in frame_0101_00.png
# Raphael Pace (Interviewee) is detected in frame_0102_00.png
# Raphael Pace (Interviewee) is detected in frame_0103_00.png
# Raphael Pace (Interviewee) is detected in frame_0104_00.png
# Raphael Pace (Interviewee) is detected in frame_0105_00.png
# Jon Mallia (Interviewer) is detected in frame_0106_00.png
# Raphael Pace (Interviewee) is detected in frame_0107_00.png
# Raphael Pace (Interviewee) is detected in frame_0108_00.png
# Raphael Pace (Interviewee) is detected in frame_0109_00.png
# Raphael Pace (Interviewee) is detected in frame_0110_00.png
# Jon Mallia (Interviewer) is detected in frame_0111_00.png
# Raphael Pace (Interviewee) is detected in frame_0112_00.png
# Raphael Pace (Interviewee) is detected in frame_0113_00.png
# Raphael Pace (Interviewee) is detected in frame_0114_00.png
# Raphael Pace (Interviewee) is detected in frame_0115_00.png
# Jon Mallia (Interviewer) is detected in frame_0116_00.png
# Raphael Pace (Interviewee) is detected in frame_0117_00.png
# Jon Mallia (Interviewer) is detected in frame_0118_00.png
# Jon Mallia (Interviewer) is detected in frame_0119_00.png
# Raphael Pace (Interviewee) is detected in frame_0120_00.png
# Raphael Pace (Interviewee) is detected in frame_0121_00.png
# Raphael Pace (Interviewee) is detected in frame_0122_00.png
# Raphael Pace (Interviewee) is detected in frame_0123_00.png
# Raphael Pace (Interviewee) is detected in frame_0124_00.png
# Raphael Pace (Interviewee) is detected in frame_0125_00.png
# Jon Mallia (Interviewer) is detected in frame_0126_00.png
# Raphael Pace (Interviewee) is detected in frame_0127_00.png
# Jon Mallia (Interviewer) is detected in frame_0128_00.png
# Raphael Pace (Interviewee) is detected in frame_0129_00.png
# Raphael Pace (Interviewee) is detected in frame_0130_00.png
# Jon Mallia (Interviewer) is detected in frame_0131_00.png
# Raphael Pace (Interviewee) is detected in frame_0132_00.png
# Raphael Pace (Interviewee) is detected in frame_0133_00.png
# Raphael Pace (Interviewee) is detected in frame_0134_00.png
# Raphael Pace (Interviewee) is detected in frame_0135_00.png
# Jon Mallia (Interviewer) is detected in frame_0136_00.png
# Raphael Pace (Interviewee) is detected in frame_0137_00.png
# Jon Mallia (Interviewer) is detected in frame_0138_00.png
# Jon Mallia (Interviewer) is detected in frame_0139_00.png
# Raphael Pace (Interviewee) is detected in frame_0140_00.png
# Jon Mallia (Interviewer) is detected in frame_0141_00.png
# Jon Mallia (Interviewer) is detected in frame_0142_00.png
# Raphael Pace (Interviewee) is detected in frame_0143_00.png
# Raphael Pace (Interviewee) is detected in frame_0144_00.png
# Raphael Pace (Interviewee) is detected in frame_0145_00.png
# Raphael Pace (Interviewee) is detected in frame_0146_00.png
# Jon Mallia (Interviewer) is detected in frame_0147_00.png
# Jon Mallia (Interviewer) is detected in frame_0148_00.png
# Raphael Pace (Interviewee) is detected in frame_0149_00.png
# Raphael Pace (Interviewee) is detected in frame_0150_00.png
# Raphael Pace (Interviewee) is detected in frame_0151_00.png
# Raphael Pace (Interviewee) is detected in frame_0152_00.png
# Raphael Pace (Interviewee) is detected in frame_0153_00.png
# Jon Mallia (Interviewer) is detected in frame_0154_00.png
# Raphael Pace (Interviewee) is detected in frame_0155_00.png
# Raphael Pace (Interviewee) is detected in frame_0156_00.png
# Raphael Pace (Interviewee) is detected in frame_0157_00.png
# Raphael Pace (Interviewee) is detected in frame_0158_00.png
# Jon Mallia (Interviewer) is detected in frame_0158_01.png
# Raphael Pace (Interviewee) is detected in frame_0159_00.png
# Raphael Pace (Interviewee) is detected in frame_0160_00.png
# Raphael Pace (Interviewee) is detected in frame_0161_00.png
# Jon Mallia (Interviewer) is detected in frame_0162_00.png
# Jon Mallia (Interviewer) is detected in frame_0163_00.png
# Raphael Pace (Interviewee) is detected in frame_0164_00.png
# Raphael Pace (Interviewee) is detected in frame_0165_00.png
# Raphael Pace (Interviewee) is detected in frame_0166_00.png
# Raphael Pace (Interviewee) is detected in frame_0167_00.png
# Raphael Pace (Interviewee) is detected in frame_0168_00.png
# Raphael Pace (Interviewee) is detected in frame_0169_00.png
# Raphael Pace (Interviewee) is detected in frame_0170_00.png
# Jon Mallia (Interviewer) is detected in frame_0170_01.png
# Raphael Pace (Interviewee) is detected in frame_0171_00.png
# Jon Mallia (Interviewer) is detected in frame_0172_00.png
# Jon Mallia (Interviewer) is detected in frame_0173_00.png
# Jon Mallia (Interviewer) is detected in frame_0174_00.png
# Raphael Pace (Interviewee) is detected in frame_0174_01.png
# Raphael Pace (Interviewee) is detected in frame_0175_00.png
# Raphael Pace (Interviewee) is detected in frame_0176_00.png
# Raphael Pace (Interviewee) is detected in frame_0177_00.png
# Raphael Pace (Interviewee) is detected in frame_0178_00.png
# Raphael Pace (Interviewee) is detected in frame_0179_00.png
# Raphael Pace (Interviewee) is detected in frame_0180_00.png
# Raphael Pace (Interviewee) is detected in frame_0181_00.png
# Raphael Pace (Interviewee) is detected in frame_0182_00.png
# Raphael Pace (Interviewee) is detected in frame_0183_00.png
# Jon Mallia (Interviewer) is detected in frame_0184_00.png
# Jon Mallia (Interviewer) is detected in frame_0185_00.png
# Raphael Pace (Interviewee) is detected in frame_0186_00.png
# Raphael Pace (Interviewee) is detected in frame_0187_00.png
# Raphael Pace (Interviewee) is detected in frame_0188_00.png
# Raphael Pace (Interviewee) is detected in frame_0189_00.png
# Raphael Pace (Interviewee) is detected in frame_0190_00.png
# Raphael Pace (Interviewee) is detected in frame_0191_00.png
# Jon Mallia (Interviewer) is detected in frame_0192_00.png
# Raphael Pace (Interviewee) is detected in frame_0193_00.png
# Raphael Pace (Interviewee) is detected in frame_0194_00.png
# Jon Mallia (Interviewer) is detected in frame_0195_00.png
# Raphael Pace (Interviewee) is detected in frame_0196_00.png
# Raphael Pace (Interviewee) is detected in frame_0197_00.png
# Raphael Pace (Interviewee) is detected in frame_0198_00.png
# Jon Mallia (Interviewer) is detected in frame_0199_00.png
# Raphael Pace (Interviewee) is detected in frame_0200_00.png
# Face not recognized in frame_0201_00.png — person not found in the database.
# Raphael Pace (Interviewee) is detected in frame_0202_00.png
# Raphael Pace (Interviewee) is detected in frame_0203_00.png
# Jon Mallia (Interviewer) is detected in frame_0204_00.png
# Raphael Pace (Interviewee) is detected in frame_0205_00.png
# Raphael Pace (Interviewee) is detected in frame_0206_00.png
# Raphael Pace (Interviewee) is detected in frame_0207_00.png
# Raphael Pace (Interviewee) is detected in frame_0208_00.png
# Jon Mallia (Interviewer) is detected in frame_0209_00.png
# Raphael Pace (Interviewee) is detected in frame_0210_00.png
# Raphael Pace (Interviewee) is detected in frame_0211_00.png
# Raphael Pace (Interviewee) is detected in frame_0212_00.png
# Raphael Pace (Interviewee) is detected in frame_0213_00.png
# Raphael Pace (Interviewee) is detected in frame_0214_00.png
# Jon Mallia (Interviewer) is detected in frame_0215_00.png
# Raphael Pace (Interviewee) is detected in frame_0216_00.png
# Raphael Pace (Interviewee) is detected in frame_0217_00.png
# Jon Mallia (Interviewer) is detected in frame_0218_00.png
# Raphael Pace (Interviewee) is detected in frame_0219_00.png
# Raphael Pace (Interviewee) is detected in frame_0220_00.png
# Raphael Pace (Interviewee) is detected in frame_0221_00.png
# Raphael Pace (Interviewee) is detected in frame_0222_00.png
# Raphael Pace (Interviewee) is detected in frame_0223_00.png
# Jon Mallia (Interviewer) is detected in frame_0224_00.png
# Raphael Pace (Interviewee) is detected in frame_0225_00.png
# Raphael Pace (Interviewee) is detected in frame_0226_00.png
# Raphael Pace (Interviewee) is detected in frame_0227_00.png
# Jon Mallia (Interviewer) is detected in frame_0228_00.png
# Jon Mallia (Interviewer) is detected in frame_0229_00.png
# Raphael Pace (Interviewee) is detected in frame_0230_00.png
# Raphael Pace (Interviewee) is detected in frame_0231_00.png
# Raphael Pace (Interviewee) is detected in frame_0232_00.png
# Jon Mallia (Interviewer) is detected in frame_0233_00.png
# Raphael Pace (Interviewee) is detected in frame_0234_00.png
# Raphael Pace (Interviewee) is detected in frame_0235_00.png
# Raphael Pace (Interviewee) is detected in frame_0236_00.png
# Raphael Pace (Interviewee) is detected in frame_0237_00.png
# Jon Mallia (Interviewer) is detected in frame_0238_00.png
# Jon Mallia (Interviewer) is detected in frame_0239_00.png
# Raphael Pace (Interviewee) is detected in frame_0240_00.png
# Raphael Pace (Interviewee) is detected in frame_0241_00.png
# Raphael Pace (Interviewee) is detected in frame_0242_00.png
# Raphael Pace (Interviewee) is detected in frame_0243_00.png
# Raphael Pace (Interviewee) is detected in frame_0244_00.png
# Raphael Pace (Interviewee) is detected in frame_0245_00.png
# Jon Mallia (Interviewer) is detected in frame_0246_00.png
# Raphael Pace (Interviewee) is detected in frame_0247_00.png
# Raphael Pace (Interviewee) is detected in frame_0248_00.png
# Raphael Pace (Interviewee) is detected in frame_0249_00.png
# Raphael Pace (Interviewee) is detected in frame_0250_00.png
# Raphael Pace (Interviewee) is detected in frame_0251_00.png
# Jon Mallia (Interviewer) is detected in frame_0252_00.png
# Raphael Pace (Interviewee) is detected in frame_0253_00.png
# Raphael Pace (Interviewee) is detected in frame_0254_00.png
# Jon Mallia (Interviewer) is detected in frame_0255_00.png
# Jon Mallia (Interviewer) is detected in frame_0256_00.png
# Raphael Pace (Interviewee) is detected in frame_0257_00.png
# Jon Mallia (Interviewer) is detected in frame_0258_00.png
# Raphael Pace (Interviewee) is detected in frame_0259_00.png
# Jon Mallia (Interviewer) is detected in frame_0259_01.png
# Jon Mallia (Interviewer) is detected in frame_0260_00.png
# Jon Mallia (Interviewer) is detected in frame_0261_00.png
# Jon Mallia (Interviewer) is detected in frame_0262_00.png
# Raphael Pace (Interviewee) is detected in frame_0263_00.png
# Raphael Pace (Interviewee) is detected in frame_0264_00.png
# Raphael Pace (Interviewee) is detected in frame_0265_00.png
# Raphael Pace (Interviewee) is detected in frame_0266_00.png
# Jon Mallia (Interviewer) is detected in frame_0267_00.png
# Jon Mallia (Interviewer) is detected in frame_0268_00.png
# Jon Mallia (Interviewer) is detected in frame_0269_00.png
# Jon Mallia (Interviewer) is detected in frame_0270_00.png
# Jon Mallia (Interviewer) is detected in frame_0271_00.png
# Jon Mallia (Interviewer) is detected in frame_0272_00.png
# Raphael Pace (Interviewee) is detected in frame_0273_00.png
# Jon Mallia (Interviewer) is detected in frame_0274_00.png
# Jon Mallia (Interviewer) is detected in frame_0275_00.png
# Raphael Pace (Interviewee) is detected in frame_0276_00.png
# Raphael Pace (Interviewee) is detected in frame_0277_00.png
# Jon Mallia (Interviewer) is detected in frame_0278_00.png
# Raphael Pace (Interviewee) is detected in frame_0279_00.png
# Raphael Pace (Interviewee) is detected in frame_0280_00.png
# Jon Mallia (Interviewer) is detected in frame_0281_00.png
# Raphael Pace (Interviewee) is detected in frame_0282_00.png
# Raphael Pace (Interviewee) is detected in frame_0283_00.png
# Jon Mallia (Interviewer) is detected in frame_0284_00.png
# Raphael Pace (Interviewee) is detected in frame_0285_00.png
# Raphael Pace (Interviewee) is detected in frame_0286_00.png
# Jon Mallia (Interviewer) is detected in frame_0287_00.png
# Raphael Pace (Interviewee) is detected in frame_0288_00.png
# Raphael Pace (Interviewee) is detected in frame_0289_00.png
# Raphael Pace (Interviewee) is detected in frame_0290_00.png
# Raphael Pace (Interviewee) is detected in frame_0291_00.png
# Raphael Pace (Interviewee) is detected in frame_0292_00.png
# Raphael Pace (Interviewee) is detected in frame_0293_00.png
# Raphael Pace (Interviewee) is detected in frame_0294_00.png
# Raphael Pace (Interviewee) is detected in frame_0295_00.png
# Raphael Pace (Interviewee) is detected in frame_0296_00.png
# Raphael Pace (Interviewee) is detected in frame_0297_00.png
# Raphael Pace (Interviewee) is detected in frame_0298_00.png
# Jon Mallia (Interviewer) is detected in frame_0299_00.png
# Raphael Pace (Interviewee) is detected in frame_0300_00.png
# Raphael Pace (Interviewee) is detected in frame_0301_00.png
# Raphael Pace (Interviewee) is detected in frame_0302_00.png
# Raphael Pace (Interviewee) is detected in frame_0303_00.png
# Jon Mallia (Interviewer) is detected in frame_0304_00.png
# Jon Mallia (Interviewer) is detected in frame_0305_00.png
# Raphael Pace (Interviewee) is detected in frame_0306_00.png
# Jon Mallia (Interviewer) is detected in frame_0307_00.png
# Jon Mallia (Interviewer) is detected in frame_0308_00.png
# Raphael Pace (Interviewee) is detected in frame_0309_00.png
# Raphael Pace (Interviewee) is detected in frame_0310_00.png
# Raphael Pace (Interviewee) is detected in frame_0311_00.png
# Jon Mallia (Interviewer) is detected in frame_0312_00.png
# Jon Mallia (Interviewer) is detected in frame_0313_00.png
# Jon Mallia (Interviewer) is detected in frame_0314_00.png
# Raphael Pace (Interviewee) is detected in frame_0315_00.png
# Jon Mallia (Interviewer) is detected in frame_0316_00.png
# Jon Mallia (Interviewer) is detected in frame_0317_00.png
# Jon Mallia (Interviewer) is detected in frame_0318_00.png
# Jon Mallia (Interviewer) is detected in frame_0319_00.png
# Jon Mallia (Interviewer) is detected in frame_0320_00.png
# Raphael Pace (Interviewee) is detected in frame_0321_00.png
# Jon Mallia (Interviewer) is detected in frame_0322_00.png
# Jon Mallia (Interviewer) is detected in frame_0323_00.png
# Jon Mallia (Interviewer) is detected in frame_0324_00.png
# Jon Mallia (Interviewer) is detected in frame_0325_00.png
# Jon Mallia (Interviewer) is detected in frame_0326_00.png
# Raphael Pace (Interviewee) is detected in frame_0327_00.png
# Jon Mallia (Interviewer) is detected in frame_0328_00.png
# Jon Mallia (Interviewer) is detected in frame_0329_00.png
# Jon Mallia (Interviewer) is detected in frame_0330_00.png
# Jon Mallia (Interviewer) is detected in frame_0331_00.png
# Jon Mallia (Interviewer) is detected in frame_0332_00.png
# No face detected in frame_0332_01.png!
# Jon Mallia (Interviewer) is detected in frame_0333_00.png
# Jon Mallia (Interviewer) is detected in frame_0334_00.png
# Jon Mallia (Interviewer) is detected in frame_0335_00.png
# Jon Mallia (Interviewer) is detected in frame_0336_00.png
# Raphael Pace (Interviewee) is detected in frame_0337_00.png
# Raphael Pace (Interviewee) is detected in frame_0338_00.png
# Raphael Pace (Interviewee) is detected in frame_0339_00.png
# Jon Mallia (Interviewer) is detected in frame_0340_00.png
# Raphael Pace (Interviewee) is detected in frame_0341_00.png
# Raphael Pace (Interviewee) is detected in frame_0342_00.png
# Raphael Pace (Interviewee) is detected in frame_0343_00.png
# Raphael Pace (Interviewee) is detected in frame_0344_00.png
# Raphael Pace (Interviewee) is detected in frame_0345_00.png
# Raphael Pace (Interviewee) is detected in frame_0346_00.png
# Jon Mallia (Interviewer) is detected in frame_0346_01.png
# Raphael Pace (Interviewee) is detected in frame_0347_00.png
# Jon Mallia (Interviewer) is detected in frame_0348_00.png
# Raphael Pace (Interviewee) is detected in frame_0349_00.png
# Raphael Pace (Interviewee) is detected in frame_0350_00.png
# Raphael Pace (Interviewee) is detected in frame_0351_00.png
# Raphael Pace (Interviewee) is detected in frame_0352_00.png
# Jon Mallia (Interviewer) is detected in frame_0353_00.png
# Raphael Pace (Interviewee) is detected in frame_0354_00.png
# Raphael Pace (Interviewee) is detected in frame_0355_00.png
# Jon Mallia (Interviewer) is detected in frame_0356_00.png
# Raphael Pace (Interviewee) is detected in frame_0357_00.png
# Raphael Pace (Interviewee) is detected in frame_0358_00.png
# Jon Mallia (Interviewer) is detected in frame_0359_00.png
# Jon Mallia (Interviewer) is detected in frame_0360_00.png
# Jon Mallia (Interviewer) is detected in frame_0361_00.png
# Jon Mallia (Interviewer) is detected in frame_0362_00.png
# Jon Mallia (Interviewer) is detected in frame_0363_00.png
# Jon Mallia (Interviewer) is detected in frame_0364_00.png
# Raphael Pace (Interviewee) is detected in frame_0365_00.png
# Raphael Pace (Interviewee) is detected in frame_0369_00.png
# Raphael Pace (Interviewee) is detected in frame_0370_00.png
# Raphael Pace (Interviewee) is detected in frame_0371_00.png
# Raphael Pace (Interviewee) is detected in frame_0372_00.png
# Raphael Pace (Interviewee) is detected in frame_0373_00.png
# Raphael Pace (Interviewee) is detected in frame_0374_00.png
# Raphael Pace (Interviewee) is detected in frame_0375_00.png
# Raphael Pace (Interviewee) is detected in frame_0376_00.png
# Raphael Pace (Interviewee) is detected in frame_0377_00.png
# Jon Mallia (Interviewer) is detected in frame_0378_00.png
# Raphael Pace (Interviewee) is detected in frame_0378_01.png
# Jon Mallia (Interviewer) is detected in frame_0379_00.png
# Raphael Pace (Interviewee) is detected in frame_0380_00.png
# Jon Mallia (Interviewer) is detected in frame_0380_01.png
# Jon Mallia (Interviewer) is detected in frame_0381_00.png
# Raphael Pace (Interviewee) is detected in frame_0382_00.png
# Jon Mallia (Interviewer) is detected in frame_0383_00.png
# Raphael Pace (Interviewee) is detected in frame_0384_00.png
# Jon Mallia (Interviewer) is detected in frame_0385_00.png
# Jon Mallia (Interviewer) is detected in frame_0386_00.png
# Jon Mallia (Interviewer) is detected in frame_0387_00.png
# Raphael Pace (Interviewee) is detected in frame_0388_00.png
# Jon Mallia (Interviewer) is detected in frame_0389_00.png
# Raphael Pace (Interviewee) is detected in frame_0389_01.png
# Jon Mallia (Interviewer) is detected in frame_0390_00.png
# Raphael Pace (Interviewee) is detected in frame_0390_01.png
# Raphael Pace (Interviewee) is detected in frame_0391_00.png
# No face detected in frame_0391_01.png!
# Jon Mallia (Interviewer) is detected in frame_0392_00.png
# Raphael Pace (Interviewee) is detected in frame_0393_00.png
# Raphael Pace (Interviewee) is detected in frame_0394_00.png
# Raphael Pace (Interviewee) is detected in frame_0395_00.png
# Raphael Pace (Interviewee) is detected in frame_0396_00.png
# Raphael Pace (Interviewee) is detected in frame_0397_00.png
# Jon Mallia (Interviewer) is detected in frame_0398_00.png
# Jon Mallia (Interviewer) is detected in frame_0399_00.png
# Raphael Pace (Interviewee) is detected in frame_0400_00.png
# Raphael Pace (Interviewee) is detected in frame_0401_00.png
# Raphael Pace (Interviewee) is detected in frame_0402_00.png
# Jon Mallia (Interviewer) is detected in frame_0403_00.png
# Raphael Pace (Interviewee) is detected in frame_0404_00.png
# Raphael Pace (Interviewee) is detected in frame_0405_00.png
# Raphael Pace (Interviewee) is detected in frame_0406_00.png
# Jon Mallia (Interviewer) is detected in frame_0407_00.png
# Raphael Pace (Interviewee) is detected in frame_0408_00.png
# Raphael Pace (Interviewee) is detected in frame_0409_00.png
# Raphael Pace (Interviewee) is detected in frame_0410_00.png
# Raphael Pace (Interviewee) is detected in frame_0411_00.png
# Raphael Pace (Interviewee) is detected in frame_0412_00.png
# Jon Mallia (Interviewer) is detected in frame_0413_00.png
# Raphael Pace (Interviewee) is detected in frame_0414_00.png
# Jon Mallia (Interviewer) is detected in frame_0415_00.png
# Raphael Pace (Interviewee) is detected in frame_0416_00.png
# Jon Mallia (Interviewer) is detected in frame_0416_01.png
# Raphael Pace (Interviewee) is detected in frame_0417_00.png
# Jon Mallia (Interviewer) is detected in frame_0418_00.png
# Jon Mallia (Interviewer) is detected in frame_0419_00.png
# Jon Mallia (Interviewer) is detected in frame_0420_00.png
# Raphael Pace (Interviewee) is detected in frame_0421_00.png
# Jon Mallia (Interviewer) is detected in frame_0421_01.png
# Jon Mallia (Interviewer) is detected in frame_0422_00.png
# Raphael Pace (Interviewee) is detected in frame_0423_00.png
# Jon Mallia (Interviewer) is detected in frame_0424_00.png
# Raphael Pace (Interviewee) is detected in frame_0425_00.png
# Raphael Pace (Interviewee) is detected in frame_0426_00.png
# Raphael Pace (Interviewee) is detected in frame_0427_00.png
# Jon Mallia (Interviewer) is detected in frame_0428_00.png
# Raphael Pace (Interviewee) is detected in frame_0429_00.png
# Jon Mallia (Interviewer) is detected in frame_0430_00.png
# Jon Mallia (Interviewer) is detected in frame_0431_00.png
# Jon Mallia (Interviewer) is detected in frame_0432_00.png
# Raphael Pace (Interviewee) is detected in frame_0433_00.png
# Jon Mallia (Interviewer) is detected in frame_0434_00.png
# Raphael Pace (Interviewee) is detected in frame_0435_00.png
# Raphael Pace (Interviewee) is detected in frame_0436_00.png
# Jon Mallia (Interviewer) is detected in frame_0437_00.png
# Jon Mallia (Interviewer) is detected in frame_0438_00.png
# Raphael Pace (Interviewee) is detected in frame_0439_00.png
# Jon Mallia (Interviewer) is detected in frame_0440_00.png
# Raphael Pace (Interviewee) is detected in frame_0441_00.png
# Raphael Pace (Interviewee) is detected in frame_0442_00.png
# Jon Mallia (Interviewer) is detected in frame_0443_00.png
# Raphael Pace (Interviewee) is detected in frame_0444_00.png
# Raphael Pace (Interviewee) is detected in frame_0445_00.png
# Raphael Pace (Interviewee) is detected in frame_0446_00.png
# Raphael Pace (Interviewee) is detected in frame_0447_00.png
# Raphael Pace (Interviewee) is detected in frame_0448_00.png
# Raphael Pace (Interviewee) is detected in frame_0449_00.png
# Raphael Pace (Interviewee) is detected in frame_0450_00.png
# Raphael Pace (Interviewee) is detected in frame_0451_00.png
# Jon Mallia (Interviewer) is detected in frame_0452_00.png
# Raphael Pace (Interviewee) is detected in frame_0453_00.png
# Raphael Pace (Interviewee) is detected in frame_0454_00.png
# Raphael Pace (Interviewee) is detected in frame_0455_00.png
# Raphael Pace (Interviewee) is detected in frame_0456_00.png
# Jon Mallia (Interviewer) is detected in frame_0457_00.png
# Jon Mallia (Interviewer) is detected in frame_0458_00.png
# Raphael Pace (Interviewee) is detected in frame_0459_00.png
# Jon Mallia (Interviewer) is detected in frame_0460_00.png
# Raphael Pace (Interviewee) is detected in frame_0461_00.png
# Raphael Pace (Interviewee) is detected in frame_0462_00.png
# Jon Mallia (Interviewer) is detected in frame_0462_01.png
# Raphael Pace (Interviewee) is detected in frame_0464_00.png
# Jon Mallia (Interviewer) is detected in frame_0464_01.png
# Raphael Pace (Interviewee) is detected in frame_0465_00.png
# Raphael Pace (Interviewee) is detected in frame_0466_00.png
# Raphael Pace (Interviewee) is detected in frame_0467_00.png
# Jon Mallia (Interviewer) is detected in frame_0468_00.png
# Raphael Pace (Interviewee) is detected in frame_0469_00.png
# Jon Mallia (Interviewer) is detected in frame_0470_00.png
# Raphael Pace (Interviewee) is detected in frame_0471_00.png
# Jon Mallia (Interviewer) is detected in frame_0472_00.png
# Raphael Pace (Interviewee) is detected in frame_0473_00.png
# Raphael Pace (Interviewee) is detected in frame_0474_00.png
# Raphael Pace (Interviewee) is detected in frame_0475_00.png
# Raphael Pace (Interviewee) is detected in frame_0476_00.png
# Raphael Pace (Interviewee) is detected in frame_0477_00.png
# Raphael Pace (Interviewee) is detected in frame_0478_00.png
# Raphael Pace (Interviewee) is detected in frame_0479_00.png
# Jon Mallia (Interviewer) is detected in frame_0479_01.png
# Raphael Pace (Interviewee) is detected in frame_0480_00.png
# Jon Mallia (Interviewer) is detected in frame_0481_00.png
# Jon Mallia (Interviewer) is detected in frame_0482_00.png
# Raphael Pace (Interviewee) is detected in frame_0483_00.png
# Raphael Pace (Interviewee) is detected in frame_0484_00.png
# Raphael Pace (Interviewee) is detected in frame_0485_00.png
# Jon Mallia (Interviewer) is detected in frame_0486_00.png
# Raphael Pace (Interviewee) is detected in frame_0487_00.png
# Jon Mallia (Interviewer) is detected in frame_0488_00.png
# Raphael Pace (Interviewee) is detected in frame_0488_01.png
# Raphael Pace (Interviewee) is detected in frame_0489_00.png
# Raphael Pace (Interviewee) is detected in frame_0490_00.png
# Raphael Pace (Interviewee) is detected in frame_0491_00.png
# Raphael Pace (Interviewee) is detected in frame_0492_00.png
# Raphael Pace (Interviewee) is detected in frame_0493_00.png
# Raphael Pace (Interviewee) is detected in frame_0494_00.png
# Raphael Pace (Interviewee) is detected in frame_0495_00.png
# Jon Mallia (Interviewer) is detected in frame_0496_01.png
# No face detected in frame_0498_00.png!
# Raphael Pace (Interviewee) is detected in frame_0499_00.png
# Jon Mallia (Interviewer) is detected in frame_0500_00.png
# Jon Mallia (Interviewer) is detected in frame_0501_00.png
# Raphael Pace (Interviewee) is detected in frame_0501_01.png
# Jon Mallia (Interviewer) is detected in frame_0502_00.png
# Jon Mallia (Interviewer) is detected in frame_0503_00.png
# Jon Mallia (Interviewer) is detected in frame_0504_00.png
# Raphael Pace (Interviewee) is detected in frame_0504_01.png
# Jon Mallia (Interviewer) is detected in frame_0505_00.png
# Raphael Pace (Interviewee) is detected in frame_0506_00.png
# Raphael Pace (Interviewee) is detected in frame_0507_00.png
# Raphael Pace (Interviewee) is detected in frame_0508_00.png
# Raphael Pace (Interviewee) is detected in frame_0509_00.png
# Raphael Pace (Interviewee) is detected in frame_0510_00.png
# Jon Mallia (Interviewer) is detected in frame_0511_00.png
# Raphael Pace (Interviewee) is detected in frame_0511_01.png
# Raphael Pace (Interviewee) is detected in frame_0512_00.png
# Jon Mallia (Interviewer) is detected in frame_0513_00.png
# Jon Mallia (Interviewer) is detected in frame_0519_00.png
# Jon Mallia (Interviewer) is detected in frame_0520_00.png
# Jon Mallia (Interviewer) is detected in frame_0521_00.png
# Raphael Pace (Interviewee) is detected in frame_0522_00.png
# Jon Mallia (Interviewer) is detected in frame_0522_01.png
# Raphael Pace (Interviewee) is detected in frame_0523_00.png
# Jon Mallia (Interviewer) is detected in frame_0523_01.png
# Jon Mallia (Interviewer) is detected in frame_0524_00.png
# Raphael Pace (Interviewee) is detected in frame_0524_01.png
# Jon Mallia (Interviewer) is detected in frame_0525_00.png
# Raphael Pace (Interviewee) is detected in frame_0525_01.png
# Jon Mallia (Interviewer) is detected in frame_0526_00.png
# Jon Mallia (Interviewer) is detected in frame_0527_00.png
# Raphael Pace (Interviewee) is detected in frame_0528_00.png
# Jon Mallia (Interviewer) is detected in frame_0529_00.png
# Raphael Pace (Interviewee) is detected in frame_0529_01.png
# Raphael Pace (Interviewee) is detected in frame_0530_00.png
# Jon Mallia (Interviewer) is detected in frame_0530_01.png
# Raphael Pace (Interviewee) is detected in frame_0531_00.png
# Jon Mallia (Interviewer) is detected in frame_0531_01.png
# Jon Mallia (Interviewer) is detected in frame_0532_00.png
# Raphael Pace (Interviewee) is detected in frame_0533_00.png
# Raphael Pace (Interviewee) is detected in frame_0534_00.png
# Raphael Pace (Interviewee) is detected in frame_0535_00.png
# Raphael Pace (Interviewee) is detected in frame_0536_00.png
# Raphael Pace (Interviewee) is detected in frame_0537_00.png
# Raphael Pace (Interviewee) is detected in frame_0538_00.png
# Raphael Pace (Interviewee) is detected in frame_0539_00.png
# Raphael Pace (Interviewee) is detected in frame_0540_00.png
# Raphael Pace (Interviewee) is detected in frame_0541_00.png
# Raphael Pace (Interviewee) is detected in frame_0542_00.png
# Jon Mallia (Interviewer) is detected in frame_0543_00.png
# Raphael Pace (Interviewee) is detected in frame_0544_00.png
# Jon Mallia (Interviewer) is detected in frame_0545_00.png
# Raphael Pace (Interviewee) is detected in frame_0546_00.png
# Jon Mallia (Interviewer) is detected in frame_0547_00.png
# Jon Mallia (Interviewer) is detected in frame_0548_00.png
# Raphael Pace (Interviewee) is detected in frame_0549_00.png
# Face not recognized in frame_0550_00.png — person not found in the database.
# Jon Mallia (Interviewer) is detected in frame_0551_00.png
# Raphael Pace (Interviewee) is detected in frame_0552_00.png
# Raphael Pace (Interviewee) is detected in frame_0553_00.png
# Raphael Pace (Interviewee) is detected in frame_0554_00.png
# Raphael Pace (Interviewee) is detected in frame_0555_00.png
# Raphael Pace (Interviewee) is detected in frame_0556_00.png
# Raphael Pace (Interviewee) is detected in frame_0557_00.png
# Raphael Pace (Interviewee) is detected in frame_0558_00.png
# No face detected in frame_0558_01.png!
# Jon Mallia (Interviewer) is detected in frame_0559_00.png
# Raphael Pace (Interviewee) is detected in frame_0560_00.png
# Raphael Pace (Interviewee) is detected in frame_0561_00.png
# Jon Mallia (Interviewer) is detected in frame_0562_00.png
# Raphael Pace (Interviewee) is detected in frame_0563_00.png
# Jon Mallia (Interviewer) is detected in frame_0564_00.png
# Raphael Pace (Interviewee) is detected in frame_0565_00.png
# Raphael Pace (Interviewee) is detected in frame_0566_00.png
# Raphael Pace (Interviewee) is detected in frame_0567_00.png
# Raphael Pace (Interviewee) is detected in frame_0568_00.png
# Raphael Pace (Interviewee) is detected in frame_0569_00.png
# Raphael Pace (Interviewee) is detected in frame_0570_00.png
# Raphael Pace (Interviewee) is detected in frame_0571_00.png
# Raphael Pace (Interviewee) is detected in frame_0572_00.png
# Raphael Pace (Interviewee) is detected in frame_0573_00.png
# Raphael Pace (Interviewee) is detected in frame_0574_00.png
# Raphael Pace (Interviewee) is detected in frame_0575_00.png
# Raphael Pace (Interviewee) is detected in frame_0577_00.png
# Jon Mallia (Interviewer) is detected in frame_0578_00.png
# Raphael Pace (Interviewee) is detected in frame_0578_01.png
# Raphael Pace (Interviewee) is detected in frame_0579_00.png
# Raphael Pace (Interviewee) is detected in frame_0580_00.png
# Face not recognized in frame_0581_00.png — person not found in the database.
# Raphael Pace (Interviewee) is detected in frame_0582_00.png
# Raphael Pace (Interviewee) is detected in frame_0583_00.png
# Raphael Pace (Interviewee) is detected in frame_0584_00.png
# Raphael Pace (Interviewee) is detected in frame_0585_00.png
# Raphael Pace (Interviewee) is detected in frame_0586_00.png
# Raphael Pace (Interviewee) is detected in frame_0587_00.png
# Raphael Pace (Interviewee) is detected in frame_0588_00.png
# Raphael Pace (Interviewee) is detected in frame_0589_00.png
# Raphael Pace (Interviewee) is detected in frame_0590_00.png
# Jon Mallia (Interviewer) is detected in frame_0590_01.png
# Jon Mallia (Interviewer) is detected in frame_0591_00.png
# Raphael Pace (Interviewee) is detected in frame_0591_01.png
# Jon Mallia (Interviewer) is detected in frame_0592_00.png
# Raphael Pace (Interviewee) is detected in frame_0593_00.png
# Raphael Pace (Interviewee) is detected in frame_0594_00.png
# Raphael Pace (Interviewee) is detected in frame_0595_00.png
# Jon Mallia (Interviewer) is detected in frame_0596_00.png
# Raphael Pace (Interviewee) is detected in frame_0597_00.png
# Raphael Pace (Interviewee) is detected in frame_0598_00.png
# Jon Mallia (Interviewer) is detected in frame_0599_00.png
# Jon Mallia (Interviewer) is detected in frame_0600_00.png
# Raphael Pace (Interviewee) is detected in frame_0601_00.png
# Raphael Pace (Interviewee) is detected in frame_0602_00.png
# Jon Mallia (Interviewer) is detected in frame_0603_00.png
# Raphael Pace (Interviewee) is detected in frame_0604_00.png
# Jon Mallia (Interviewer) is detected in frame_0605_00.png
# Jon Mallia (Interviewer) is detected in frame_0606_00.png
# Jon Mallia (Interviewer) is detected in frame_0607_00.png
# Raphael Pace (Interviewee) is detected in frame_0608_00.png
# Raphael Pace (Interviewee) is detected in frame_0609_00.png
# Raphael Pace (Interviewee) is detected in frame_0610_00.png
# Raphael Pace (Interviewee) is detected in frame_0611_00.png
# Raphael Pace (Interviewee) is detected in frame_0612_00.png
# Raphael Pace (Interviewee) is detected in frame_0613_00.png
# Raphael Pace (Interviewee) is detected in frame_0614_00.png
# Raphael Pace (Interviewee) is detected in frame_0615_00.png
# Jon Mallia (Interviewer) is detected in frame_0616_00.png
# Jon Mallia (Interviewer) is detected in frame_0617_00.png
# Raphael Pace (Interviewee) is detected in frame_0618_00.png
# Raphael Pace (Interviewee) is detected in frame_0619_00.png
# Raphael Pace (Interviewee) is detected in frame_0620_00.png
# Jon Mallia (Interviewer) is detected in frame_0621_00.png
# Jon Mallia (Interviewer) is detected in frame_0622_00.png
# Raphael Pace (Interviewee) is detected in frame_0623_00.png
# Raphael Pace (Interviewee) is detected in frame_0624_00.png
# Jon Mallia (Interviewer) is detected in frame_0625_00.png
# Raphael Pace (Interviewee) is detected in frame_0626_00.png
# Jon Mallia (Interviewer) is detected in frame_0627_00.png
# Raphael Pace (Interviewee) is detected in frame_0628_00.png
# Jon Mallia (Interviewer) is detected in frame_0629_00.png
# Jon Mallia (Interviewer) is detected in frame_0630_00.png
# Raphael Pace (Interviewee) is detected in frame_0631_00.png
# Raphael Pace (Interviewee) is detected in frame_0632_00.png
# Jon Mallia (Interviewer) is detected in frame_0632_01.png
# Raphael Pace (Interviewee) is detected in frame_0633_00.png
# Raphael Pace (Interviewee) is detected in frame_0634_00.png
# Raphael Pace (Interviewee) is detected in frame_0635_00.png
# Raphael Pace (Interviewee) is detected in frame_0636_00.png
# Raphael Pace (Interviewee) is detected in frame_0637_00.png
# Jon Mallia (Interviewer) is detected in frame_0637_01.png
# Raphael Pace (Interviewee) is detected in frame_0638_00.png
# Jon Mallia (Interviewer) is detected in frame_0638_01.png
# Raphael Pace (Interviewee) is detected in frame_0640_00.png
# Raphael Pace (Interviewee) is detected in frame_0641_00.png
# Jon Mallia (Interviewer) is detected in frame_0641_01.png
# Face not recognized in frame_0642_00.png — person not found in the database.
# Jon Mallia (Interviewer) is detected in frame_0643_00.png
# Face not recognized in frame_0643_01.png — person not found in the database.
# Jon Mallia (Interviewer) is detected in frame_0644_00.png
# Jon Mallia (Interviewer) is detected in frame_0645_00.png
# Raphael Pace (Interviewee) is detected in frame_0645_01.png
# Raphael Pace (Interviewee) is detected in frame_0646_00.png
# Jon Mallia (Interviewer) is detected in frame_0646_01.png
# Raphael Pace (Interviewee) is detected in frame_0647_00.png
# Raphael Pace (Interviewee) is detected in frame_0648_00.png
# Raphael Pace (Interviewee) is detected in frame_0649_00.png
# Raphael Pace (Interviewee) is detected in frame_0650_00.png
# Jon Mallia (Interviewer) is detected in frame_0651_00.png
# Raphael Pace (Interviewee) is detected in frame_0651_01.png
# Raphael Pace (Interviewee) is detected in frame_0652_00.png
# Raphael Pace (Interviewee) is detected in frame_0653_00.png
# Jon Mallia (Interviewer) is detected in frame_0654_00.png
# Raphael Pace (Interviewee) is detected in frame_0654_01.png
# Jon Mallia (Interviewer) is detected in frame_0655_00.png
# Raphael Pace (Interviewee) is detected in frame_0655_01.png
# Jon Mallia (Interviewer) is detected in frame_0656_00.png
# Raphael Pace (Interviewee) is detected in frame_0656_01.png
# Jon Mallia (Interviewer) is detected in frame_0657_00.png
# Raphael Pace (Interviewee) is detected in frame_0657_01.png
# Raphael Pace (Interviewee) is detected in frame_0658_00.png
# Jon Mallia (Interviewer) is detected in frame_0658_01.png
# Jon Mallia (Interviewer) is detected in frame_0659_00.png
# Raphael Pace (Interviewee) is detected in frame_0659_01.png
# Raphael Pace (Interviewee) is detected in frame_0660_00.png
# Raphael Pace (Interviewee) is detected in frame_0661_00.png
# Jon Mallia (Interviewer) is detected in frame_0661_01.png
# Jon Mallia (Interviewer) is detected in frame_0662_00.png
# Raphael Pace (Interviewee) is detected in frame_0662_01.png
# Raphael Pace (Interviewee) is detected in frame_0663_00.png
# Raphael Pace (Interviewee) is detected in frame_0664_00.png
# Raphael Pace (Interviewee) is detected in frame_0665_00.png
# Jon Mallia (Interviewer) is detected in frame_0666_00.png
# Raphael Pace (Interviewee) is detected in frame_0667_00.png
# Raphael Pace (Interviewee) is detected in frame_0668_00.png
# Raphael Pace (Interviewee) is detected in frame_0669_00.png
# Jon Mallia (Interviewer) is detected in frame_0670_00.png
# Raphael Pace (Interviewee) is detected in frame_0671_00.png
# Raphael Pace (Interviewee) is detected in frame_0672_00.png
# Raphael Pace (Interviewee) is detected in frame_0673_00.png
# Raphael Pace (Interviewee) is detected in frame_0674_00.png
# Jon Mallia (Interviewer) is detected in frame_0675_00.png
# Raphael Pace (Interviewee) is detected in frame_0676_00.png
# Raphael Pace (Interviewee) is detected in frame_0677_00.png
# Jon Mallia (Interviewer) is detected in frame_0678_00.png
# Raphael Pace (Interviewee) is detected in frame_0678_01.png
# Jon Mallia (Interviewer) is detected in frame_0679_00.png
# Raphael Pace (Interviewee) is detected in frame_0679_01.png
# Raphael Pace (Interviewee) is detected in frame_0680_00.png
# Jon Mallia (Interviewer) is detected in frame_0680_01.png
# Jon Mallia (Interviewer) is detected in frame_0681_00.png
# Jon Mallia (Interviewer) is detected in frame_0681_01.png
# Raphael Pace (Interviewee) is detected in frame_0682_00.png
# Jon Mallia (Interviewer) is detected in frame_0682_01.png
# Jon Mallia (Interviewer) is detected in frame_0683_00.png
# Raphael Pace (Interviewee) is detected in frame_0683_01.png
# Jon Mallia (Interviewer) is detected in frame_0684_00.png
# Raphael Pace (Interviewee) is detected in frame_0684_01.png
# Raphael Pace (Interviewee) is detected in frame_0685_00.png
# Jon Mallia (Interviewer) is detected in frame_0686_00.png
# Jon Mallia (Interviewer) is detected in frame_0687_00.png
# Raphael Pace (Interviewee) is detected in frame_0688_00.png
# Raphael Pace (Interviewee) is detected in frame_0689_00.png
# Raphael Pace (Interviewee) is detected in frame_0690_00.png
# Raphael Pace (Interviewee) is detected in frame_0691_00.png
# Raphael Pace (Interviewee) is detected in frame_0692_00.png
# Raphael Pace (Interviewee) is detected in frame_0693_00.png
# Raphael Pace (Interviewee) is detected in frame_0694_00.png
# Jon Mallia (Interviewer) is detected in frame_0694_01.png
# Raphael Pace (Interviewee) is detected in frame_0695_00.png
# Jon Mallia (Interviewer) is detected in frame_0696_00.png
# Raphael Pace (Interviewee) is detected in frame_0697_00.png
# Raphael Pace (Interviewee) is detected in frame_0698_00.png
# Jon Mallia (Interviewer) is detected in frame_0699_00.png
# Raphael Pace (Interviewee) is detected in frame_0700_00.png
# Raphael Pace (Interviewee) is detected in frame_0701_00.png
# Raphael Pace (Interviewee) is detected in frame_0702_00.png
# Raphael Pace (Interviewee) is detected in frame_0703_00.png
# Raphael Pace (Interviewee) is detected in frame_0704_00.png
# Jon Mallia (Interviewer) is detected in frame_0705_00.png
# Raphael Pace (Interviewee) is detected in frame_0706_00.png
# Raphael Pace (Interviewee) is detected in frame_0707_00.png
# Jon Mallia (Interviewer) is detected in frame_0707_01.png
# Raphael Pace (Interviewee) is detected in frame_0708_00.png
# Raphael Pace (Interviewee) is detected in frame_0709_00.png
# Raphael Pace (Interviewee) is detected in frame_0710_00.png
# Raphael Pace (Interviewee) is detected in frame_0711_00.png
# Jon Mallia (Interviewer) is detected in frame_0711_01.png
# Raphael Pace (Interviewee) is detected in frame_0712_00.png
# Jon Mallia (Interviewer) is detected in frame_0713_00.png
# Raphael Pace (Interviewee) is detected in frame_0714_00.png
# Raphael Pace (Interviewee) is detected in frame_0715_00.png
# Raphael Pace (Interviewee) is detected in frame_0716_00.png
# Raphael Pace (Interviewee) is detected in frame_0717_00.png
# Raphael Pace (Interviewee) is detected in frame_0718_00.png
# Raphael Pace (Interviewee) is detected in frame_0719_00.png
# Raphael Pace (Interviewee) is detected in frame_0720_00.png
# Raphael Pace (Interviewee) is detected in frame_0721_00.png
# Raphael Pace (Interviewee) is detected in frame_0722_00.png
# Raphael Pace (Interviewee) is detected in frame_0723_00.png
# Raphael Pace (Interviewee) is detected in frame_0724_00.png
# Jon Mallia (Interviewer) is detected in frame_0725_00.png
# Raphael Pace (Interviewee) is detected in frame_0726_00.png
# Raphael Pace (Interviewee) is detected in frame_0727_00.png
# Raphael Pace (Interviewee) is detected in frame_0728_00.png
# Raphael Pace (Interviewee) is detected in frame_0729_00.png
# Raphael Pace (Interviewee) is detected in frame_0730_00.png
# Jon Mallia (Interviewer) is detected in frame_0731_00.png
# Jon Mallia (Interviewer) is detected in frame_0732_00.png
# Raphael Pace (Interviewee) is detected in frame_0733_00.png
# Raphael Pace (Interviewee) is detected in frame_0734_00.png
# Raphael Pace (Interviewee) is detected in frame_0735_00.png
# Raphael Pace (Interviewee) is detected in frame_0736_00.png
# Raphael Pace (Interviewee) is detected in frame_0737_00.png
# Jon Mallia (Interviewer) is detected in frame_0738_00.png
# Jon Mallia (Interviewer) is detected in frame_0741_00.png
# Raphael Pace (Interviewee) is detected in frame_0742_00.png
# Raphael Pace (Interviewee) is detected in frame_0743_00.png
# Jon Mallia (Interviewer) is detected in frame_0743_01.png
# Raphael Pace (Interviewee) is detected in frame_0744_00.png
# Raphael Pace (Interviewee) is detected in frame_0745_00.png
# Jon Mallia (Interviewer) is detected in frame_0750_00.png
# Raphael Pace (Interviewee) is detected in frame_0750_01.png
# Raphael Pace (Interviewee) is detected in frame_0751_00.png
# Jon Mallia (Interviewer) is detected in frame_0752_00.png
# Raphael Pace (Interviewee) is detected in frame_0753_00.png
# Raphael Pace (Interviewee) is detected in frame_0754_00.png
# Raphael Pace (Interviewee) is detected in frame_0755_00.png
# Jon Mallia (Interviewer) is detected in frame_0755_01.png
# Raphael Pace (Interviewee) is detected in frame_0756_00.png
# Jon Mallia (Interviewer) is detected in frame_0757_00.png
# Raphael Pace (Interviewee) is detected in frame_0757_01.png
# Jon Mallia (Interviewer) is detected in frame_0758_00.png
# Raphael Pace (Interviewee) is detected in frame_0758_01.png
# Jon Mallia (Interviewer) is detected in frame_0759_00.png
# Raphael Pace (Interviewee) is detected in frame_0759_01.png
# Jon Mallia (Interviewer) is detected in frame_0760_00.png
# Raphael Pace (Interviewee) is detected in frame_0760_01.png
# Jon Mallia (Interviewer) is detected in frame_0761_00.png
# Jon Mallia (Interviewer) is detected in frame_0762_00.png
# ...
# Raphael Pace (Interviewee) is detected in frame_0848_00.png
# Raphael Pace (Interviewee) is detected in frame_0849_00.png
# Jon Mallia (Interviewer) is detected in frame_0850_00.png
# Raphael Pace (Interviewee) is detected in frame_0851_00.png
# Raphael Pace (Interviewee) is detected in frame_0852_00.png
# Raphael Pace (Interviewee) is detected in frame_0853_00.png
# Raphael Pace (Interviewee) is detected in frame_0854_00.png
# Jon Mallia (Interviewer) is detected in frame_0855_00.png
# Raphael Pace (Interviewee) is detected in frame_0855_01.png
# Raphael Pace (Interviewee) is detected in frame_0856_00.png
# Raphael Pace (Interviewee) is detected in frame_0857_00.png
# Raphael Pace (Interviewee) is detected in frame_0858_00.png
# Raphael Pace (Interviewee) is detected in frame_0859_00.png
# Jon Mallia (Interviewer) is detected in frame_0860_00.png
# Jon Mallia (Interviewer) is detected in frame_0861_00.png
# Jon Mallia (Interviewer) is detected in frame_0862_00.png
# Jon Mallia (Interviewer) is detected in frame_0863_00.png
# Jon Mallia (Interviewer) is detected in frame_0864_00.png
# Jon Mallia (Interviewer) is detected in frame_0865_00.png
# Raphael Pace (Interviewee) is detected in frame_0866_00.png
# Face not recognized in frame_0867_00.png — person not found in the database.
# Face not recognized in frame_0867_01.png — person not found in the database.
# Raphael Pace (Interviewee) is detected in frame_0868_00.png
# Raphael Pace (Interviewee) is detected in frame_0869_00.png
# Raphael Pace (Interviewee) is detected in frame_0870_00.png
# Jon Mallia (Interviewer) is detected in frame_0871_00.png
# Raphael Pace (Interviewee) is detected in frame_0871_01.png
# Raphael Pace (Interviewee) is detected in frame_0872_00.png
# Raphael Pace (Interviewee) is detected in frame_0873_00.png
# Raphael Pace (Interviewee) is detected in frame_0874_00.png
# Raphael Pace (Interviewee) is detected in frame_0875_00.png
# Jon Mallia (Interviewer) is detected in frame_0876_00.png
# Raphael Pace (Interviewee) is detected in frame_0877_00.png
# Jon Mallia (Interviewer) is detected in frame_0878_00.png
# Jon Mallia (Interviewer) is detected in frame_0879_00.png
# Raphael Pace (Interviewee) is detected in frame_0879_01.png
# Raphael Pace (Interviewee) is detected in frame_0880_00.png
# Jon Mallia (Interviewer) is detected in frame_0880_01.png
# Raphael Pace (Interviewee) is detected in frame_0881_00.png
# Jon Mallia (Interviewer) is detected in frame_0881_01.png
# Jon Mallia (Interviewer) is detected in frame_0882_00.png
# Raphael Pace (Interviewee) is detected in frame_0882_01.png
# Raphael Pace (Interviewee) is detected in frame_0883_00.png
# Jon Mallia (Interviewer) is detected in frame_0884_00.png
# Jon Mallia (Interviewer) is detected in frame_0885_00.png
# Raphael Pace (Interviewee) is detected in frame_0886_00.png
# Raphael Pace (Interviewee) is detected in frame_0887_00.png
# Raphael Pace (Interviewee) is detected in frame_0888_00.png
# Raphael Pace (Interviewee) is detected in frame_0889_00.png
# Raphael Pace (Interviewee) is detected in frame_0890_00.png
# Jon Mallia (Interviewer) is detected in frame_0890_01.png
# Jon Mallia (Interviewer) is detected in frame_0891_00.png
# Raphael Pace (Interviewee) is detected in frame_0891_01.png
# Raphael Pace (Interviewee) is detected in frame_0892_00.png
# Raphael Pace (Interviewee) is detected in frame_0893_00.png
# Raphael Pace (Interviewee) is detected in frame_0894_00.png
# Raphael Pace (Interviewee) is detected in frame_0895_00.png
# Raphael Pace (Interviewee) is detected in frame_0896_00.png
# Raphael Pace (Interviewee) is detected in frame_0897_00.png
# Raphael Pace (Interviewee) is detected in frame_0898_00.png
# Raphael Pace (Interviewee) is detected in frame_0899_00.png
# Raphael Pace (Interviewee) is detected in frame_0900_00.png
# Raphael Pace (Interviewee) is detected in frame_0901_00.png
# Jon Mallia (Interviewer) is detected in frame_0902_00.png
# Raphael Pace (Interviewee) is detected in frame_0903_00.png
# Raphael Pace (Interviewee) is detected in frame_0904_00.png
# Raphael Pace (Interviewee) is detected in frame_0905_00.png
# Raphael Pace (Interviewee) is detected in frame_0906_00.png
# Raphael Pace (Interviewee) is detected in frame_0907_00.png
# Raphael Pace (Interviewee) is detected in frame_0908_00.png
# Jon Mallia (Interviewer) is detected in frame_0909_00.png
# Raphael Pace (Interviewee) is detected in frame_0910_00.png
# Raphael Pace (Interviewee) is detected in frame_0911_00.png
# Raphael Pace (Interviewee) is detected in frame_0912_00.png
# Jon Mallia (Interviewer) is detected in frame_0913_00.png
# Jon Mallia (Interviewer) is detected in frame_0914_00.png
# Raphael Pace (Interviewee) is detected in frame_0915_00.png
# Raphael Pace (Interviewee) is detected in frame_0916_00.png
# Raphael Pace (Interviewee) is detected in frame_0917_00.png
# Raphael Pace (Interviewee) is detected in frame_0918_00.png
# Raphael Pace (Interviewee) is detected in frame_0919_00.png
# Jon Mallia (Interviewer) is detected in frame_0920_00.png
# Raphael Pace (Interviewee) is detected in frame_0921_00.png
# Raphael Pace (Interviewee) is detected in frame_0922_00.png
# Raphael Pace (Interviewee) is detected in frame_0923_00.png
# Jon Mallia (Interviewer) is detected in frame_0924_00.png
# Raphael Pace (Interviewee) is detected in frame_0925_00.png
# Raphael Pace (Interviewee) is detected in frame_0926_00.png
# Jon Mallia (Interviewer) is detected in frame_0927_00.png
# Raphael Pace (Interviewee) is detected in frame_0928_00.png
# Raphael Pace (Interviewee) is detected in frame_0929_00.png
# Raphael Pace (Interviewee) is detected in frame_0930_00.png
# Raphael Pace (Interviewee) is detected in frame_0931_00.png
# Jon Mallia (Interviewer) is detected in frame_0932_00.png
# Raphael Pace (Interviewee) is detected in frame_0933_00.png
# Raphael Pace (Interviewee) is detected in frame_0934_00.png
# Raphael Pace (Interviewee) is detected in frame_0935_00.png
# Jon Mallia (Interviewer) is detected in frame_0935_01.png
# Jon Mallia (Interviewer) is detected in frame_0936_00.png
# Jon Mallia (Interviewer) is detected in frame_0936_01.png
# Raphael Pace (Interviewee) is detected in frame_0937_00.png
# Jon Mallia (Interviewer) is detected in frame_0937_01.png
# Raphael Pace (Interviewee) is detected in frame_0938_00.png
# Jon Mallia (Interviewer) is detected in frame_0938_01.png
# Raphael Pace (Interviewee) is detected in frame_0939_00.png
# Jon Mallia (Interviewer) is detected in frame_0939_01.png
# Raphael Pace (Interviewee) is detected in frame_0940_00.png
# No face detected in frame_0940_01.png!
# Jon Mallia (Interviewer) is detected in frame_0941_00.png
# Raphael Pace (Interviewee) is detected in frame_0941_01.png
# Jon Mallia (Interviewer) is detected in frame_0942_00.png
# Raphael Pace (Interviewee) is detected in frame_0942_01.png
# Jon Mallia (Interviewer) is detected in frame_0943_00.png
# Raphael Pace (Interviewee) is detected in frame_0943_01.png
# Raphael Pace (Interviewee) is detected in frame_0944_00.png
# Jon Mallia (Interviewer) is detected in frame_0944_01.png
# Jon Mallia (Interviewer) is detected in frame_0945_00.png
# Raphael Pace (Interviewee) is detected in frame_0945_01.png
# Jon Mallia (Interviewer) is detected in frame_0946_00.png
# Raphael Pace (Interviewee) is detected in frame_0946_01.png
# Jon Mallia (Interviewer) is detected in frame_0947_00.png
# Raphael Pace (Interviewee) is detected in frame_0947_01.png
# Raphael Pace (Interviewee) is detected in frame_0948_00.png
# Raphael Pace (Interviewee) is detected in frame_0949_00.png
# Raphael Pace (Interviewee) is detected in frame_0950_00.png
# Raphael Pace (Interviewee) is detected in frame_0951_00.png
# Raphael Pace (Interviewee) is detected in frame_0952_00.png
# Raphael Pace (Interviewee) is detected in frame_0953_00.png
# Raphael Pace (Interviewee) is detected in frame_0954_00.png
# Jon Mallia (Interviewer) is detected in frame_0955_00.png
# Raphael Pace (Interviewee) is detected in frame_0956_00.png
# Raphael Pace (Interviewee) is detected in frame_0957_00.png
# Raphael Pace (Interviewee) is detected in frame_0958_00.png
# Raphael Pace (Interviewee) is detected in frame_0959_00.png
# Raphael Pace (Interviewee) is detected in frame_0960_00.png
# Jon Mallia (Interviewer) is detected in frame_0961_00.png
# Raphael Pace (Interviewee) is detected in frame_0962_00.png
# Jon Mallia (Interviewer) is detected in frame_0963_00.png
# Jon Mallia (Interviewer) is detected in frame_0964_00.png
# Raphael Pace (Interviewee) is detected in frame_0965_00.png
# Raphael Pace (Interviewee) is detected in frame_0966_00.png
# Raphael Pace (Interviewee) is detected in frame_0967_00.png
# Raphael Pace (Interviewee) is detected in frame_0968_00.png
# Raphael Pace (Interviewee) is detected in frame_0969_00.png
# Jon Mallia (Interviewer) is detected in frame_0970_00.png
# Jon Mallia (Interviewer) is detected in frame_0971_00.png
# Raphael Pace (Interviewee) is detected in frame_0972_00.png
# Jon Mallia (Interviewer) is detected in frame_0973_00.png
# Jon Mallia (Interviewer) is detected in frame_0974_00.png
# Raphael Pace (Interviewee) is detected in frame_0975_00.png
# Raphael Pace (Interviewee) is detected in frame_0976_00.png
# Jon Mallia (Interviewer) is detected in frame_0977_00.png
# Raphael Pace (Interviewee) is detected in frame_0978_00.png
# Raphael Pace (Interviewee) is detected in frame_0979_00.png
# Raphael Pace (Interviewee) is detected in frame_0980_00.png
# Raphael Pace (Interviewee) is detected in frame_0981_00.png
# Raphael Pace (Interviewee) is detected in frame_0982_00.png
# Raphael Pace (Interviewee) is detected in frame_0983_00.png
# Jon Mallia (Interviewer) is detected in frame_0984_00.png
# Jon Mallia (Interviewer) is detected in frame_0985_00.png
# Raphael Pace (Interviewee) is detected in frame_0986_00.png
# Jon Mallia (Interviewer) is detected in frame_0987_00.png
# Raphael Pace (Interviewee) is detected in frame_0988_00.png
# Raphael Pace (Interviewee) is detected in frame_0989_00.png
# Raphael Pace (Interviewee) is detected in frame_0990_00.png
# Raphael Pace (Interviewee) is detected in frame_0991_00.png
# Raphael Pace (Interviewee) is detected in frame_0992_00.png
# Jon Mallia (Interviewer) is detected in frame_0993_00.png
# Raphael Pace (Interviewee) is detected in frame_0994_00.png
# Raphael Pace (Interviewee) is detected in frame_0995_00.png
# Raphael Pace (Interviewee) is detected in frame_0996_00.png
# Raphael Pace (Interviewee) is detected in frame_0997_00.png
# Jon Mallia (Interviewer) is detected in frame_0998_00.png
# Raphael Pace (Interviewee) is detected in frame_0999_00.png
# Raphael Pace (Interviewee) is detected in frame_1000_00.png
# Raphael Pace (Interviewee) is detected in frame_1001_00.png
# Raphael Pace (Interviewee) is detected in frame_1002_00.png
# Raphael Pace (Interviewee) is detected in frame_1003_00.png
# Raphael Pace (Interviewee) is detected in frame_1004_00.png
# Raphael Pace (Interviewee) is detected in frame_1005_00.png
# Raphael Pace (Interviewee) is detected in frame_1006_00.png
# Raphael Pace (Interviewee) is detected in frame_1007_00.png
# Raphael Pace (Interviewee) is detected in frame_1008_00.png
# Raphael Pace (Interviewee) is detected in frame_1009_00.png
# Jon Mallia (Interviewer) is detected in frame_1010_00.png
# Jon Mallia (Interviewer) is detected in frame_1011_00.png
# Raphael Pace (Interviewee) is detected in frame_1012_00.png
# Raphael Pace (Interviewee) is detected in frame_1013_00.png
# Raphael Pace (Interviewee) is detected in frame_1014_00.png
# Raphael Pace (Interviewee) is detected in frame_1015_00.png
# Raphael Pace (Interviewee) is detected in frame_1016_00.png
# Jon Mallia (Interviewer) is detected in frame_1017_00.png
# Raphael Pace (Interviewee) is detected in frame_1018_00.png
# Raphael Pace (Interviewee) is detected in frame_1019_00.png
# Raphael Pace (Interviewee) is detected in frame_1020_00.png
# Raphael Pace (Interviewee) is detected in frame_1021_00.png
# Raphael Pace (Interviewee) is detected in frame_1022_00.png
# Raphael Pace (Interviewee) is detected in frame_1023_00.png
# Jon Mallia (Interviewer) is detected in frame_1024_00.png
# Jon Mallia (Interviewer) is detected in frame_1025_00.png
# Raphael Pace (Interviewee) is detected in frame_1026_00.png
# Jon Mallia (Interviewer) is detected in frame_1027_00.png
# Jon Mallia (Interviewer) is detected in frame_1028_00.png
# Jon Mallia (Interviewer) is detected in frame_1029_00.png
# Raphael Pace (Interviewee) is detected in frame_1030_00.png
# Raphael Pace (Interviewee) is detected in frame_1031_00.png
# Jon Mallia (Interviewer) is detected in frame_1032_00.png
# Raphael Pace (Interviewee) is detected in frame_1033_00.png
# Raphael Pace (Interviewee) is detected in frame_1034_00.png
# Raphael Pace (Interviewee) is detected in frame_1035_00.png
# Jon Mallia (Interviewer) is detected in frame_1035_01.png
# Jon Mallia (Interviewer) is detected in frame_1036_00.png
# Jon Mallia (Interviewer) is detected in frame_1037_00.png
# Jon Mallia (Interviewer) is detected in frame_1038_00.png
# Raphael Pace (Interviewee) is detected in frame_1039_00.png
# Raphael Pace (Interviewee) is detected in frame_1040_00.png
# Raphael Pace (Interviewee) is detected in frame_1041_00.png
# Jon Mallia (Interviewer) is detected in frame_1042_00.png
# Raphael Pace (Interviewee) is detected in frame_1043_00.png
# Jon Mallia (Interviewer) is detected in frame_1044_00.png
# Raphael Pace (Interviewee) is detected in frame_1045_00.png
# Jon Mallia (Interviewer) is detected in frame_1046_00.png
# Raphael Pace (Interviewee) is detected in frame_1047_00.png
# Jon Mallia (Interviewer) is detected in frame_1047_01.png
# Jon Mallia (Interviewer) is detected in frame_1048_00.png
# Jon Mallia (Interviewer) is detected in frame_1049_00.png
# Jon Mallia (Interviewer) is detected in frame_1050_00.png
# Jon Mallia (Interviewer) is detected in frame_1051_00.png
# Raphael Pace (Interviewee) is detected in frame_1052_00.png
# Raphael Pace (Interviewee) is detected in frame_1053_00.png
# Jon Mallia (Interviewer) is detected in frame_1054_00.png
# Raphael Pace (Interviewee) is detected in frame_1055_00.png
# Raphael Pace (Interviewee) is detected in frame_1056_00.png
# Jon Mallia (Interviewer) is detected in frame_1057_00.png
# Raphael Pace (Interviewee) is detected in frame_1058_00.png
# Raphael Pace (Interviewee) is detected in frame_1059_00.png
# Jon Mallia (Interviewer) is detected in frame_1060_00.png
# Raphael Pace (Interviewee) is detected in frame_1061_00.png
# Jon Mallia (Interviewer) is detected in frame_1062_00.png
# Jon Mallia (Interviewer) is detected in frame_1063_00.png
# Jon Mallia (Interviewer) is detected in frame_1064_00.png
# Jon Mallia (Interviewer) is detected in frame_1065_00.png
# Jon Mallia (Interviewer) is detected in frame_1066_00.png
# Raphael Pace (Interviewee) is detected in frame_1067_00.png
# Raphael Pace (Interviewee) is detected in frame_1068_00.png
# Raphael Pace (Interviewee) is detected in frame_1069_00.png
# Raphael Pace (Interviewee) is detected in frame_1070_00.png
# Jon Mallia (Interviewer) is detected in frame_1071_00.png
# Raphael Pace (Interviewee) is detected in frame_1072_00.png
# Raphael Pace (Interviewee) is detected in frame_1073_00.png
# Raphael Pace (Interviewee) is detected in frame_1074_00.png
# Raphael Pace (Interviewee) is detected in frame_1075_00.png
# Raphael Pace (Interviewee) is detected in frame_1076_00.png
# Raphael Pace (Interviewee) is detected in frame_1077_00.png
# Raphael Pace (Interviewee) is detected in frame_1078_00.png
# Raphael Pace (Interviewee) is detected in frame_1079_00.png
# Raphael Pace (Interviewee) is detected in frame_1080_00.png
# Jon Mallia (Interviewer) is detected in frame_1081_00.png
# Raphael Pace (Interviewee) is detected in frame_1082_00.png
# Raphael Pace (Interviewee) is detected in frame_1083_00.png
# Jon Mallia (Interviewer) is detected in frame_1083_01.png
# Jon Mallia (Interviewer) is detected in frame_1084_00.png
# Jon Mallia (Interviewer) is detected in frame_1085_00.png
# Jon Mallia (Interviewer) is detected in frame_1086_00.png
# Jon Mallia (Interviewer) is detected in frame_1087_00.png
# Jon Mallia (Interviewer) is detected in frame_1088_00.png
# Jon Mallia (Interviewer) is detected in frame_1089_00.png
# Jon Mallia (Interviewer) is detected in frame_1090_00.png
# Person Classification process for video_14 has finished!

# %% [markdown]
# ### Loading results

# %%
video_person_categorized = load_person_categories(chosen_video_data_path)

if 'unknown' not in video_person_categorized.keys():
    video_person_categorized['unknown'] = []

for person_category, cat_list in video_person_categorized.items():
    print(person_category, '-', cat_list)
# Out:
# interviewee - ['frame_0009_00.png', 'frame_0010_00.png', 'frame_0011_00.png', 'frame_0012_00.png', 'frame_0013_00.png', 'frame_0014_00.png', 'frame_0016_01.png', 'frame_0018_00.png', 'frame_0019_00.png', 'frame_0020_01.png', 'frame_0021_00.png', 'frame_0023_00.png', 'frame_0027_00.png', 'frame_0028_00.png', 'frame_0029_00.png', 'frame_0030_00.png', 'frame_0032_01.png', 'frame_0033_01.png', 'frame_0037_00.png', 'frame_0038_00.png', 'frame_0039_00.png', 'frame_0040_00.png', 'frame_0042_00.png', 'frame_0043_00.png', 'frame_0045_00.png', 'frame_0047_00.png', 'frame_0048_00.png', 'frame_0049_00.png', 'frame_0050_00.png', 'frame_0051_00.png', 'frame_0052_00.png', 'frame_0053_00.png', 'frame_0055_00.png', 'frame_0056_00.png', 'frame_0057_00.png', 'frame_0058_00.png', 'frame_0060_00.png', 'frame_0061_00.png', 'frame_0062_00.png', 'frame_0063_00.png', 'frame_0064_00.png', 'frame_0067_00.png', 'frame_0068_00.png', 'frame_0069_00.png', 'frame_0070_00.png', 'frame_0071_00.png', 'frame_0072_00.png', 'frame_0074_00.png', 'frame_0075_00.png', 'frame_0076_00.png', 'frame_0077_00.png', 'frame_0078_00.png', 'frame_0079_00.png', 'frame_0080_00.png', 'frame_0081_00.png', 'frame_0082_00.png', 'frame_0083_00.png', 'frame_0084_00.png', 'frame_0085_00.png', 'frame_0086_00.png', 'frame_0087_00.png', 'frame_0088_00.png', 'frame_0089_00.png', 'frame_0092_00.png', 'frame_0093_00.png', 'frame_0094_01.png', 'frame_0095_00.png', 'frame_0097_00.png', 'frame_0099_00.png', 'frame_0101_00.png', 'frame_0102_00.png', 'frame_0103_00.png', 'frame_0104_00.png', 'frame_0105_00.png', 'frame_0107_00.png', 'frame_0108_00.png', 'frame_0109_00.png', 'frame_0110_00.png', 'frame_0112_00.png', 'frame_0113_00.png', 'frame_0114_00.png', 'frame_0115_00.png', 'frame_0117_00.png', 'frame_0120_00.png', 'frame_0121_00.png', 'frame_0122_00.png', 'frame_0123_00.png', 'frame_0124_00.png', 'frame_0125_00.png', 'frame_0127_00.png', 'frame_0129_00.png', 'frame_0130_00.png', 'frame_0132_00.png', 'frame_0133_00.png', 'frame_0134_00.png', 'frame_0135_00.png', 'frame_0137_00.png', 'frame_0140_00.png', 'frame_0143_00.png', 'frame_0144_00.png', 'frame_0145_00.png', 'frame_0146_00.png', 'frame_0149_00.png', 'frame_0150_00.png', 'frame_0151_00.png', 'frame_0152_00.png', 'frame_0153_00.png', 'frame_0155_00.png', 'frame_0156_00.png', 'frame_0157_00.png', 'frame_0158_00.png', 'frame_0159_00.png', 'frame_0160_00.png', 'frame_0161_00.png', 'frame_0164_00.png', 'frame_0165_00.png', 'frame_0166_00.png', 'frame_0167_00.png', 'frame_0168_00.png', 'frame_0169_00.png', 'frame_0170_00.png', 'frame_0171_00.png', 'frame_0174_01.png', 'frame_0175_00.png', 'frame_0176_00.png', 'frame_0177_00.png', 'frame_0178_00.png', 'frame_0179_00.png', 'frame_0180_00.png', 'frame_0181_00.png', 'frame_0182_00.png', 'frame_0183_00.png', 'frame_0186_00.png', 'frame_0187_00.png', 'frame_0188_00.png', 'frame_0189_00.png', 'frame_0190_00.png', 'frame_0191_00.png', 'frame_0193_00.png', 'frame_0194_00.png', 'frame_0196_00.png', 'frame_0197_00.png', 'frame_0198_00.png', 'frame_0200_00.png', 'frame_0202_00.png', 'frame_0203_00.png', 'frame_0205_00.png', 'frame_0206_00.png', 'frame_0207_00.png', 'frame_0208_00.png', 'frame_0210_00.png', 'frame_0211_00.png', 'frame_0212_00.png', 'frame_0213_00.png', 'frame_0214_00.png', 'frame_0216_00.png', 'frame_0217_00.png', 'frame_0219_00.png', 'frame_0220_00.png', 'frame_0221_00.png', 'frame_0222_00.png', 'frame_0223_00.png', 'frame_0225_00.png', 'frame_0226_00.png', 'frame_0227_00.png', 'frame_0230_00.png', 'frame_0231_00.png', 'frame_0232_00.png', 'frame_0234_00.png', 'frame_0235_00.png', 'frame_0236_00.png', 'frame_0237_00.png', 'frame_0240_00.png', 'frame_0241_00.png', 'frame_0242_00.png', 'frame_0243_00.png', 'frame_0244_00.png', 'frame_0245_00.png', 'frame_0247_00.png', 'frame_0248_00.png', 'frame_0249_00.png', 'frame_0250_00.png', 'frame_0251_00.png', 'frame_0253_00.png', 'frame_0254_00.png', 'frame_0257_00.png', 'frame_0259_00.png', 'frame_0263_00.png', 'frame_0264_00.png', 'frame_0265_00.p ...
# interviewer - ['frame_0015_00.png', 'frame_0016_00.png', 'frame_0017_00.png', 'frame_0020_00.png', 'frame_0021_01.png', 'frame_0022_00.png', 'frame_0024_00.png', 'frame_0025_00.png', 'frame_0026_00.png', 'frame_0031_00.png', 'frame_0032_00.png', 'frame_0033_00.png', 'frame_0034_00.png', 'frame_0035_00.png', 'frame_0036_00.png', 'frame_0041_00.png', 'frame_0044_00.png', 'frame_0046_00.png', 'frame_0054_00.png', 'frame_0058_01.png', 'frame_0060_01.png', 'frame_0065_00.png', 'frame_0066_00.png', 'frame_0073_00.png', 'frame_0090_00.png', 'frame_0091_00.png', 'frame_0094_00.png', 'frame_0096_00.png', 'frame_0098_00.png', 'frame_0100_00.png', 'frame_0106_00.png', 'frame_0111_00.png', 'frame_0116_00.png', 'frame_0118_00.png', 'frame_0119_00.png', 'frame_0126_00.png', 'frame_0128_00.png', 'frame_0131_00.png', 'frame_0136_00.png', 'frame_0138_00.png', 'frame_0139_00.png', 'frame_0141_00.png', 'frame_0142_00.png', 'frame_0147_00.png', 'frame_0148_00.png', 'frame_0154_00.png', 'frame_0158_01.png', 'frame_0162_00.png', 'frame_0163_00.png', 'frame_0170_01.png', 'frame_0172_00.png', 'frame_0173_00.png', 'frame_0174_00.png', 'frame_0184_00.png', 'frame_0185_00.png', 'frame_0192_00.png', 'frame_0195_00.png', 'frame_0199_00.png', 'frame_0204_00.png', 'frame_0209_00.png', 'frame_0215_00.png', 'frame_0218_00.png', 'frame_0224_00.png', 'frame_0228_00.png', 'frame_0229_00.png', 'frame_0233_00.png', 'frame_0238_00.png', 'frame_0239_00.png', 'frame_0246_00.png', 'frame_0252_00.png', 'frame_0255_00.png', 'frame_0256_00.png', 'frame_0258_00.png', 'frame_0259_01.png', 'frame_0260_00.png', 'frame_0261_00.png', 'frame_0262_00.png', 'frame_0267_00.png', 'frame_0268_00.png', 'frame_0269_00.png', 'frame_0270_00.png', 'frame_0271_00.png', 'frame_0272_00.png', 'frame_0274_00.png', 'frame_0275_00.png', 'frame_0278_00.png', 'frame_0281_00.png', 'frame_0284_00.png', 'frame_0287_00.png', 'frame_0299_00.png', 'frame_0304_00.png', 'frame_0305_00.png', 'frame_0307_00.png', 'frame_0308_00.png', 'frame_0312_00.png', 'frame_0313_00.png', 'frame_0314_00.png', 'frame_0316_00.png', 'frame_0317_00.png', 'frame_0318_00.png', 'frame_0319_00.png', 'frame_0320_00.png', 'frame_0322_00.png', 'frame_0323_00.png', 'frame_0324_00.png', 'frame_0325_00.png', 'frame_0326_00.png', 'frame_0328_00.png', 'frame_0329_00.png', 'frame_0330_00.png', 'frame_0331_00.png', 'frame_0332_00.png', 'frame_0333_00.png', 'frame_0334_00.png', 'frame_0335_00.png', 'frame_0336_00.png', 'frame_0340_00.png', 'frame_0346_01.png', 'frame_0348_00.png', 'frame_0353_00.png', 'frame_0356_00.png', 'frame_0359_00.png', 'frame_0360_00.png', 'frame_0361_00.png', 'frame_0362_00.png', 'frame_0363_00.png', 'frame_0364_00.png', 'frame_0378_00.png', 'frame_0379_00.png', 'frame_0380_01.png', 'frame_0381_00.png', 'frame_0383_00.png', 'frame_0385_00.png', 'frame_0386_00.png', 'frame_0387_00.png', 'frame_0389_00.png', 'frame_0390_00.png', 'frame_0392_00.png', 'frame_0398_00.png', 'frame_0399_00.png', 'frame_0403_00.png', 'frame_0407_00.png', 'frame_0413_00.png', 'frame_0415_00.png', 'frame_0416_01.png', 'frame_0418_00.png', 'frame_0419_00.png', 'frame_0420_00.png', 'frame_0421_01.png', 'frame_0422_00.png', 'frame_0424_00.png', 'frame_0428_00.png', 'frame_0430_00.png', 'frame_0431_00.png', 'frame_0432_00.png', 'frame_0434_00.png', 'frame_0437_00.png', 'frame_0438_00.png', 'frame_0440_00.png', 'frame_0443_00.png', 'frame_0452_00.png', 'frame_0457_00.png', 'frame_0458_00.png', 'frame_0460_00.png', 'frame_0462_01.png', 'frame_0464_01.png', 'frame_0468_00.png', 'frame_0470_00.png', 'frame_0472_00.png', 'frame_0479_01.png', 'frame_0481_00.png', 'frame_0482_00.png', 'frame_0486_00.png', 'frame_0488_00.png', 'frame_0496_01.png', 'frame_0500_00.png', 'frame_0501_00.png', 'frame_0502_00.png', 'frame_0503_00.png', 'frame_0504_00.png', 'frame_0505_00.png', 'frame_0511_00.png', 'frame_0513_00.png', 'frame_0519_00.png', 'frame_0520_00.png', 'frame_0521_00.png', 'frame_0522_01.png', 'frame_0523_01.png', 'frame_0524_00.png', 'frame_0525_00.p ...
# unknown - ['frame_0201_00.png', 'frame_0332_01.png', 'frame_0391_01.png', 'frame_0498_00.png', 'frame_0550_00.png', 'frame_0558_01.png', 'frame_0581_00.png', 'frame_0642_00.png', 'frame_0643_01.png', 'frame_0867_00.png', 'frame_0867_01.png', 'frame_0940_01.png']

# %% [markdown]
# ## Execution of Emotion Classification

# %%
if roi_list_exists_in_file:
    if not bool(video_person_categorized):
        video_person_categorized = load_person_categories(chosen_video_data_path)
        if 'unknown' not in video_person_categorized.keys():
            video_person_categorized['unknown'] = []
        
    for snapshot_img in os.listdir(dir_chosen_full_path)[0:30]:
        if snapshot_img.endswith('.jpg') or snapshot_img.endswith('.png'):
            if snapshot_img not in video_person_categorized['unknown']:
                base_img_name = os.path.splitext(snapshot_img)[0][:-3]
                snapshot_path = os.path.join(dir_chosen_full_path, snapshot_img)
                try:
                    with suppress_stdout():
                        snapshot_encodings = DeepFace.represent(snapshot_path, detector_backend='mtcnn')
                except:
                    print(f'No face detected in {snapshot_img}!')
                    continue
                
                result = ''
                if len(snapshot_encodings) == 1:
                    emotion_displayed, emotion_probs, entropy_value = predict_emotion(snapshot_path, snapshot_img, video_emotions_categorized, backend_detector='retinaface')
                else:
                    highest_detected_confidence = -0.01
                    best_encoding = None
                    for encoding_index, encoding in enumerate(snapshot_encodings):
                        if encoding['face_confidence'] > highest_detected_confidence:
                            highest_detected_confidence = encoding['face_confidence']
                            best_encoding = encoding
                    
                    snapshot_cv = cv2.imread(snapshot_path)

                    roi_x = best_encoding['facial_area']['x']
                    roi_y = best_encoding['facial_area']['y']
                    roi_w = best_encoding['facial_area']['w']
                    roi_h = best_encoding['facial_area']['h']
                    roi_left, roi_right = roi_x, roi_x + roi_w
                    roi_top, roi_bottom = roi_y, roi_y + roi_h

                    if roi_top < 0:
                        roi_top = 0
                    
                    if roi_left < 0:
                        roi_left = 0

                    snapshot_crop = snapshot_cv[roi_top:roi_bottom, roi_left:roi_right]
                    emotion_displayed, emotion_probs, entropy_value = predict_emotion(snapshot_crop, snapshot_img, video_emotions_categorized, backend_detector='retinaface')
                arousal_val, valence_val = calculate_av(emotion_probs)
                print(f'Emotion displayed in {snapshot_img}: {emotion_displayed}')
                #print(f"Emotion Probabilties: {emotion_probs}")
                #print(f"Entropy for {snapshot_img}: {entropy_value}")
                write_emotion_detected(chosen_video_data_path, base_img_name, os.path.splitext(snapshot_img)[0], emotion_displayed.lower())
                write_emotion_probs(chosen_video_data_path, base_img_name, os.path.splitext(snapshot_img)[0], emotion_probs)
                write_emotion_entropy(chosen_video_data_path, base_img_name, os.path.splitext(snapshot_img)[0], entropy_value)
                write_av_values(chosen_video_data_path, base_img_name, os.path.splitext(snapshot_img)[0], arousal_val, valence_val)
    print(f"Emotion Classification process for {dir_chosen} has finished!")
else:
    raise Exception(f'Please ensure that all facial ROIs from {dir_chosen} have been extracted before running this!')
# Out:
# Emotion displayed in frame_0009_00.png: neutral
# Emotion displayed in frame_0010_00.png: happy
# Emotion displayed in frame_0011_00.png: sad
# Emotion displayed in frame_0012_00.png: angry
# Emotion displayed in frame_0013_00.png: sad
# Emotion displayed in frame_0014_00.png: neutral
# Emotion displayed in frame_0015_00.png: sad
# Emotion displayed in frame_0016_00.png: sad
# Emotion displayed in frame_0016_01.png: angry
# Emotion displayed in frame_0017_00.png: neutral
# Emotion displayed in frame_0018_00.png: happy
# Emotion displayed in frame_0019_00.png: neutral
# Emotion displayed in frame_0020_00.png: angry
# Emotion displayed in frame_0020_01.png: angry
# Emotion displayed in frame_0021_00.png: sad
# Emotion displayed in frame_0021_01.png: angry
# Emotion displayed in frame_0022_00.png: neutral
# Emotion displayed in frame_0023_00.png: sad
# Emotion displayed in frame_0024_00.png: sad
# Emotion displayed in frame_0025_00.png: neutral
# Emotion displayed in frame_0026_00.png: neutral
# Emotion displayed in frame_0027_00.png: angry
# Emotion displayed in frame_0028_00.png: neutral
# Emotion displayed in frame_0029_00.png: sad
# Emotion displayed in frame_0030_00.png: sad
# Emotion displayed in frame_0031_00.png: sad
# Emotion displayed in frame_0032_00.png: angry
# Emotion displayed in frame_0032_01.png: angry
# Emotion displayed in frame_0033_00.png: sad
# Emotion displayed in frame_0033_01.png: angry
# Emotion Classification process for video_14 has finished!

# %%
video_emotion_categorized = load_emotion_categories(chosen_video_data_path)

for emotion_category, cat_list in video_emotion_categorized.items():
    print(emotion_category, '-', cat_list)
# Out:
# neutral - ['frame_0009_00.png', 'frame_0014_00.png', 'frame_0017_00.png', 'frame_0019_00.png', 'frame_0022_00.png', 'frame_0025_00.png', 'frame_0026_00.png', 'frame_0028_00.png', 'frame_0034_00.png', 'frame_0035_00.png', 'frame_0036_00.png', 'frame_0037_00.png', 'frame_0039_00.png', 'frame_0043_00.png', 'frame_0044_00.png', 'frame_0053_00.png', 'frame_0056_00.png', 'frame_0057_00.png', 'frame_0058_01.png', 'frame_0062_00.png', 'frame_0066_00.png', 'frame_0068_00.png', 'frame_0073_00.png', 'frame_0075_00.png', 'frame_0078_00.png', 'frame_0080_00.png', 'frame_0086_00.png', 'frame_0089_00.png', 'frame_0091_00.png', 'frame_0092_00.png', 'frame_0093_00.png', 'frame_0098_00.png', 'frame_0102_00.png', 'frame_0105_00.png', 'frame_0106_00.png', 'frame_0109_00.png', 'frame_0110_00.png', 'frame_0112_00.png', 'frame_0113_00.png', 'frame_0117_00.png', 'frame_0120_00.png', 'frame_0124_00.png', 'frame_0125_00.png', 'frame_0127_00.png', 'frame_0129_00.png', 'frame_0130_00.png', 'frame_0131_00.png', 'frame_0132_00.png', 'frame_0133_00.png', 'frame_0134_00.png', 'frame_0135_00.png', 'frame_0137_00.png', 'frame_0140_00.png', 'frame_0142_00.png', 'frame_0152_00.png', 'frame_0153_00.png', 'frame_0155_00.png', 'frame_0156_00.png', 'frame_0160_00.png', 'frame_0161_00.png', 'frame_0162_00.png', 'frame_0163_00.png', 'frame_0167_00.png', 'frame_0170_00.png', 'frame_0178_00.png', 'frame_0182_00.png', 'frame_0185_00.png', 'frame_0188_00.png', 'frame_0189_00.png', 'frame_0190_00.png', 'frame_0193_00.png', 'frame_0206_00.png', 'frame_0207_00.png', 'frame_0208_00.png', 'frame_0210_00.png', 'frame_0211_00.png', 'frame_0226_00.png', 'frame_0232_00.png', 'frame_0233_00.png', 'frame_0236_00.png', 'frame_0241_00.png', 'frame_0245_00.png', 'frame_0246_00.png', 'frame_0255_00.png', 'frame_0259_00.png', 'frame_0260_00.png', 'frame_0268_00.png', 'frame_0270_00.png', 'frame_0271_00.png', 'frame_0274_00.png', 'frame_0278_00.png', 'frame_0282_00.png', 'frame_0287_00.png', 'frame_0294_00.png', 'frame_0295_00.png', 'frame_0296_00.png', 'frame_0298_00.png', 'frame_0302_00.png', 'frame_0305_00.png', 'frame_0307_00.png', 'frame_0308_00.png', 'frame_0309_00.png', 'frame_0314_00.png', 'frame_0316_00.png', 'frame_0317_00.png', 'frame_0318_00.png', 'frame_0321_00.png', 'frame_0323_00.png', 'frame_0324_00.png', 'frame_0331_00.png', 'frame_0332_00.png', 'frame_0334_00.png', 'frame_0335_00.png', 'frame_0337_00.png', 'frame_0340_00.png', 'frame_0341_00.png', 'frame_0342_00.png', 'frame_0347_00.png', 'frame_0348_00.png', 'frame_0355_00.png', 'frame_0357_00.png', 'frame_0363_00.png', 'frame_0364_00.png', 'frame_0376_00.png', 'frame_0377_00.png', 'frame_0379_00.png', 'frame_0381_00.png', 'frame_0383_00.png', 'frame_0386_00.png', 'frame_0387_00.png', 'frame_0388_00.png', 'frame_0395_00.png', 'frame_0399_00.png', 'frame_0403_00.png', 'frame_0405_00.png', 'frame_0408_00.png', 'frame_0409_00.png', 'frame_0410_00.png', 'frame_0412_00.png', 'frame_0413_00.png', 'frame_0415_00.png', 'frame_0418_00.png', 'frame_0419_00.png', 'frame_0420_00.png', 'frame_0421_00.png', 'frame_0424_00.png', 'frame_0431_00.png', 'frame_0432_00.png', 'frame_0433_00.png', 'frame_0434_00.png', 'frame_0435_00.png', 'frame_0437_00.png', 'frame_0440_00.png', 'frame_0441_00.png', 'frame_0451_00.png', 'frame_0452_00.png', 'frame_0457_00.png', 'frame_0462_00.png', 'frame_0465_00.png', 'frame_0467_00.png', 'frame_0468_00.png', 'frame_0470_00.png', 'frame_0472_00.png', 'frame_0477_00.png', 'frame_0482_00.png', 'frame_0500_00.png', 'frame_0503_00.png', 'frame_0507_00.png', 'frame_0512_00.png', 'frame_0513_00.png', 'frame_0519_00.png', 'frame_0520_00.png', 'frame_0525_00.png', 'frame_0529_01.png', 'frame_0532_00.png', 'frame_0537_00.png', 'frame_0540_00.png', 'frame_0543_00.png', 'frame_0547_00.png', 'frame_0549_00.png', 'frame_0551_00.png', 'frame_0552_00.png', 'frame_0554_00.png', 'frame_0558_00.png', 'frame_0559_00.png', 'frame_0565_00.png', 'frame_0567_00.png', 'frame_0585_00.png', 'frame_0587_00.png', 'frame_0592_00.png', ...
# happy - ['frame_0010_00.png', 'frame_0018_00.png', 'frame_0042_00.png', 'frame_0060_00.png', 'frame_0064_00.png', 'frame_0079_00.png', 'frame_0104_00.png', 'frame_0118_00.png', 'frame_0143_00.png', 'frame_0149_00.png', 'frame_0174_01.png', 'frame_0200_00.png', 'frame_0237_00.png', 'frame_0247_00.png', 'frame_0265_00.png', 'frame_0275_00.png', 'frame_0279_00.png', 'frame_0281_00.png', 'frame_0293_00.png', 'frame_0338_00.png', 'frame_0346_00.png', 'frame_0351_00.png', 'frame_0369_00.png', 'frame_0370_00.png', 'frame_0384_00.png', 'frame_0390_01.png', 'frame_0391_00.png', 'frame_0394_00.png', 'frame_0396_00.png', 'frame_0398_00.png', 'frame_0423_00.png', 'frame_0444_00.png', 'frame_0447_00.png', 'frame_0448_00.png', 'frame_0450_00.png', 'frame_0455_00.png', 'frame_0458_00.png', 'frame_0464_00.png', 'frame_0474_00.png', 'frame_0478_00.png', 'frame_0479_00.png', 'frame_0494_00.png', 'frame_0499_00.png', 'frame_0504_01.png', 'frame_0510_00.png', 'frame_0511_01.png', 'frame_0521_00.png', 'frame_0522_00.png', 'frame_0531_00.png', 'frame_0555_00.png', 'frame_0568_00.png', 'frame_0570_00.png', 'frame_0571_00.png', 'frame_0575_00.png', 'frame_0578_01.png', 'frame_0580_00.png', 'frame_0588_00.png', 'frame_0590_00.png', 'frame_0595_00.png', 'frame_0610_00.png', 'frame_0624_00.png', 'frame_0632_00.png', 'frame_0634_00.png', 'frame_0648_00.png', 'frame_0650_00.png', 'frame_0651_01.png', 'frame_0656_01.png', 'frame_0658_00.png', 'frame_0662_01.png', 'frame_0682_00.png', 'frame_0693_00.png', 'frame_0697_00.png', 'frame_0705_00.png', 'frame_0753_00.png', 'frame_0754_00.png', 'frame_0757_01.png', 'frame_0770_01.png', 'frame_0777_00.png', 'frame_0788_00.png', 'frame_0827_00.png', 'frame_0830_00.png', 'frame_0846_00.png', 'frame_0849_00.png', 'frame_0890_00.png', 'frame_0891_01.png', 'frame_0897_00.png', 'frame_0910_00.png', 'frame_0920_00.png', 'frame_0921_00.png', 'frame_0922_00.png', 'frame_0935_00.png', 'frame_0936_01.png', 'frame_0937_00.png', 'frame_0954_00.png', 'frame_0983_00.png', 'frame_0984_00.png', 'frame_1015_00.png', 'frame_1016_00.png', 'frame_1049_00.png', 'frame_1059_00.png', 'frame_1073_00.png', 'frame_1074_00.png', 'frame_1075_00.png']
# sad - ['frame_0011_00.png', 'frame_0013_00.png', 'frame_0015_00.png', 'frame_0016_00.png', 'frame_0021_00.png', 'frame_0023_00.png', 'frame_0024_00.png', 'frame_0029_00.png', 'frame_0030_00.png', 'frame_0031_00.png', 'frame_0033_00.png', 'frame_0040_00.png', 'frame_0041_00.png', 'frame_0048_00.png', 'frame_0051_00.png', 'frame_0052_00.png', 'frame_0055_00.png', 'frame_0063_00.png', 'frame_0065_00.png', 'frame_0069_00.png', 'frame_0070_00.png', 'frame_0072_00.png', 'frame_0074_00.png', 'frame_0076_00.png', 'frame_0081_00.png', 'frame_0082_00.png', 'frame_0083_00.png', 'frame_0084_00.png', 'frame_0087_00.png', 'frame_0088_00.png', 'frame_0096_00.png', 'frame_0097_00.png', 'frame_0099_00.png', 'frame_0100_00.png', 'frame_0107_00.png', 'frame_0111_00.png', 'frame_0116_00.png', 'frame_0119_00.png', 'frame_0122_00.png', 'frame_0123_00.png', 'frame_0126_00.png', 'frame_0128_00.png', 'frame_0136_00.png', 'frame_0139_00.png', 'frame_0144_00.png', 'frame_0145_00.png', 'frame_0147_00.png', 'frame_0150_00.png', 'frame_0151_00.png', 'frame_0154_00.png', 'frame_0157_00.png', 'frame_0164_00.png', 'frame_0165_00.png', 'frame_0166_00.png', 'frame_0168_00.png', 'frame_0171_00.png', 'frame_0172_00.png', 'frame_0173_00.png', 'frame_0174_00.png', 'frame_0175_00.png', 'frame_0176_00.png', 'frame_0177_00.png', 'frame_0179_00.png', 'frame_0180_00.png', 'frame_0184_00.png', 'frame_0186_00.png', 'frame_0191_00.png', 'frame_0195_00.png', 'frame_0196_00.png', 'frame_0197_00.png', 'frame_0198_00.png', 'frame_0203_00.png', 'frame_0204_00.png', 'frame_0205_00.png', 'frame_0215_00.png', 'frame_0216_00.png', 'frame_0217_00.png', 'frame_0218_00.png', 'frame_0221_00.png', 'frame_0224_00.png', 'frame_0225_00.png', 'frame_0227_00.png', 'frame_0228_00.png', 'frame_0235_00.png', 'frame_0238_00.png', 'frame_0239_00.png', 'frame_0240_00.png', 'frame_0242_00.png', 'frame_0243_00.png', 'frame_0248_00.png', 'frame_0251_00.png', 'frame_0254_00.png', 'frame_0256_00.png', 'frame_0257_00.png', 'frame_0261_00.png', 'frame_0262_00.png', 'frame_0264_00.png', 'frame_0266_00.png', 'frame_0267_00.png', 'frame_0269_00.png', 'frame_0273_00.png', 'frame_0276_00.png', 'frame_0277_00.png', 'frame_0280_00.png', 'frame_0286_00.png', 'frame_0290_00.png', 'frame_0292_00.png', 'frame_0297_00.png', 'frame_0299_00.png', 'frame_0300_00.png', 'frame_0301_00.png', 'frame_0303_00.png', 'frame_0304_00.png', 'frame_0312_00.png', 'frame_0313_00.png', 'frame_0315_00.png', 'frame_0319_00.png', 'frame_0320_00.png', 'frame_0325_00.png', 'frame_0326_00.png', 'frame_0328_00.png', 'frame_0330_00.png', 'frame_0333_00.png', 'frame_0336_00.png', 'frame_0339_00.png', 'frame_0344_00.png', 'frame_0346_01.png', 'frame_0349_00.png', 'frame_0350_00.png', 'frame_0352_00.png', 'frame_0353_00.png', 'frame_0354_00.png', 'frame_0356_00.png', 'frame_0358_00.png', 'frame_0359_00.png', 'frame_0360_00.png', 'frame_0361_00.png', 'frame_0365_00.png', 'frame_0372_00.png', 'frame_0373_00.png', 'frame_0374_00.png', 'frame_0375_00.png', 'frame_0390_00.png', 'frame_0392_00.png', 'frame_0397_00.png', 'frame_0401_00.png', 'frame_0402_00.png', 'frame_0406_00.png', 'frame_0407_00.png', 'frame_0411_00.png', 'frame_0416_00.png', 'frame_0417_00.png', 'frame_0421_01.png', 'frame_0426_00.png', 'frame_0427_00.png', 'frame_0436_00.png', 'frame_0439_00.png', 'frame_0442_00.png', 'frame_0443_00.png', 'frame_0446_00.png', 'frame_0449_00.png', 'frame_0459_00.png', 'frame_0460_00.png', 'frame_0461_00.png', 'frame_0466_00.png', 'frame_0469_00.png', 'frame_0475_00.png', 'frame_0476_00.png', 'frame_0479_01.png', 'frame_0480_00.png', 'frame_0481_00.png', 'frame_0485_00.png', 'frame_0486_00.png', 'frame_0487_00.png', 'frame_0488_00.png', 'frame_0488_01.png', 'frame_0489_00.png', 'frame_0490_00.png', 'frame_0491_00.png', 'frame_0492_00.png', 'frame_0493_00.png', 'frame_0495_00.png', 'frame_0501_01.png', 'frame_0502_00.png', 'frame_0505_00.png', 'frame_0506_00.png', 'frame_0511_00.png', 'frame_0523_00.png', 'frame_0523_01.png', 'frame_0525_01.png', 'fr ...
# angry - ['frame_0012_00.png', 'frame_0016_01.png', 'frame_0020_00.png', 'frame_0020_01.png', 'frame_0021_01.png', 'frame_0027_00.png', 'frame_0032_00.png', 'frame_0032_01.png', 'frame_0033_01.png', 'frame_0038_00.png', 'frame_0045_00.png', 'frame_0046_00.png', 'frame_0047_00.png', 'frame_0049_00.png', 'frame_0050_00.png', 'frame_0061_00.png', 'frame_0067_00.png', 'frame_0071_00.png', 'frame_0077_00.png', 'frame_0085_00.png', 'frame_0090_00.png', 'frame_0094_01.png', 'frame_0095_00.png', 'frame_0101_00.png', 'frame_0103_00.png', 'frame_0108_00.png', 'frame_0115_00.png', 'frame_0121_00.png', 'frame_0146_00.png', 'frame_0148_00.png', 'frame_0158_00.png', 'frame_0158_01.png', 'frame_0159_00.png', 'frame_0169_00.png', 'frame_0181_00.png', 'frame_0183_00.png', 'frame_0187_00.png', 'frame_0194_00.png', 'frame_0199_00.png', 'frame_0202_00.png', 'frame_0212_00.png', 'frame_0213_00.png', 'frame_0214_00.png', 'frame_0220_00.png', 'frame_0222_00.png', 'frame_0231_00.png', 'frame_0234_00.png', 'frame_0244_00.png', 'frame_0249_00.png', 'frame_0250_00.png', 'frame_0253_00.png', 'frame_0258_00.png', 'frame_0259_01.png', 'frame_0263_00.png', 'frame_0272_00.png', 'frame_0283_00.png', 'frame_0285_00.png', 'frame_0288_00.png', 'frame_0289_00.png', 'frame_0291_00.png', 'frame_0306_00.png', 'frame_0310_00.png', 'frame_0311_00.png', 'frame_0327_00.png', 'frame_0345_00.png', 'frame_0371_00.png', 'frame_0378_00.png', 'frame_0380_01.png', 'frame_0382_00.png', 'frame_0389_00.png', 'frame_0389_01.png', 'frame_0393_00.png', 'frame_0400_00.png', 'frame_0404_00.png', 'frame_0414_00.png', 'frame_0416_01.png', 'frame_0425_00.png', 'frame_0428_00.png', 'frame_0429_00.png', 'frame_0430_00.png', 'frame_0445_00.png', 'frame_0453_00.png', 'frame_0454_00.png', 'frame_0456_00.png', 'frame_0462_01.png', 'frame_0464_01.png', 'frame_0471_00.png', 'frame_0473_00.png', 'frame_0483_00.png', 'frame_0484_00.png', 'frame_0501_00.png', 'frame_0504_00.png', 'frame_0508_00.png', 'frame_0509_00.png', 'frame_0524_01.png', 'frame_0529_00.png', 'frame_0530_00.png', 'frame_0535_00.png', 'frame_0553_00.png', 'frame_0579_00.png', 'frame_0582_00.png', 'frame_0586_00.png', 'frame_0590_01.png', 'frame_0593_00.png', 'frame_0601_00.png', 'frame_0611_00.png', 'frame_0612_00.png', 'frame_0614_00.png', 'frame_0626_00.png', 'frame_0631_00.png', 'frame_0633_00.png', 'frame_0644_00.png', 'frame_0646_00.png', 'frame_0647_00.png', 'frame_0653_00.png', 'frame_0654_00.png', 'frame_0659_01.png', 'frame_0663_00.png', 'frame_0664_00.png', 'frame_0668_00.png', 'frame_0673_00.png', 'frame_0678_00.png', 'frame_0680_01.png', 'frame_0681_01.png', 'frame_0683_00.png', 'frame_0684_01.png', 'frame_0694_01.png', 'frame_0706_00.png', 'frame_0709_00.png', 'frame_0712_00.png', 'frame_0715_00.png', 'frame_0719_00.png', 'frame_0733_00.png', 'frame_0743_01.png', 'frame_0745_00.png', 'frame_0751_00.png', 'frame_0752_00.png', 'frame_0757_00.png', 'frame_0763_01.png', 'frame_0766_00.png', 'frame_0766_01.png', 'frame_0768_00.png', 'frame_0775_00.png', 'frame_0782_00.png', 'frame_0784_00.png', 'frame_0789_00.png', 'frame_0789_01.png', 'frame_0790_01.png', 'frame_0791_01.png', 'frame_0795_00.png', 'frame_0797_01.png', 'frame_0813_00.png', 'frame_0815_00.png', 'frame_0820_00.png', 'frame_0824_00.png', 'frame_0825_00.png', 'frame_0837_00.png', 'frame_0844_00.png', 'frame_0852_00.png', 'frame_0860_00.png', 'frame_0863_00.png', 'frame_0866_00.png', 'frame_0870_00.png', 'frame_0871_00.png', 'frame_0880_01.png', 'frame_0881_01.png', 'frame_0886_00.png', 'frame_0887_00.png', 'frame_0888_00.png', 'frame_0889_00.png', 'frame_0893_00.png', 'frame_0894_00.png', 'frame_0901_00.png', 'frame_0905_00.png', 'frame_0907_00.png', 'frame_0917_00.png', 'frame_0918_00.png', 'frame_0934_00.png', 'frame_0937_01.png', 'frame_0940_00.png', 'frame_0941_00.png', 'frame_0941_01.png', 'frame_0942_00.png', 'frame_0945_01.png', 'frame_0951_00.png', 'frame_0952_00.png', 'frame_0959_00.png', 'frame_0963_00.png', 'frame_0968_00.png', 'frame_0973_00.png', ' ...
# fear - ['frame_0054_00.png', 'frame_0058_00.png', 'frame_0060_01.png', 'frame_0094_00.png', 'frame_0114_00.png', 'frame_0138_00.png', 'frame_0141_00.png', 'frame_0170_01.png', 'frame_0192_00.png', 'frame_0209_00.png', 'frame_0219_00.png', 'frame_0223_00.png', 'frame_0229_00.png', 'frame_0230_00.png', 'frame_0252_00.png', 'frame_0284_00.png', 'frame_0322_00.png', 'frame_0329_00.png', 'frame_0343_00.png', 'frame_0362_00.png', 'frame_0378_01.png', 'frame_0380_00.png', 'frame_0385_00.png', 'frame_0422_00.png', 'frame_0438_00.png', 'frame_0522_01.png', 'frame_0524_00.png', 'frame_0527_00.png', 'frame_0528_00.png', 'frame_0536_00.png', 'frame_0539_00.png', 'frame_0557_00.png', 'frame_0591_00.png', 'frame_0616_00.png', 'frame_0632_01.png', 'frame_0638_00.png', 'frame_0641_00.png', 'frame_0654_01.png', 'frame_0655_00.png', 'frame_0656_00.png', 'frame_0661_00.png', 'frame_0667_00.png', 'frame_0669_00.png', 'frame_0675_00.png', 'frame_0679_01.png', 'frame_0680_00.png', 'frame_0681_00.png', 'frame_0699_00.png', 'frame_0707_01.png', 'frame_0755_01.png', 'frame_0758_00.png', 'frame_0785_00.png', 'frame_0798_01.png', 'frame_0900_00.png', 'frame_0947_01.png', 'frame_1036_00.png', 'frame_1083_00.png']
# surprise - ['frame_0496_01.png', 'frame_0643_00.png']
