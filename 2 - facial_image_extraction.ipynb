# %% [markdown]
# # Import packages

# %%
import os
import json
import cv2
import time
import datetime
import shutil   # ONLY USED FOR CLEARING EXISTING FRAMES
from common_functionality import *
from deepface import DeepFace
import face_recognition, face_rec
import numpy as np
# Out:
# WARNING:tensorflow:From c:\Users\mvass\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Frame Extraction

# %%
def create_json_file(file_path):
    with open(file_path, 'w') as f:
        f.write(json.dumps({}))

# %%
def reset_frames_list(file_path):
    with open(file_path, 'r+') as f:
        processed_data = json.load(f)
        if 'frames_list' in processed_data.keys():
            processed_data['frames_list'].clear()
            print(processed_data)
        
        f.seek(0)
        json.dump(processed_data, f, indent=4)
        f.truncate()

# %%
def update_json_content(file_path, pic_dict):
    with open(file_path, 'r+') as f:
        processed_data = json.load(f)
        if 'frames_list' not in processed_data.keys():
            processed_data['frames_list'] = []
        
        processed_data['frames_list'].append(pic_dict)
        f.seek(0)
        json.dump(processed_data, f, indent=4)
        f.truncate()

# %%
videos_dir = 'videos_db'
imgs_dir = 'vid_frames'
data_folder = 'data'
video_data_folder = 'video_data'
full_vid_data_path = os.path.join(data_folder, video_data_folder)

# %%
#NOTE: ONLY TO BE USED TO PROCESS THE VIDEOS DONE BY MARK LAWRENCE
videos_dir = 'videos_db_ml'
imgs_dir = 'vid_frames_ml'
data_folder = 'data'
video_data_folder = 'video_data_ml'
full_vid_data_path = os.path.join(data_folder, video_data_folder)

# %%
if not os.path.exists(full_vid_data_path):
    os.mkdir(full_vid_data_path)

# %%
frames_subDirs = []

print('List of available of videos with extracted frames:')
for root, dirs, files in os.walk(videos_dir, topdown=True):
    for vid in files:
        if vid.endswith('.mp4'):
            frames_subDirs.append(vid)

videos_sorted = sorted(frames_subDirs, key=lambda x: int(x.split('_')[-1].split('.')[0]))

print(videos_sorted)
# Out:
# List of available of videos with extracted frames:
# ['video_1.mp4', 'video_2.mp4']

# %%
seconds_between_skips = 10

for video_name in videos_sorted:
    if video_name.endswith('mp4'):
        video_data_path = os.path.join(full_vid_data_path, f'{os.path.splitext(video_name)[0]}.json')
        if not os.path.exists(video_data_path):
            create_json_file(video_data_path)
        else:
            reset_frames_list(video_data_path)
        video_path = f'{videos_dir}/{video_name}'
        #_, video_name = video_path.split('/')
        cap = cv2.VideoCapture(video_path)
        fps = cap.get(cv2.CAP_PROP_FPS)
        total_frames = cap.get(cv2.CAP_PROP_FRAME_COUNT)
        duration_in_seconds = total_frames // fps
        #print(duration_in_seconds)
        #print(fps)

        frame_interval = int(fps * seconds_between_skips)

        video_imgs_path = f'{imgs_dir}/{video_name[:-4]}'

        if not os.path.exists(video_imgs_path):
            os.makedirs(video_imgs_path)
        else:
            if len(os.listdir(video_imgs_path)) > 0:
                clear_folder(video_imgs_path)

        print("Processing "+str(video_name))
        start = time.time()

        start_timestamp_seconds = 75
        frame_count = 1

        # Set the position in milliseconds to the next timestamp
        cap.set(cv2.CAP_PROP_POS_MSEC, start_timestamp_seconds * 1000)
        new_ts_dt = datetime.timedelta(seconds=start_timestamp_seconds)
        while True:
            
            ret, frame = cap.read()
            if not ret:
                break
            else:
                # Save the frame as an image
                saved_frame_count = frame_count-1
                new_timestamp = (start_timestamp_seconds + (seconds_between_skips * frame_count))
                frame_filename = os.path.join(video_imgs_path, f"frame_{saved_frame_count:04d}.png")
                cv2.imwrite(frame_filename, frame)
                print(f"Exported frame {frame_count} at {new_ts_dt}")

                # Write frame number and timestamp to JSON file
                frame_dict = {'frame_num': f"frame_{saved_frame_count:04d}", 'frame_timestamp': str(new_ts_dt)}
                #print(frame_dict)
                update_json_content(video_data_path, frame_dict)

                # Update timestamp
                new_ts_dt = datetime.timedelta(seconds=new_timestamp)
                #print(f"Exported frame {frame_count} at {new_timestamp // (60*60):02d}:{new_timestamp // 60:02d}:{new_timestamp % 60:02d}")

                # Skip the desired number of frames
                cap.set(cv2.CAP_PROP_POS_MSEC, new_timestamp * 1000)
                frame_count += 1


        end = time.time()
        print("Video "+str(video_name)+" has been processed!")

        seconds = end - start
        print (f"Time taken : {seconds} seconds")
        print("----------------------------------------------------")

        cap.release()
    #break

cv2.destroyAllWindows()

print(f"All frames extracted from the videos in the directory \"{videos_dir}\" can be found in the directory \"{imgs_dir}\"")
# Out:
# Folder cleared
# Processing video_2.mp4
# Exported frame 1 at 0:01:15
# Exported frame 2 at 0:01:25
# Exported frame 3 at 0:01:35
# Exported frame 4 at 0:01:45
# Exported frame 5 at 0:01:55
# Exported frame 6 at 0:02:05
# Exported frame 7 at 0:02:15
# Exported frame 8 at 0:02:25
# Exported frame 9 at 0:02:35
# Exported frame 10 at 0:02:45
# Exported frame 11 at 0:02:55
# Exported frame 12 at 0:03:05
# Exported frame 13 at 0:03:15
# Exported frame 14 at 0:03:25
# Exported frame 15 at 0:03:35
# Exported frame 16 at 0:03:45
# Exported frame 17 at 0:03:55
# Exported frame 18 at 0:04:05
# Exported frame 19 at 0:04:15
# Exported frame 20 at 0:04:25
# Exported frame 21 at 0:04:35
# Exported frame 22 at 0:04:45
# Exported frame 23 at 0:04:55
# Exported frame 24 at 0:05:05
# Exported frame 25 at 0:05:15
# Exported frame 26 at 0:05:25
# Exported frame 27 at 0:05:35
# Exported frame 28 at 0:05:45
# Exported frame 29 at 0:05:55
# Exported frame 30 at 0:06:05
# Exported frame 31 at 0:06:15
# Exported frame 32 at 0:06:25
# Exported frame 33 at 0:06:35
# Exported frame 34 at 0:06:45
# Exported frame 35 at 0:06:55
# Exported frame 36 at 0:07:05
# Exported frame 37 at 0:07:15
# Exported frame 38 at 0:07:25
# Exported frame 39 at 0:07:35
# Exported frame 40 at 0:07:45
# Exported frame 41 at 0:07:55
# Exported frame 42 at 0:08:05
# Exported frame 43 at 0:08:15
# Exported frame 44 at 0:08:25
# Exported frame 45 at 0:08:35
# Exported frame 46 at 0:08:45
# Exported frame 47 at 0:08:55
# Exported frame 48 at 0:09:05
# Exported frame 49 at 0:09:15
# Exported frame 50 at 0:09:25
# Exported frame 51 at 0:09:35
# Exported frame 52 at 0:09:45
# Exported frame 53 at 0:09:55
# Exported frame 54 at 0:10:05
# Exported frame 55 at 0:10:15
# Exported frame 56 at 0:10:25
# Exported frame 57 at 0:10:35
# Exported frame 58 at 0:10:45
# Exported frame 59 at 0:10:55
# Exported frame 60 at 0:11:05
# Exported frame 61 at 0:11:15
# Exported frame 62 at 0:11:25
# Exported frame 63 at 0:11:35
# Exported frame 64 at 0:11:45
# Exported frame 65 at 0:11:55
# Exported frame 66 at 0:12:05
# Exported frame 67 at 0:12:15
# Exported frame 68 at 0:12:25
# Exported frame 69 at 0:12:35
# Exported frame 70 at 0:12:45
# Exported frame 71 at 0:12:55
# Exported frame 72 at 0:13:05
# Exported frame 73 at 0:13:15
# Exported frame 74 at 0:13:25
# Exported frame 75 at 0:13:35
# Exported frame 76 at 0:13:45
# Exported frame 77 at 0:13:55
# Exported frame 78 at 0:14:05
# Exported frame 79 at 0:14:15
# Exported frame 80 at 0:14:25
# Exported frame 81 at 0:14:35
# Exported frame 82 at 0:14:45
# Exported frame 83 at 0:14:55
# Exported frame 84 at 0:15:05
# Exported frame 85 at 0:15:15
# Exported frame 86 at 0:15:25
# Exported frame 87 at 0:15:35
# Exported frame 88 at 0:15:45
# Exported frame 89 at 0:15:55
# Exported frame 90 at 0:16:05
# Exported frame 91 at 0:16:15
# Exported frame 92 at 0:16:25
# Exported frame 93 at 0:16:35
# Exported frame 94 at 0:16:45
# Exported frame 95 at 0:16:55
# Exported frame 96 at 0:17:05
# Exported frame 97 at 0:17:15
# Exported frame 98 at 0:17:25
# Exported frame 99 at 0:17:35
# Exported frame 100 at 0:17:45
# Exported frame 101 at 0:17:55
# Exported frame 102 at 0:18:05
# Exported frame 103 at 0:18:15
# Exported frame 104 at 0:18:25
# Exported frame 105 at 0:18:35
# Exported frame 106 at 0:18:45
# Exported frame 107 at 0:18:55
# Exported frame 108 at 0:19:05
# Exported frame 109 at 0:19:15
# Exported frame 110 at 0:19:25
# Exported frame 111 at 0:19:35
# Exported frame 112 at 0:19:45
# Exported frame 113 at 0:19:55
# Exported frame 114 at 0:20:05
# Exported frame 115 at 0:20:15
# Exported frame 116 at 0:20:25
# Exported frame 117 at 0:20:35
# Exported frame 118 at 0:20:45
# Exported frame 119 at 0:20:55
# Exported frame 120 at 0:21:05
# Exported frame 121 at 0:21:15
# Exported frame 122 at 0:21:25
# Exported frame 123 at 0:21:35
# Exported frame 124 at 0:21:45
# Exported frame 125 at 0:21:55
# Exported frame 126 at 0:22:05
# Exported frame 127 at 0:22:15
# Exported frame 128 at 0:22:25
# Exported frame 129 at 0:22:35
# Exported frame 130 at 0:22:45
# Exported frame 131 at 0:22:55
# Exported frame 132 at 0:23:05
# Exported frame 133 at 0:23:15
# Exported frame 134 at 0:23:25
# Exported frame 135 at 0:23:35
# Exported frame 136 at 0:23:45
# Exported frame 137 at 0:23:55
# Exported frame 138 at 0:24:05
# Exported frame 139 at 0:24:15
# Exported frame 140 at 0:24:25
# Exported frame 141 at 0:24:35
# Exported frame 142 at 0:24:45
# Exported frame 143 at 0:24:55
# Exported frame 144 at 0:25:05
# Exported frame 145 at 0:25:15
# Exported frame 146 at 0:25:25
# Exported frame 147 at 0:25:35
# Exported frame 148 at 0:25:45
# Exported frame 149 at 0:25:55
# Exported frame 150 at 0:26:05
# Exported frame 151 at 0:26:15
# Exported frame 152 at 0:26:25
# Exported frame 153 at 0:26:35
# Exported frame 154 at 0:26:45
# Exported frame 155 at 0:26:55
# Exported frame 156 at 0:27:05
# Exported frame 157 at 0:27:15
# Exported frame 158 at 0:27:25
# Exported frame 159 at 0:27:35
# Exported frame 160 at 0:27:45
# Exported frame 161 at 0:27:55
# Exported frame 162 at 0:28:05
# Exported frame 163 at 0:28:15
# Exported frame 164 at 0:28:25
# Exported frame 165 at 0:28:35
# Exported frame 166 at 0:28:45
# Exported frame 167 at 0:28:55
# Exported frame 168 at 0:29:05
# Exported frame 169 at 0:29:15
# Exported frame 170 at 0:29:25
# Exported frame 171 at 0:29:35
# Exported frame 172 at 0:29:45
# Exported frame 173 at 0:29:55
# Exported frame 174 at 0:30:05
# Exported frame 175 at 0:30:15
# Exported frame 176 at 0:30:25
# Exported frame 177 at 0:30:35
# Exported frame 178 at 0:30:45
# Exported frame 179 at 0:30:55
# Exported frame 180 at 0:31:05
# Exported frame 181 at 0:31:15
# Exported frame 182 at 0:31:25
# Exported frame 183 at 0:31:35
# Exported frame 184 at 0:31:45
# Exported frame 185 at 0:31:55
# Exported frame 186 at 0:32:05
# Exported frame 187 at 0:32:15
# Exported frame 188 at 0:32:25
# Exported frame 189 at 0:32:35
# Exported frame 190 at 0:32:45
# Exported frame 191 at 0:32:55
# Exported frame 192 at 0:33:05
# Exported frame 193 at 0:33:15
# Exported frame 194 at 0:33:25
# Exported frame 195 at 0:33:35
# Exported frame 196 at 0:33:45
# Exported frame 197 at 0:33:55
# Exported frame 198 at 0:34:05
# Exported frame 199 at 0:34:15
# Exported frame 200 at 0:34:25
# Exported frame 201 at 0:34:35
# Exported frame 202 at 0:34:45
# Exported frame 203 at 0:34:55
# Exported frame 204 at 0:35:05
# Exported frame 205 at 0:35:15
# Exported frame 206 at 0:35:25
# Exported frame 207 at 0:35:35
# Exported frame 208 at 0:35:45
# Exported frame 209 at 0:35:55
# Exported frame 210 at 0:36:05
# Exported frame 211 at 0:36:15
# Exported frame 212 at 0:36:25
# Exported frame 213 at 0:36:35
# Exported frame 214 at 0:36:45
# Exported frame 215 at 0:36:55
# Exported frame 216 at 0:37:05
# Exported frame 217 at 0:37:15
# Exported frame 218 at 0:37:25
# Exported frame 219 at 0:37:35
# Exported frame 220 at 0:37:45
# Exported frame 221 at 0:37:55
# Exported frame 222 at 0:38:05
# Exported frame 223 at 0:38:15
# Exported frame 224 at 0:38:25
# Exported frame 225 at 0:38:35
# Exported frame 226 at 0:38:45
# Exported frame 227 at 0:38:55
# Exported frame 228 at 0:39:05
# Exported frame 229 at 0:39:15
# Exported frame 230 at 0:39:25
# Exported frame 231 at 0:39:35
# Exported frame 232 at 0:39:45
# Exported frame 233 at 0:39:55
# Exported frame 234 at 0:40:05
# Exported frame 235 at 0:40:15
# Exported frame 236 at 0:40:25
# Exported frame 237 at 0:40:35
# Exported frame 238 at 0:40:45
# Exported frame 239 at 0:40:55
# Exported frame 240 at 0:41:05
# Exported frame 241 at 0:41:15
# Exported frame 242 at 0:41:25
# Exported frame 243 at 0:41:35
# Exported frame 244 at 0:41:45
# Exported frame 245 at 0:41:55
# Exported frame 246 at 0:42:05
# Exported frame 247 at 0:42:15
# Exported frame 248 at 0:42:25
# Exported frame 249 at 0:42:35
# Exported frame 250 at 0:42:45
# Exported frame 251 at 0:42:55
# Exported frame 252 at 0:43:05
# Exported frame 253 at 0:43:15
# Exported frame 254 at 0:43:25
# Exported frame 255 at 0:43:35
# Exported frame 256 at 0:43:45
# Exported frame 257 at 0:43:55
# Exported frame 258 at 0:44:05
# Exported frame 259 at 0:44:15
# Exported frame 260 at 0:44:25
# Exported frame 261 at 0:44:35
# Exported frame 262 at 0:44:45
# Exported frame 263 at 0:44:55
# Exported frame 264 at 0:45:05
# Exported frame 265 at 0:45:15
# Exported frame 266 at 0:45:25
# Exported frame 267 at 0:45:35
# Exported frame 268 at 0:45:45
# Exported frame 269 at 0:45:55
# Exported frame 270 at 0:46:05
# Exported frame 271 at 0:46:15
# Exported frame 272 at 0:46:25
# Exported frame 273 at 0:46:35
# Exported frame 274 at 0:46:45
# Exported frame 275 at 0:46:55
# Exported frame 276 at 0:47:05
# Exported frame 277 at 0:47:15
# Exported frame 278 at 0:47:25
# Exported frame 279 at 0:47:35
# Exported frame 280 at 0:47:45
# Exported frame 281 at 0:47:55
# Exported frame 282 at 0:48:05
# Exported frame 283 at 0:48:15
# Exported frame 284 at 0:48:25
# Exported frame 285 at 0:48:35
# Exported frame 286 at 0:48:45
# Exported frame 287 at 0:48:55
# Exported frame 288 at 0:49:05
# Exported frame 289 at 0:49:15
# Exported frame 290 at 0:49:25
# Exported frame 291 at 0:49:35
# Exported frame 292 at 0:49:45
# Exported frame 293 at 0:49:55
# Exported frame 294 at 0:50:05
# Exported frame 295 at 0:50:15
# Exported frame 296 at 0:50:25
# Exported frame 297 at 0:50:35
# Exported frame 298 at 0:50:45
# Exported frame 299 at 0:50:55
# Exported frame 300 at 0:51:05
# Exported frame 301 at 0:51:15
# Exported frame 302 at 0:51:25
# Exported frame 303 at 0:51:35
# Exported frame 304 at 0:51:45
# Exported frame 305 at 0:51:55
# Exported frame 306 at 0:52:05
# Exported frame 307 at 0:52:15
# Exported frame 308 at 0:52:25
# Exported frame 309 at 0:52:35
# Exported frame 310 at 0:52:45
# Exported frame 311 at 0:52:55
# Exported frame 312 at 0:53:05
# Exported frame 313 at 0:53:15
# Exported frame 314 at 0:53:25
# Exported frame 315 at 0:53:35
# Exported frame 316 at 0:53:45
# Exported frame 317 at 0:53:55
# Exported frame 318 at 0:54:05
# Exported frame 319 at 0:54:15
# Exported frame 320 at 0:54:25
# Exported frame 321 at 0:54:35
# Exported frame 322 at 0:54:45
# Exported frame 323 at 0:54:55
# Exported frame 324 at 0:55:05
# Exported frame 325 at 0:55:15
# Exported frame 326 at 0:55:25
# Exported frame 327 at 0:55:35
# Exported frame 328 at 0:55:45
# Exported frame 329 at 0:55:55
# Exported frame 330 at 0:56:05
# Exported frame 331 at 0:56:15
# Exported frame 332 at 0:56:25
# Exported frame 333 at 0:56:35
# Exported frame 334 at 0:56:45
# Exported frame 335 at 0:56:55
# Exported frame 336 at 0:57:05
# Exported frame 337 at 0:57:15
# Exported frame 338 at 0:57:25
# Exported frame 339 at 0:57:35
# Exported frame 340 at 0:57:45
# Exported frame 341 at 0:57:55
# Exported frame 342 at 0:58:05
# Exported frame 343 at 0:58:15
# Exported frame 344 at 0:58:25
# Exported frame 345 at 0:58:35
# Exported frame 346 at 0:58:45
# Exported frame 347 at 0:58:55
# Exported frame 348 at 0:59:05
# Exported frame 349 at 0:59:15
# Exported frame 350 at 0:59:25
# Exported frame 351 at 0:59:35
# Exported frame 352 at 0:59:45
# Exported frame 353 at 0:59:55
# Exported frame 354 at 1:00:05
# Exported frame 355 at 1:00:15
# Exported frame 356 at 1:00:25
# Exported frame 357 at 1:00:35
# Exported frame 358 at 1:00:45
# Exported frame 359 at 1:00:55
# Exported frame 360 at 1:01:05
# Exported frame 361 at 1:01:15
# Exported frame 362 at 1:01:25
# Exported frame 363 at 1:01:35
# Exported frame 364 at 1:01:45
# Exported frame 365 at 1:01:55
# Exported frame 366 at 1:02:05
# Exported frame 367 at 1:02:15
# Exported frame 368 at 1:02:25
# Exported frame 369 at 1:02:35
# Exported frame 370 at 1:02:45
# Exported frame 371 at 1:02:55
# Exported frame 372 at 1:03:05
# Exported frame 373 at 1:03:15
# Exported frame 374 at 1:03:25
# Exported frame 375 at 1:03:35
# Exported frame 376 at 1:03:45
# Exported frame 377 at 1:03:55
# Exported frame 378 at 1:04:05
# Exported frame 379 at 1:04:15
# Exported frame 380 at 1:04:25
# Exported frame 381 at 1:04:35
# Exported frame 382 at 1:04:45
# Exported frame 383 at 1:04:55
# Exported frame 384 at 1:05:05
# Exported frame 385 at 1:05:15
# Exported frame 386 at 1:05:25
# Exported frame 387 at 1:05:35
# Exported frame 388 at 1:05:45
# Exported frame 389 at 1:05:55
# Exported frame 390 at 1:06:05
# Exported frame 391 at 1:06:15
# Exported frame 392 at 1:06:25
# Exported frame 393 at 1:06:35
# Exported frame 394 at 1:06:45
# Exported frame 395 at 1:06:55
# Exported frame 396 at 1:07:05
# Exported frame 397 at 1:07:15
# Exported frame 398 at 1:07:25
# Exported frame 399 at 1:07:35
# Exported frame 400 at 1:07:45
# Exported frame 401 at 1:07:55
# Exported frame 402 at 1:08:05
# Exported frame 403 at 1:08:15
# Exported frame 404 at 1:08:25
# Exported frame 405 at 1:08:35
# Exported frame 406 at 1:08:45
# Exported frame 407 at 1:08:55
# Exported frame 408 at 1:09:05
# Exported frame 409 at 1:09:15
# Exported frame 410 at 1:09:25
# Exported frame 411 at 1:09:35
# Exported frame 412 at 1:09:45
# Exported frame 413 at 1:09:55
# Exported frame 414 at 1:10:05
# Exported frame 415 at 1:10:15
# Exported frame 416 at 1:10:25
# Exported frame 417 at 1:10:35
# Exported frame 418 at 1:10:45
# Exported frame 419 at 1:10:55
# Exported frame 420 at 1:11:05
# Exported frame 421 at 1:11:15
# Exported frame 422 at 1:11:25
# Exported frame 423 at 1:11:35
# Exported frame 424 at 1:11:45
# Exported frame 425 at 1:11:55
# Exported frame 426 at 1:12:05
# Exported frame 427 at 1:12:15
# Exported frame 428 at 1:12:25
# Exported frame 429 at 1:12:35
# Exported frame 430 at 1:12:45
# Exported frame 431 at 1:12:55
# Exported frame 432 at 1:13:05
# Exported frame 433 at 1:13:15
# Exported frame 434 at 1:13:25
# Exported frame 435 at 1:13:35
# Exported frame 436 at 1:13:45
# Exported frame 437 at 1:13:55
# Exported frame 438 at 1:14:05
# Exported frame 439 at 1:14:15
# Exported frame 440 at 1:14:25
# Exported frame 441 at 1:14:35
# Exported frame 442 at 1:14:45
# Exported frame 443 at 1:14:55
# Exported frame 444 at 1:15:05
# Exported frame 445 at 1:15:15
# Exported frame 446 at 1:15:25
# Exported frame 447 at 1:15:35
# Exported frame 448 at 1:15:45
# Exported frame 449 at 1:15:55
# Exported frame 450 at 1:16:05
# Exported frame 451 at 1:16:15
# Exported frame 452 at 1:16:25
# Exported frame 453 at 1:16:35
# Exported frame 454 at 1:16:45
# Exported frame 455 at 1:16:55
# Exported frame 456 at 1:17:05
# Exported frame 457 at 1:17:15
# Exported frame 458 at 1:17:25
# Exported frame 459 at 1:17:35
# Exported frame 460 at 1:17:45
# Exported frame 461 at 1:17:55
# Exported frame 462 at 1:18:05
# Exported frame 463 at 1:18:15
# Exported frame 464 at 1:18:25
# Exported frame 465 at 1:18:35
# Exported frame 466 at 1:18:45
# Exported frame 467 at 1:18:55
# Exported frame 468 at 1:19:05
# Exported frame 469 at 1:19:15
# Exported frame 470 at 1:19:25
# Exported frame 471 at 1:19:35
# Exported frame 472 at 1:19:45
# Exported frame 473 at 1:19:55
# Exported frame 474 at 1:20:05
# Exported frame 475 at 1:20:15
# Exported frame 476 at 1:20:25
# Exported frame 477 at 1:20:35
# Exported frame 478 at 1:20:45
# Exported frame 479 at 1:20:55
# Exported frame 480 at 1:21:05
# Exported frame 481 at 1:21:15
# Exported frame 482 at 1:21:25
# Exported frame 483 at 1:21:35
# Exported frame 484 at 1:21:45
# Exported frame 485 at 1:21:55
# Exported frame 486 at 1:22:05
# Exported frame 487 at 1:22:15
# Exported frame 488 at 1:22:25
# Exported frame 489 at 1:22:35
# Exported frame 490 at 1:22:45
# Exported frame 491 at 1:22:55
# Exported frame 492 at 1:23:05
# Exported frame 493 at 1:23:15
# Exported frame 494 at 1:23:25
# Exported frame 495 at 1:23:35
# Exported frame 496 at 1:23:45
# Exported frame 497 at 1:23:55
# Exported frame 498 at 1:24:05
# Exported frame 499 at 1:24:15
# Exported frame 500 at 1:24:25
# Exported frame 501 at 1:24:35
# Exported frame 502 at 1:24:45
# Exported frame 503 at 1:24:55
# Exported frame 504 at 1:25:05
# Exported frame 505 at 1:25:15
# Exported frame 506 at 1:25:25
# Exported frame 507 at 1:25:35
# Exported frame 508 at 1:25:45
# Exported frame 509 at 1:25:55
# Exported frame 510 at 1:26:05
# Exported frame 511 at 1:26:15
# Exported frame 512 at 1:26:25
# Exported frame 513 at 1:26:35
# Exported frame 514 at 1:26:45
# Exported frame 515 at 1:26:55
# Exported frame 516 at 1:27:05
# Exported frame 517 at 1:27:15
# Exported frame 518 at 1:27:25
# Exported frame 519 at 1:27:35
# Exported frame 520 at 1:27:45
# Exported frame 521 at 1:27:55
# Exported frame 522 at 1:28:05
# Exported frame 523 at 1:28:15
# Exported frame 524 at 1:28:25
# Exported frame 525 at 1:28:35
# Exported frame 526 at 1:28:45
# Exported frame 527 at 1:28:55
# Exported frame 528 at 1:29:05
# Exported frame 529 at 1:29:15
# Exported frame 530 at 1:29:25
# Exported frame 531 at 1:29:35
# Exported frame 532 at 1:29:45
# Exported frame 533 at 1:29:55
# Exported frame 534 at 1:30:05
# Exported frame 535 at 1:30:15
# Exported frame 536 at 1:30:25
# Exported frame 537 at 1:30:35
# Exported frame 538 at 1:30:45
# Exported frame 539 at 1:30:55
# Exported frame 540 at 1:31:05
# Exported frame 541 at 1:31:15
# Exported frame 542 at 1:31:25
# Exported frame 543 at 1:31:35
# Exported frame 544 at 1:31:45
# Exported frame 545 at 1:31:55
# Exported frame 546 at 1:32:05
# Exported frame 547 at 1:32:15
# Exported frame 548 at 1:32:25
# Exported frame 549 at 1:32:35
# Exported frame 550 at 1:32:45
# Exported frame 551 at 1:32:55
# Exported frame 552 at 1:33:05
# Exported frame 553 at 1:33:15
# Exported frame 554 at 1:33:25
# Exported frame 555 at 1:33:35
# Exported frame 556 at 1:33:45
# Exported frame 557 at 1:33:55
# Exported frame 558 at 1:34:05
# Exported frame 559 at 1:34:15
# Exported frame 560 at 1:34:25
# Exported frame 561 at 1:34:35
# Exported frame 562 at 1:34:45
# Exported frame 563 at 1:34:55
# Exported frame 564 at 1:35:05
# Exported frame 565 at 1:35:15
# Video video_2.mp4 has been processed!
# Time taken : 72.80538773536682 seconds
# ----------------------------------------------------
# All frames extracted from the videos in the directory "videos_db" can be found in the directory "vid_frames"

# %%
#NOTE: ONLY TO BE USED TO PROCESS THE VIDEOS DONE BY MARK LAWRENCE
seconds_between_skips = 10

for video_name in videos_sorted:
    if video_name.endswith('mp4'):
        video_data_path = os.path.join(full_vid_data_path, f'{os.path.splitext(video_name)[0]}.json')
        if not os.path.exists(video_data_path):
            create_json_file(video_data_path)
        else:
            reset_frames_list(video_data_path)
        video_path = f'{videos_dir}/{video_name}'
        #_, video_name = video_path.split('/')
        cap = cv2.VideoCapture(video_path)
        fps = cap.get(cv2.CAP_PROP_FPS)
        total_frames = cap.get(cv2.CAP_PROP_FRAME_COUNT)
        duration_in_seconds = total_frames // fps
        #print(duration_in_seconds)
        #print(fps)

        frame_interval = int(fps * seconds_between_skips)

        video_imgs_path = f'{imgs_dir}/{video_name[:-4]}'

        if not os.path.exists(video_imgs_path):
            os.makedirs(video_imgs_path)
        else:
            if len(os.listdir(video_imgs_path)) > 0:
                clear_folder(video_imgs_path)

        print("Processing "+str(video_name))
        start = time.time()

        start_timestamp_seconds = 75
        frame_count = 1

        # Set the position in milliseconds to the next timestamp
        cap.set(cv2.CAP_PROP_POS_MSEC, start_timestamp_seconds * 1000)
        new_ts_dt = datetime.timedelta(seconds=start_timestamp_seconds)
        while True:
            
            ret, frame = cap.read()
            if not ret:
                break
            else:
                # Save the frame as an image
                saved_frame_count = frame_count-1
                new_timestamp = (start_timestamp_seconds + (seconds_between_skips * frame_count))
                frame_filename = os.path.join(video_imgs_path, f"frame_{saved_frame_count:04d}.png")
                cv2.imwrite(frame_filename, frame)
                print(f"Exported frame {frame_count} at {new_ts_dt}")

                # Write frame number and timestamp to JSON file
                frame_dict = {'frame_num': f"frame_{saved_frame_count:04d}", 'frame_timestamp': str(new_ts_dt)}
                #print(frame_dict)
                update_json_content(video_data_path, frame_dict)

                # Update timestamp
                new_ts_dt = datetime.timedelta(seconds=new_timestamp)
                #print(f"Exported frame {frame_count} at {new_timestamp // (60*60):02d}:{new_timestamp // 60:02d}:{new_timestamp % 60:02d}")

                # Skip the desired number of frames
                cap.set(cv2.CAP_PROP_POS_MSEC, new_timestamp * 1000)
                frame_count += 1


        end = time.time()
        print("Video "+str(video_name)+" has been processed!")

        seconds = end - start
        print (f"Time taken : {seconds} seconds")
        print("----------------------------------------------------")

        cap.release()
    #break

cv2.destroyAllWindows()

print(f"All frames extracted from the videos in the directory \"{videos_dir}\" can be found in the directory \"{imgs_dir}\"")
# Out:
# {'video_date': '26-02-2025', 'frames_list': []}
# Folder cleared
# Processing video_1.mp4
# Exported frame 1 at 0:01:15
# Exported frame 2 at 0:01:25
# Exported frame 3 at 0:01:35
# Exported frame 4 at 0:01:45
# Exported frame 5 at 0:01:55
# Exported frame 6 at 0:02:05
# Exported frame 7 at 0:02:15
# Exported frame 8 at 0:02:25
# Exported frame 9 at 0:02:35
# Exported frame 10 at 0:02:45
# Exported frame 11 at 0:02:55
# Exported frame 12 at 0:03:05
# Exported frame 13 at 0:03:15
# Exported frame 14 at 0:03:25
# Exported frame 15 at 0:03:35
# Exported frame 16 at 0:03:45
# Exported frame 17 at 0:03:55
# Exported frame 18 at 0:04:05
# Exported frame 19 at 0:04:15
# Exported frame 20 at 0:04:25
# Exported frame 21 at 0:04:35
# Exported frame 22 at 0:04:45
# Exported frame 23 at 0:04:55
# Exported frame 24 at 0:05:05
# Exported frame 25 at 0:05:15
# Exported frame 26 at 0:05:25
# Exported frame 27 at 0:05:35
# Exported frame 28 at 0:05:45
# Exported frame 29 at 0:05:55
# Exported frame 30 at 0:06:05
# Exported frame 31 at 0:06:15
# Exported frame 32 at 0:06:25
# Exported frame 33 at 0:06:35
# Exported frame 34 at 0:06:45
# Exported frame 35 at 0:06:55
# Exported frame 36 at 0:07:05
# Exported frame 37 at 0:07:15
# Exported frame 38 at 0:07:25
# Exported frame 39 at 0:07:35
# Exported frame 40 at 0:07:45
# Exported frame 41 at 0:07:55
# Exported frame 42 at 0:08:05
# Exported frame 43 at 0:08:15
# Exported frame 44 at 0:08:25
# Exported frame 45 at 0:08:35
# Exported frame 46 at 0:08:45
# Exported frame 47 at 0:08:55
# Exported frame 48 at 0:09:05
# Exported frame 49 at 0:09:15
# Exported frame 50 at 0:09:25
# Exported frame 51 at 0:09:35
# Exported frame 52 at 0:09:45
# Exported frame 53 at 0:09:55
# Exported frame 54 at 0:10:05
# Exported frame 55 at 0:10:15
# Exported frame 56 at 0:10:25
# Exported frame 57 at 0:10:35
# Exported frame 58 at 0:10:45
# Exported frame 59 at 0:10:55
# Exported frame 60 at 0:11:05
# Exported frame 61 at 0:11:15
# Exported frame 62 at 0:11:25
# Exported frame 63 at 0:11:35
# Exported frame 64 at 0:11:45
# Exported frame 65 at 0:11:55
# Exported frame 66 at 0:12:05
# Exported frame 67 at 0:12:15
# Exported frame 68 at 0:12:25
# Exported frame 69 at 0:12:35
# Exported frame 70 at 0:12:45
# Exported frame 71 at 0:12:55
# Exported frame 72 at 0:13:05
# Exported frame 73 at 0:13:15
# Exported frame 74 at 0:13:25
# Exported frame 75 at 0:13:35
# Exported frame 76 at 0:13:45
# Exported frame 77 at 0:13:55
# Exported frame 78 at 0:14:05
# Exported frame 79 at 0:14:15
# Exported frame 80 at 0:14:25
# Exported frame 81 at 0:14:35
# Exported frame 82 at 0:14:45
# Exported frame 83 at 0:14:55
# Exported frame 84 at 0:15:05
# Exported frame 85 at 0:15:15
# Exported frame 86 at 0:15:25
# Exported frame 87 at 0:15:35
# Exported frame 88 at 0:15:45
# Exported frame 89 at 0:15:55
# Exported frame 90 at 0:16:05
# Exported frame 91 at 0:16:15
# Exported frame 92 at 0:16:25
# Exported frame 93 at 0:16:35
# Exported frame 94 at 0:16:45
# Exported frame 95 at 0:16:55
# Exported frame 96 at 0:17:05
# Exported frame 97 at 0:17:15
# Exported frame 98 at 0:17:25
# Exported frame 99 at 0:17:35
# Exported frame 100 at 0:17:45
# Exported frame 101 at 0:17:55
# Exported frame 102 at 0:18:05
# Exported frame 103 at 0:18:15
# Exported frame 104 at 0:18:25
# Exported frame 105 at 0:18:35
# Exported frame 106 at 0:18:45
# Exported frame 107 at 0:18:55
# Exported frame 108 at 0:19:05
# Exported frame 109 at 0:19:15
# Exported frame 110 at 0:19:25
# Exported frame 111 at 0:19:35
# Exported frame 112 at 0:19:45
# Exported frame 113 at 0:19:55
# Exported frame 114 at 0:20:05
# Exported frame 115 at 0:20:15
# Exported frame 116 at 0:20:25
# Exported frame 117 at 0:20:35
# Exported frame 118 at 0:20:45
# Exported frame 119 at 0:20:55
# Exported frame 120 at 0:21:05
# Exported frame 121 at 0:21:15
# Exported frame 122 at 0:21:25
# Exported frame 123 at 0:21:35
# Exported frame 124 at 0:21:45
# Exported frame 125 at 0:21:55
# Exported frame 126 at 0:22:05
# Exported frame 127 at 0:22:15
# Exported frame 128 at 0:22:25
# Exported frame 129 at 0:22:35
# Exported frame 130 at 0:22:45
# Exported frame 131 at 0:22:55
# Exported frame 132 at 0:23:05
# Exported frame 133 at 0:23:15
# Exported frame 134 at 0:23:25
# Exported frame 135 at 0:23:35
# Exported frame 136 at 0:23:45
# Exported frame 137 at 0:23:55
# Exported frame 138 at 0:24:05
# Exported frame 139 at 0:24:15
# Exported frame 140 at 0:24:25
# Exported frame 141 at 0:24:35
# Exported frame 142 at 0:24:45
# Exported frame 143 at 0:24:55
# Exported frame 144 at 0:25:05
# Exported frame 145 at 0:25:15
# Exported frame 146 at 0:25:25
# Exported frame 147 at 0:25:35
# Exported frame 148 at 0:25:45
# Exported frame 149 at 0:25:55
# Exported frame 150 at 0:26:05
# Exported frame 151 at 0:26:15
# Exported frame 152 at 0:26:25
# Exported frame 153 at 0:26:35
# Exported frame 154 at 0:26:45
# Exported frame 155 at 0:26:55
# Exported frame 156 at 0:27:05
# Exported frame 157 at 0:27:15
# Exported frame 158 at 0:27:25
# Exported frame 159 at 0:27:35
# Exported frame 160 at 0:27:45
# Exported frame 161 at 0:27:55
# Exported frame 162 at 0:28:05
# Exported frame 163 at 0:28:15
# Exported frame 164 at 0:28:25
# Exported frame 165 at 0:28:35
# Exported frame 166 at 0:28:45
# Exported frame 167 at 0:28:55
# Exported frame 168 at 0:29:05
# Exported frame 169 at 0:29:15
# Exported frame 170 at 0:29:25
# Exported frame 171 at 0:29:35
# Exported frame 172 at 0:29:45
# Exported frame 173 at 0:29:55
# Exported frame 174 at 0:30:05
# Exported frame 175 at 0:30:15
# Exported frame 176 at 0:30:25
# Exported frame 177 at 0:30:35
# Exported frame 178 at 0:30:45
# Exported frame 179 at 0:30:55
# Exported frame 180 at 0:31:05
# Exported frame 181 at 0:31:15
# Exported frame 182 at 0:31:25
# Exported frame 183 at 0:31:35
# Exported frame 184 at 0:31:45
# Exported frame 185 at 0:31:55
# Exported frame 186 at 0:32:05
# Exported frame 187 at 0:32:15
# Exported frame 188 at 0:32:25
# Exported frame 189 at 0:32:35
# Exported frame 190 at 0:32:45
# Exported frame 191 at 0:32:55
# Exported frame 192 at 0:33:05
# Exported frame 193 at 0:33:15
# Exported frame 194 at 0:33:25
# Exported frame 195 at 0:33:35
# Exported frame 196 at 0:33:45
# Exported frame 197 at 0:33:55
# Exported frame 198 at 0:34:05
# Exported frame 199 at 0:34:15
# Exported frame 200 at 0:34:25
# Exported frame 201 at 0:34:35
# Exported frame 202 at 0:34:45
# Exported frame 203 at 0:34:55
# Exported frame 204 at 0:35:05
# Exported frame 205 at 0:35:15
# Exported frame 206 at 0:35:25
# Exported frame 207 at 0:35:35
# Exported frame 208 at 0:35:45
# Exported frame 209 at 0:35:55
# Exported frame 210 at 0:36:05
# Exported frame 211 at 0:36:15
# Exported frame 212 at 0:36:25
# Exported frame 213 at 0:36:35
# Exported frame 214 at 0:36:45
# Exported frame 215 at 0:36:55
# Exported frame 216 at 0:37:05
# Exported frame 217 at 0:37:15
# Exported frame 218 at 0:37:25
# Exported frame 219 at 0:37:35
# Exported frame 220 at 0:37:45
# Exported frame 221 at 0:37:55
# Exported frame 222 at 0:38:05
# Exported frame 223 at 0:38:15
# Exported frame 224 at 0:38:25
# Exported frame 225 at 0:38:35
# Exported frame 226 at 0:38:45
# Exported frame 227 at 0:38:55
# Exported frame 228 at 0:39:05
# Exported frame 229 at 0:39:15
# Exported frame 230 at 0:39:25
# Exported frame 231 at 0:39:35
# Exported frame 232 at 0:39:45
# Exported frame 233 at 0:39:55
# Exported frame 234 at 0:40:05
# Exported frame 235 at 0:40:15
# Exported frame 236 at 0:40:25
# Exported frame 237 at 0:40:35
# Exported frame 238 at 0:40:45
# Exported frame 239 at 0:40:55
# Exported frame 240 at 0:41:05
# Exported frame 241 at 0:41:15
# Exported frame 242 at 0:41:25
# Exported frame 243 at 0:41:35
# Exported frame 244 at 0:41:45
# Exported frame 245 at 0:41:55
# Exported frame 246 at 0:42:05
# Exported frame 247 at 0:42:15
# Exported frame 248 at 0:42:25
# Exported frame 249 at 0:42:35
# Exported frame 250 at 0:42:45
# Exported frame 251 at 0:42:55
# Exported frame 252 at 0:43:05
# Exported frame 253 at 0:43:15
# Exported frame 254 at 0:43:25
# Exported frame 255 at 0:43:35
# Exported frame 256 at 0:43:45
# Exported frame 257 at 0:43:55
# Exported frame 258 at 0:44:05
# Exported frame 259 at 0:44:15
# Exported frame 260 at 0:44:25
# Exported frame 261 at 0:44:35
# Exported frame 262 at 0:44:45
# Exported frame 263 at 0:44:55
# Exported frame 264 at 0:45:05
# Exported frame 265 at 0:45:15
# Exported frame 266 at 0:45:25
# Exported frame 267 at 0:45:35
# Exported frame 268 at 0:45:45
# Exported frame 269 at 0:45:55
# Exported frame 270 at 0:46:05
# Exported frame 271 at 0:46:15
# Exported frame 272 at 0:46:25
# Exported frame 273 at 0:46:35
# Exported frame 274 at 0:46:45
# Exported frame 275 at 0:46:55
# Exported frame 276 at 0:47:05
# Exported frame 277 at 0:47:15
# Exported frame 278 at 0:47:25
# Exported frame 279 at 0:47:35
# Exported frame 280 at 0:47:45
# Exported frame 281 at 0:47:55
# Exported frame 282 at 0:48:05
# Exported frame 283 at 0:48:15
# Exported frame 284 at 0:48:25
# Exported frame 285 at 0:48:35
# Exported frame 286 at 0:48:45
# Exported frame 287 at 0:48:55
# Exported frame 288 at 0:49:05
# Exported frame 289 at 0:49:15
# Exported frame 290 at 0:49:25
# Exported frame 291 at 0:49:35
# Exported frame 292 at 0:49:45
# Exported frame 293 at 0:49:55
# Exported frame 294 at 0:50:05
# Exported frame 295 at 0:50:15
# Exported frame 296 at 0:50:25
# Exported frame 297 at 0:50:35
# Exported frame 298 at 0:50:45
# Exported frame 299 at 0:50:55
# Exported frame 300 at 0:51:05
# Exported frame 301 at 0:51:15
# Exported frame 302 at 0:51:25
# Exported frame 303 at 0:51:35
# Exported frame 304 at 0:51:45
# Exported frame 305 at 0:51:55
# Exported frame 306 at 0:52:05
# Exported frame 307 at 0:52:15
# Exported frame 308 at 0:52:25
# Exported frame 309 at 0:52:35
# Exported frame 310 at 0:52:45
# Exported frame 311 at 0:52:55
# Exported frame 312 at 0:53:05
# Exported frame 313 at 0:53:15
# Exported frame 314 at 0:53:25
# Exported frame 315 at 0:53:35
# Exported frame 316 at 0:53:45
# Exported frame 317 at 0:53:55
# Exported frame 318 at 0:54:05
# Exported frame 319 at 0:54:15
# Exported frame 320 at 0:54:25
# Exported frame 321 at 0:54:35
# Exported frame 322 at 0:54:45
# Exported frame 323 at 0:54:55
# Exported frame 324 at 0:55:05
# Exported frame 325 at 0:55:15
# Exported frame 326 at 0:55:25
# Exported frame 327 at 0:55:35
# Exported frame 328 at 0:55:45
# Exported frame 329 at 0:55:55
# Exported frame 330 at 0:56:05
# Exported frame 331 at 0:56:15
# Exported frame 332 at 0:56:25
# Exported frame 333 at 0:56:35
# Exported frame 334 at 0:56:45
# Exported frame 335 at 0:56:55
# Exported frame 336 at 0:57:05
# Exported frame 337 at 0:57:15
# Exported frame 338 at 0:57:25
# Exported frame 339 at 0:57:35
# Exported frame 340 at 0:57:45
# Exported frame 341 at 0:57:55
# Exported frame 342 at 0:58:05
# Exported frame 343 at 0:58:15
# Exported frame 344 at 0:58:25
# Exported frame 345 at 0:58:35
# Exported frame 346 at 0:58:45
# Exported frame 347 at 0:58:55
# Exported frame 348 at 0:59:05
# Exported frame 349 at 0:59:15
# Exported frame 350 at 0:59:25
# Exported frame 351 at 0:59:35
# Exported frame 352 at 0:59:45
# Exported frame 353 at 0:59:55
# Exported frame 354 at 1:00:05
# Exported frame 355 at 1:00:15
# Exported frame 356 at 1:00:25
# Exported frame 357 at 1:00:35
# Exported frame 358 at 1:00:45
# Exported frame 359 at 1:00:55
# Exported frame 360 at 1:01:05
# Exported frame 361 at 1:01:15
# Exported frame 362 at 1:01:25
# Exported frame 363 at 1:01:35
# Exported frame 364 at 1:01:45
# Exported frame 365 at 1:01:55
# Exported frame 366 at 1:02:05
# Exported frame 367 at 1:02:15
# Exported frame 368 at 1:02:25
# Exported frame 369 at 1:02:35
# Exported frame 370 at 1:02:45
# Exported frame 371 at 1:02:55
# Exported frame 372 at 1:03:05
# Exported frame 373 at 1:03:15
# Exported frame 374 at 1:03:25
# Exported frame 375 at 1:03:35
# Exported frame 376 at 1:03:45
# Exported frame 377 at 1:03:55
# Exported frame 378 at 1:04:05
# Exported frame 379 at 1:04:15
# Exported frame 380 at 1:04:25
# Exported frame 381 at 1:04:35
# Exported frame 382 at 1:04:45
# Exported frame 383 at 1:04:55
# Exported frame 384 at 1:05:05
# Exported frame 385 at 1:05:15
# Exported frame 386 at 1:05:25
# Exported frame 387 at 1:05:35
# Exported frame 388 at 1:05:45
# Exported frame 389 at 1:05:55
# Exported frame 390 at 1:06:05
# Exported frame 391 at 1:06:15
# Exported frame 392 at 1:06:25
# Exported frame 393 at 1:06:35
# Exported frame 394 at 1:06:45
# Exported frame 395 at 1:06:55
# Exported frame 396 at 1:07:05
# Exported frame 397 at 1:07:15
# Exported frame 398 at 1:07:25
# Exported frame 399 at 1:07:35
# Exported frame 400 at 1:07:45
# Exported frame 401 at 1:07:55
# Exported frame 402 at 1:08:05
# Exported frame 403 at 1:08:15
# Exported frame 404 at 1:08:25
# Exported frame 405 at 1:08:35
# Exported frame 406 at 1:08:45
# Exported frame 407 at 1:08:55
# Exported frame 408 at 1:09:05
# Exported frame 409 at 1:09:15
# Exported frame 410 at 1:09:25
# Exported frame 411 at 1:09:35
# Exported frame 412 at 1:09:45
# Exported frame 413 at 1:09:55
# Exported frame 414 at 1:10:05
# Exported frame 415 at 1:10:15
# Exported frame 416 at 1:10:25
# Exported frame 417 at 1:10:35
# Exported frame 418 at 1:10:45
# Exported frame 419 at 1:10:55
# Exported frame 420 at 1:11:05
# Exported frame 421 at 1:11:15
# Exported frame 422 at 1:11:25
# Exported frame 423 at 1:11:35
# Exported frame 424 at 1:11:45
# Exported frame 425 at 1:11:55
# Exported frame 426 at 1:12:05
# Exported frame 427 at 1:12:15
# Exported frame 428 at 1:12:25
# Exported frame 429 at 1:12:35
# Exported frame 430 at 1:12:45
# Exported frame 431 at 1:12:55
# Exported frame 432 at 1:13:05
# Exported frame 433 at 1:13:15
# Exported frame 434 at 1:13:25
# Exported frame 435 at 1:13:35
# Exported frame 436 at 1:13:45
# Exported frame 437 at 1:13:55
# Exported frame 438 at 1:14:05
# Exported frame 439 at 1:14:15
# Exported frame 440 at 1:14:25
# Exported frame 441 at 1:14:35
# Exported frame 442 at 1:14:45
# Exported frame 443 at 1:14:55
# Exported frame 444 at 1:15:05
# Exported frame 445 at 1:15:15
# Exported frame 446 at 1:15:25
# Exported frame 447 at 1:15:35
# Exported frame 448 at 1:15:45
# Exported frame 449 at 1:15:55
# Exported frame 450 at 1:16:05
# Exported frame 451 at 1:16:15
# Exported frame 452 at 1:16:25
# Exported frame 453 at 1:16:35
# Exported frame 454 at 1:16:45
# Exported frame 455 at 1:16:55
# Video video_1.mp4 has been processed!
# Time taken : 20.01977014541626 seconds
# ----------------------------------------------------
# {'video_date': '12-03-2025', 'frames_list': []}
# Folder cleared
# Processing video_2.mp4
# Exported frame 1 at 0:01:15
# Exported frame 2 at 0:01:25
# Exported frame 3 at 0:01:35
# Exported frame 4 at 0:01:45
# Exported frame 5 at 0:01:55
# Exported frame 6 at 0:02:05
# Exported frame 7 at 0:02:15
# Exported frame 8 at 0:02:25
# Exported frame 9 at 0:02:35
# Exported frame 10 at 0:02:45
# Exported frame 11 at 0:02:55
# Exported frame 12 at 0:03:05
# Exported frame 13 at 0:03:15
# Exported frame 14 at 0:03:25
# Exported frame 15 at 0:03:35
# Exported frame 16 at 0:03:45
# Exported frame 17 at 0:03:55
# Exported frame 18 at 0:04:05
# Exported frame 19 at 0:04:15
# Exported frame 20 at 0:04:25
# Exported frame 21 at 0:04:35
# Exported frame 22 at 0:04:45
# Exported frame 23 at 0:04:55
# Exported frame 24 at 0:05:05
# Exported frame 25 at 0:05:15
# Exported frame 26 at 0:05:25
# Exported frame 27 at 0:05:35
# Exported frame 28 at 0:05:45
# Exported frame 29 at 0:05:55
# Exported frame 30 at 0:06:05
# Exported frame 31 at 0:06:15
# Exported frame 32 at 0:06:25
# Exported frame 33 at 0:06:35
# Exported frame 34 at 0:06:45
# Exported frame 35 at 0:06:55
# Exported frame 36 at 0:07:05
# Exported frame 37 at 0:07:15
# Exported frame 38 at 0:07:25
# Exported frame 39 at 0:07:35
# Exported frame 40 at 0:07:45
# Exported frame 41 at 0:07:55
# Exported frame 42 at 0:08:05
# Exported frame 43 at 0:08:15
# Exported frame 44 at 0:08:25
# Exported frame 45 at 0:08:35
# Exported frame 46 at 0:08:45
# Exported frame 47 at 0:08:55
# Exported frame 48 at 0:09:05
# Exported frame 49 at 0:09:15
# Exported frame 50 at 0:09:25
# Exported frame 51 at 0:09:35
# Exported frame 52 at 0:09:45
# Exported frame 53 at 0:09:55
# Exported frame 54 at 0:10:05
# Exported frame 55 at 0:10:15
# Exported frame 56 at 0:10:25
# Exported frame 57 at 0:10:35
# Exported frame 58 at 0:10:45
# Exported frame 59 at 0:10:55
# Exported frame 60 at 0:11:05
# Exported frame 61 at 0:11:15
# Exported frame 62 at 0:11:25
# Exported frame 63 at 0:11:35
# Exported frame 64 at 0:11:45
# Exported frame 65 at 0:11:55
# Exported frame 66 at 0:12:05
# Exported frame 67 at 0:12:15
# Exported frame 68 at 0:12:25
# Exported frame 69 at 0:12:35
# Exported frame 70 at 0:12:45
# Exported frame 71 at 0:12:55
# Exported frame 72 at 0:13:05
# Exported frame 73 at 0:13:15
# Exported frame 74 at 0:13:25
# Exported frame 75 at 0:13:35
# Exported frame 76 at 0:13:45
# Exported frame 77 at 0:13:55
# Exported frame 78 at 0:14:05
# Exported frame 79 at 0:14:15
# Exported frame 80 at 0:14:25
# Exported frame 81 at 0:14:35
# Exported frame 82 at 0:14:45
# Exported frame 83 at 0:14:55
# Exported frame 84 at 0:15:05
# Exported frame 85 at 0:15:15
# Exported frame 86 at 0:15:25
# Exported frame 87 at 0:15:35
# Exported frame 88 at 0:15:45
# Exported frame 89 at 0:15:55
# Exported frame 90 at 0:16:05
# Exported frame 91 at 0:16:15
# Exported frame 92 at 0:16:25
# Exported frame 93 at 0:16:35
# Exported frame 94 at 0:16:45
# Exported frame 95 at 0:16:55
# Exported frame 96 at 0:17:05
# Exported frame 97 at 0:17:15
# Exported frame 98 at 0:17:25
# Exported frame 99 at 0:17:35
# Exported frame 100 at 0:17:45
# Exported frame 101 at 0:17:55
# Exported frame 102 at 0:18:05
# Exported frame 103 at 0:18:15
# Exported frame 104 at 0:18:25
# Exported frame 105 at 0:18:35
# Exported frame 106 at 0:18:45
# Exported frame 107 at 0:18:55
# Exported frame 108 at 0:19:05
# Exported frame 109 at 0:19:15
# Exported frame 110 at 0:19:25
# Exported frame 111 at 0:19:35
# Exported frame 112 at 0:19:45
# Exported frame 113 at 0:19:55
# Exported frame 114 at 0:20:05
# Exported frame 115 at 0:20:15
# Exported frame 116 at 0:20:25
# Exported frame 117 at 0:20:35
# Exported frame 118 at 0:20:45
# Exported frame 119 at 0:20:55
# Exported frame 120 at 0:21:05
# Exported frame 121 at 0:21:15
# Exported frame 122 at 0:21:25
# Exported frame 123 at 0:21:35
# Exported frame 124 at 0:21:45
# Exported frame 125 at 0:21:55
# Exported frame 126 at 0:22:05
# Exported frame 127 at 0:22:15
# Exported frame 128 at 0:22:25
# Exported frame 129 at 0:22:35
# Exported frame 130 at 0:22:45
# Exported frame 131 at 0:22:55
# Exported frame 132 at 0:23:05
# Exported frame 133 at 0:23:15
# Exported frame 134 at 0:23:25
# Exported frame 135 at 0:23:35
# Exported frame 136 at 0:23:45
# Exported frame 137 at 0:23:55
# Exported frame 138 at 0:24:05
# Exported frame 139 at 0:24:15
# Exported frame 140 at 0:24:25
# Exported frame 141 at 0:24:35
# Exported frame 142 at 0:24:45
# Exported frame 143 at 0:24:55
# Exported frame 144 at 0:25:05
# Exported frame 145 at 0:25:15
# Exported frame 146 at 0:25:25
# Exported frame 147 at 0:25:35
# Exported frame 148 at 0:25:45
# Exported frame 149 at 0:25:55
# Exported frame 150 at 0:26:05
# Exported frame 151 at 0:26:15
# Exported frame 152 at 0:26:25
# Exported frame 153 at 0:26:35
# Exported frame 154 at 0:26:45
# Exported frame 155 at 0:26:55
# Exported frame 156 at 0:27:05
# Exported frame 157 at 0:27:15
# Exported frame 158 at 0:27:25
# Exported frame 159 at 0:27:35
# Exported frame 160 at 0:27:45
# Exported frame 161 at 0:27:55
# Exported frame 162 at 0:28:05
# Exported frame 163 at 0:28:15
# Exported frame 164 at 0:28:25
# Exported frame 165 at 0:28:35
# Exported frame 166 at 0:28:45
# Exported frame 167 at 0:28:55
# Exported frame 168 at 0:29:05
# Exported frame 169 at 0:29:15
# Exported frame 170 at 0:29:25
# Exported frame 171 at 0:29:35
# Exported frame 172 at 0:29:45
# Exported frame 173 at 0:29:55
# Exported frame 174 at 0:30:05
# Exported frame 175 at 0:30:15
# Exported frame 176 at 0:30:25
# Exported frame 177 at 0:30:35
# Exported frame 178 at 0:30:45
# Exported frame 179 at 0:30:55
# Exported frame 180 at 0:31:05
# Exported frame 181 at 0:31:15
# Exported frame 182 at 0:31:25
# Exported frame 183 at 0:31:35
# Exported frame 184 at 0:31:45
# Exported frame 185 at 0:31:55
# Exported frame 186 at 0:32:05
# Exported frame 187 at 0:32:15
# Exported frame 188 at 0:32:25
# Exported frame 189 at 0:32:35
# Exported frame 190 at 0:32:45
# Exported frame 191 at 0:32:55
# Exported frame 192 at 0:33:05
# Exported frame 193 at 0:33:15
# Exported frame 194 at 0:33:25
# Exported frame 195 at 0:33:35
# Exported frame 196 at 0:33:45
# Exported frame 197 at 0:33:55
# Exported frame 198 at 0:34:05
# Exported frame 199 at 0:34:15
# Exported frame 200 at 0:34:25
# Exported frame 201 at 0:34:35
# Exported frame 202 at 0:34:45
# Exported frame 203 at 0:34:55
# Exported frame 204 at 0:35:05
# Exported frame 205 at 0:35:15
# Exported frame 206 at 0:35:25
# Exported frame 207 at 0:35:35
# Exported frame 208 at 0:35:45
# Exported frame 209 at 0:35:55
# Exported frame 210 at 0:36:05
# Exported frame 211 at 0:36:15
# Exported frame 212 at 0:36:25
# Exported frame 213 at 0:36:35
# Exported frame 214 at 0:36:45
# Exported frame 215 at 0:36:55
# Exported frame 216 at 0:37:05
# Exported frame 217 at 0:37:15
# Exported frame 218 at 0:37:25
# Exported frame 219 at 0:37:35
# Exported frame 220 at 0:37:45
# Exported frame 221 at 0:37:55
# Exported frame 222 at 0:38:05
# Exported frame 223 at 0:38:15
# Exported frame 224 at 0:38:25
# Exported frame 225 at 0:38:35
# Exported frame 226 at 0:38:45
# Exported frame 227 at 0:38:55
# Exported frame 228 at 0:39:05
# Exported frame 229 at 0:39:15
# Exported frame 230 at 0:39:25
# Exported frame 231 at 0:39:35
# Exported frame 232 at 0:39:45
# Exported frame 233 at 0:39:55
# Exported frame 234 at 0:40:05
# Exported frame 235 at 0:40:15
# Exported frame 236 at 0:40:25
# Exported frame 237 at 0:40:35
# Exported frame 238 at 0:40:45
# Exported frame 239 at 0:40:55
# Exported frame 240 at 0:41:05
# Exported frame 241 at 0:41:15
# Exported frame 242 at 0:41:25
# Exported frame 243 at 0:41:35
# Exported frame 244 at 0:41:45
# Exported frame 245 at 0:41:55
# Exported frame 246 at 0:42:05
# Exported frame 247 at 0:42:15
# Exported frame 248 at 0:42:25
# Exported frame 249 at 0:42:35
# Exported frame 250 at 0:42:45
# Exported frame 251 at 0:42:55
# Exported frame 252 at 0:43:05
# Exported frame 253 at 0:43:15
# Exported frame 254 at 0:43:25
# Exported frame 255 at 0:43:35
# Exported frame 256 at 0:43:45
# Exported frame 257 at 0:43:55
# Exported frame 258 at 0:44:05
# Exported frame 259 at 0:44:15
# Exported frame 260 at 0:44:25
# Exported frame 261 at 0:44:35
# Exported frame 262 at 0:44:45
# Exported frame 263 at 0:44:55
# Exported frame 264 at 0:45:05
# Exported frame 265 at 0:45:15
# Exported frame 266 at 0:45:25
# Exported frame 267 at 0:45:35
# Exported frame 268 at 0:45:45
# Exported frame 269 at 0:45:55
# Exported frame 270 at 0:46:05
# Exported frame 271 at 0:46:15
# Exported frame 272 at 0:46:25
# Exported frame 273 at 0:46:35
# Exported frame 274 at 0:46:45
# Exported frame 275 at 0:46:55
# Exported frame 276 at 0:47:05
# Exported frame 277 at 0:47:15
# Exported frame 278 at 0:47:25
# Exported frame 279 at 0:47:35
# Exported frame 280 at 0:47:45
# Exported frame 281 at 0:47:55
# Exported frame 282 at 0:48:05
# Exported frame 283 at 0:48:15
# Exported frame 284 at 0:48:25
# Exported frame 285 at 0:48:35
# Exported frame 286 at 0:48:45
# Exported frame 287 at 0:48:55
# Exported frame 288 at 0:49:05
# Exported frame 289 at 0:49:15
# Exported frame 290 at 0:49:25
# Exported frame 291 at 0:49:35
# Exported frame 292 at 0:49:45
# Exported frame 293 at 0:49:55
# Exported frame 294 at 0:50:05
# Exported frame 295 at 0:50:15
# Exported frame 296 at 0:50:25
# Exported frame 297 at 0:50:35
# Exported frame 298 at 0:50:45
# Exported frame 299 at 0:50:55
# Exported frame 300 at 0:51:05
# Exported frame 301 at 0:51:15
# Exported frame 302 at 0:51:25
# Exported frame 303 at 0:51:35
# Exported frame 304 at 0:51:45
# Exported frame 305 at 0:51:55
# Exported frame 306 at 0:52:05
# Exported frame 307 at 0:52:15
# Exported frame 308 at 0:52:25
# Exported frame 309 at 0:52:35
# Exported frame 310 at 0:52:45
# Exported frame 311 at 0:52:55
# Exported frame 312 at 0:53:05
# Exported frame 313 at 0:53:15
# Exported frame 314 at 0:53:25
# Exported frame 315 at 0:53:35
# Exported frame 316 at 0:53:45
# Exported frame 317 at 0:53:55
# Exported frame 318 at 0:54:05
# Video video_2.mp4 has been processed!
# Time taken : 15.48855209350586 seconds
# ----------------------------------------------------
# All frames extracted from the videos in the directory "videos_db_ml" can be found in the directory "vid_frames_ml"

# %% [markdown]
# # Facial ROI Extraction

# %% [markdown]
# ## JSON functionality

# %% [markdown]
# <b>NOTE: Data folder must contain video data before running below two functions</b>

# %%
# Function to add number of extracted facial ROIs to video data file
def add_num_rois_to_json(file_path, base_img_name, num_rois):
    with open(file_path, 'r+') as f:
        processed_data = json.load(f)
        if 'frames_list' not in processed_data.keys():
            processed_data['frames_list'] = []
        
        for index, frame in enumerate(processed_data['frames_list']):
            if frame['frame_num'] == base_img_name:
                frame_dict = frame.copy()
                pos = index
                break
        
        frame_dict['num_of_rois'] = num_rois

        processed_data['frames_list'][pos] = frame_dict
        f.seek(0)
        json.dump(processed_data, f, indent=4)
        f.truncate()  # This prevents leftover characters from previous write

# Function to add extracted facial ROI names to video data file
def add_roi_names_to_json(file_path, base_img_name, rois_list):
    with open(file_path, 'r+') as f:
        processed_data = json.load(f)
        if 'frames_list' not in processed_data.keys():
            processed_data['frames_list'] = []
        
        for index, frame in enumerate(processed_data['frames_list']):
            if frame['frame_num'] == base_img_name:
                frame_dict = frame.copy()
                pos = index
                break
        
        if len(rois_list) > 0:
            frame_dict['rois_list'] = [{'roi_num': roi_name} for roi_name in rois_list]
        else:
            frame_dict['rois_list'] = []

        processed_data['frames_list'][pos] = frame_dict
        f.seek(0)
        json.dump(processed_data, f, indent=4)
        f.truncate()  # This prevents leftover characters from previous write

def add_encodings_to_json(file_path, base_img_name, encodings_list):
    with open(file_path, 'r+') as f:
        processed_data = json.load(f)
        if 'frames_list' not in processed_data:
            processed_data['frames_list'] = []

        frame_dict = None
        for index, frame in enumerate(processed_data['frames_list']):
            if frame['frame_num'] == base_img_name:
                frame_dict = frame
                pos = index
                break

        if frame_dict is None:
            raise Exception(f"Frame {base_img_name} not found in {file_path}")

        # Match encodings to ROI entries
        rois_list = frame_dict.get('rois_list', [])
        for i, roi in enumerate(rois_list):
            if i < len(encodings_list):
                facial_encoding = encodings_list[i].get('facial_area', {})
                roi['facial_encoding'] = {k: v for k, v in facial_encoding.items() if not (k == 'left_eye' or k == 'right_eye')}
            #else:
                #roi['facial_encoding'] = []  # or None if you prefer
        
        processed_data['frames_list'][pos] = frame_dict
        f.seek(0)
        json.dump(processed_data, f, indent=4)
        f.truncate()

def check_for_intermission_frame(file_path, base_img_name, intermission_path):
    intermission_found = False
    with open(file_path, 'r+') as f:
        processed_data = json.load(f)
        if 'frames_list' not in processed_data.keys():
            processed_data['frames_list'] = []
        
        for index, frame in enumerate(processed_data['frames_list']):
            if frame['frame_num'] == base_img_name:
                frame_dict = frame.copy()
                pos = index
                break
    
    with open(intermission_path, 'r+') as f:
        intermission_data = json.load(f)
    
    print(processed_data['frames_list'][pos]['frame_timestamp'])
    timestamp_h, timestamp_m, timestamp_s = map(int, processed_data['frames_list'][pos]['frame_timestamp'].split(':'))
    timestamp_delta = datetime.timedelta(hours=timestamp_h, minutes=timestamp_m, seconds=timestamp_s)
    
    for intermission in intermission_data['commercial_times']:
        start = intermission['start_time']
        start_h, start_m, start_s = map(int, start.split(':'))
        start_delta = datetime.timedelta(hours=start_h, minutes=start_m, seconds=start_s)
        end = intermission['end_time']
        end_h, end_m, end_s = map(int, end.split(':'))
        end_delta = datetime.timedelta(hours=end_h, minutes=end_m, seconds=end_s)
        if timestamp_delta > start_delta and timestamp_delta <= end_delta:
            intermission_found = True
            break
            #return "Cannot perform facial ROI extraction"
    
    return intermission_found
        #print("Cannot perform facial ROI extraction" if timestamp_delta > start_delta and timestamp_delta <= end_delta else "Can perform facial ROI extraction")

# %% [markdown]
# ## Parameter declaration and initialisation

# %%
padding = 25

frames_dir = 'vid_frames'
frames_subDirs = []
rois_dir = 'face_rois_test_dt_2'
data_folder = 'data'
video_data_path = os.path.join(data_folder, 'video_data')
intermission_data_path = os.path.join('data', 'intermission_data')

# This is essential to avoid any unnecessary extraction of facial ROIs from ads at the bottom of the video
y_crop = 81

# %%
vid_frames_folders = [folder for folder in os.listdir(".") if os.path.isdir(os.path.join(".", folder)) and folder.startswith("vid_frames")]

for index, frames_dir in enumerate(vid_frames_folders):
    print(f'{index+1}: {frames_dir}')
# Out:
# 1: test_vid_frames
# 2: test_vid_frames_ml

# %%
valid_choice = False
while not valid_choice:
    index_choice = input('Enter index of video frames directory: ')

    if index_choice.isnumeric():
        if int(index_choice) > len(vid_frames_folders) or int(index_choice) <= 0:
            valid_choice = False
            print('Invalid choice!')
        else:
            valid_choice = True
            frames_dir = vid_frames_folders[int(index_choice)-1]
            rois_dir = f'face_rois_dt_{"_".join(frames_dir.split("_")[-1:])}' if frames_dir != "vid_frames" else "face_rois_dt"
            video_data_path = os.path.join(data_folder, f'video_data_{"_".join(frames_dir.split("_")[-1:])}') if frames_dir != "vid_frames" else os.path.join(data_folder, 'video_data')
            print("Video Frames Folder selected:", frames_dir)
            print(rois_dir)
            print(video_data_path)

    else:
        valid_choice = False
        print("Index entered is not numeric!")
# Out:
# Video Frames Folder selected: test_vid_frames_ml
# test_face_rois_dt_ml
# test_data\video_data_ml

# %%
if not os.path.exists(rois_dir):
    os.mkdir(rois_dir)

# %% [markdown]
# ## Facial ROI execution

# %% [markdown]
# ### Asking user for directory of video to process

# %%
frames_subDirs = []

print('List of available of videos with extracted frames:')
for root, dirs, files in os.walk(frames_dir, topdown=True):
    for subDir in dirs:
        frames_subDirs.append(subDir)

frames_subDirs_sorted = sorted(frames_subDirs, key=lambda x: int(x.split('_')[-1]))

for index, subDir in enumerate(frames_subDirs_sorted):
    print(f'{index+1}: {os.path.join(frames_dir, subDir)}')
# Out:
# List of available of videos with extracted frames:
# 1: test_vid_frames_ml\video_1
# 2: test_vid_frames_ml\video_2

# %%
valid_choice = False
dir_chosen = ""
dir_chosen_full_path = ""
while not valid_choice:
    index_choice = input('Enter index of directory that you want to retrieve face ROIs: ')

    if index_choice.isnumeric():
        if int(index_choice) > len(frames_subDirs_sorted) or int(index_choice) <= 0:
            valid_choice = False
            print('Invalid choice!')
        else:
            valid_choice = True
            dir_chosen = frames_subDirs_sorted[int(index_choice)-1]
            dir_chosen_full_path = os.path.join(frames_dir, dir_chosen)
            chosen_video_data_path = os.path.join(video_data_path, f'{dir_chosen}.json')
            chosen_video_intermission_path = os.path.join(intermission_data_path, f'{dir_chosen}.json') if "_ml" not in frames_dir else os.path.join(f'{intermission_data_path}_ml', f'{dir_chosen}.json')
            print("Directory selected:", dir_chosen_full_path)
            print("Video selected:", dir_chosen)
    else:
        valid_choice = False
        print("Index entered is not numeric!")
# Out:
# Directory selected: test_vid_frames_ml\video_1
# Video selected: video_1

# %%
rois_subDir = os.path.join(rois_dir, dir_chosen)

if not os.path.exists(rois_subDir):
    os.mkdir(rois_subDir)
else:
    if len(os.listdir(rois_subDir)) > 0:
        clear_folder(rois_subDir)

# %% [markdown]
# ## Validate if video data exists

# %%
# Check if data file for selected video exists in the data folder
video_data_file_exists = check_if_data_file_exists(dir_chosen)

if not video_data_file_exists:
    raise Exception(f'Data file for {dir_chosen} does not exist in {video_data_path}!')
    exit(0)

# Check if there is a list of extracted frames in the selected video data file
video_data_exists = validate_data_file(chosen_video_data_path)

print(chosen_video_data_path)
print(chosen_video_intermission_path)

if not video_data_exists:
    raise Exception(f'Please ensure that all frames from {dir_chosen} have been extracted before running this!')
    exit(0)

print("Chosen video data file is valid!")
# Out:
# test_data\video_data_ml\video_1.json
# data\intermission_data_ml\video_1.json
# Chosen video data file is valid!

# %% [markdown]
# ## Extract facial ROIs from video frames

# %%
min_w, min_h = 20, 30

# %%
total_num_rois_extracted = 0
if video_data_exists:
    # Loop through each file in the directory
    for snapshot_img in os.listdir(dir_chosen_full_path):
        roi_names = []
        valid_encodings = []

        # Only take into account image files (which end in .jpg or .png)
        if snapshot_img.endswith('.jpg') or snapshot_img.endswith('.png'):
            snapshot_path = os.path.join(dir_chosen_full_path, snapshot_img)
            snapshot_basename = os.path.splitext(os.path.basename(snapshot_img))[0]
            snapshot_ext = os.path.splitext(os.path.basename(snapshot_img))[1]
            #print(snapshot_basename)
            #print(snapshot_ext)

            is_intermission_frame = check_for_intermission_frame(chosen_video_data_path, snapshot_basename, chosen_video_intermission_path)

            if is_intermission_frame:
                print(f'Intermission frame detected at {snapshot_basename}! Cannot extract potential face/s!')
                add_num_rois_to_json(chosen_video_data_path, os.path.splitext(snapshot_img)[0], 0)
                add_roi_names_to_json(chosen_video_data_path, os.path.splitext(snapshot_img)[0], [])
                continue

            # Load and crop image to avoid extracting faces from any ads from the bottom of the screen
            snapshot = face_rec.load_image_file(snapshot_path)
            snapshot = cv2.cvtColor(snapshot, cv2.COLOR_BGR2RGB)
            snapshot_crop = snapshot[:snapshot.shape[0]-y_crop,:]

            # Extract facial encodings from the processed image
            # If no faces are found, then program moves on to next image
            try:
                snapshot_encodings = DeepFace.represent(snapshot_crop, detector_backend='retinaface')
            except:
                print(f'No face detected in {snapshot_basename}!')
                print("------------------------------------------------------------------------------")
                add_num_rois_to_json(chosen_video_data_path, os.path.splitext(snapshot_img)[0], 0)
                add_roi_names_to_json(chosen_video_data_path, os.path.splitext(snapshot_img)[0], [])
                continue
            
            num_rois = len(snapshot_encodings)

            # Do not perform ROI extraction on frames with more than 2 ROIs (e.g. in commercials)
            if num_rois > 2:
                add_num_rois_to_json(chosen_video_data_path, os.path.splitext(snapshot_img)[0], 0)
                add_roi_names_to_json(chosen_video_data_path, os.path.splitext(snapshot_img)[0], [])
                continue
            
            # Extract facial ROIs using information generated from the encodings
            for index, encoding in enumerate(snapshot_encodings):
                #print(snapshot_path.split('/')[-1], '-',encoding['facial_area'])
                roi_x = encoding['facial_area']['x']
                roi_y = encoding['facial_area']['y']
                roi_w = encoding['facial_area']['w']
                roi_h = encoding['facial_area']['h']
                roi_left, roi_right = roi_x - padding, roi_x + roi_w + padding
                roi_top, roi_bottom = roi_y - padding, roi_y + roi_h + padding

                # Ensure dimensions are greater than 0 to avoid any errors
                if roi_top < 0:
                    roi_top = 0
                
                if roi_left < 0:
                    roi_left = 0

                roi_img = snapshot[roi_top:roi_bottom, roi_left:roi_right]
                #print(roi_img.shape)

                img_w, img_h = roi_img.shape[1], roi_img.shape[0]

                # Do not save any facial ROIs that are too small (e.g. in commercials)
                if roi_w < min_w or roi_h < min_h:
                    num_rois -= 1
                    continue
                
                # Declare and initalise the ROI filename and the location of the file in which it is to be saved
                roi_filename = f'{snapshot_basename}_{index:02d}{snapshot_ext}'
                roi_full_path = os.path.join(rois_subDir, roi_filename)

                # Save extracted ROI
                cv2.imwrite(roi_full_path, roi_img)
                roi_names.append(os.path.splitext(roi_filename)[0])
                valid_encodings.append(encoding)
            
            # Inform user about progress
            print(f"Extracted {num_rois} facial ROIs from {snapshot_basename}: {roi_names}")
            print("------------------------------------------------------------------------------")

            total_num_rois_extracted += num_rois
            
            # Write information to video data file
            add_num_rois_to_json(chosen_video_data_path, os.path.splitext(snapshot_img)[0], num_rois)
            add_roi_names_to_json(chosen_video_data_path, os.path.splitext(snapshot_img)[0], roi_names)
            add_encodings_to_json(chosen_video_data_path, os.path.splitext(snapshot_img)[0], valid_encodings)

    # Inform user that facial ROI extraction process is complete
    print(f"A total of {total_num_rois_extracted} facial ROIs for {dir_chosen} have been saved in {rois_subDir}")
else:
    raise Exception(f'Please ensure that all frames from {dir_chosen} have been extracted before running this!')
# Out:
# 0:01:15
# Intermission frame detected at frame_0000! Cannot extract potential face/s!
# 0:01:25
# Extracted 1 facial ROIs from frame_0001: ['frame_0001_00']
# ------------------------------------------------------------------------------
# 0:01:35
# Extracted 1 facial ROIs from frame_0002: ['frame_0002_00']
# ------------------------------------------------------------------------------
# 0:01:45
# Extracted 2 facial ROIs from frame_0003: ['frame_0003_00', 'frame_0003_01']
# ------------------------------------------------------------------------------
# 0:01:55
# Extracted 2 facial ROIs from frame_0004: ['frame_0004_00', 'frame_0004_01']
# ------------------------------------------------------------------------------
# 0:02:05
# Extracted 1 facial ROIs from frame_0005: ['frame_0005_00']
# ------------------------------------------------------------------------------
# 0:02:15
# Extracted 1 facial ROIs from frame_0006: ['frame_0006_00']
# ------------------------------------------------------------------------------
# 0:02:25
# Extracted 1 facial ROIs from frame_0007: ['frame_0007_00']
# ------------------------------------------------------------------------------
# 0:02:35
# Extracted 1 facial ROIs from frame_0008: ['frame_0008_00']
# ------------------------------------------------------------------------------
# 0:02:45
# Extracted 2 facial ROIs from frame_0009: ['frame_0009_00', 'frame_0009_01']
# ------------------------------------------------------------------------------
# 0:02:55
# Extracted 1 facial ROIs from frame_0010: ['frame_0010_00']
# ------------------------------------------------------------------------------
# 0:03:05
# Extracted 1 facial ROIs from frame_0011: ['frame_0011_00']
# ------------------------------------------------------------------------------
# 0:03:15
# Extracted 1 facial ROIs from frame_0012: ['frame_0012_00']
# ------------------------------------------------------------------------------
# 0:03:25
# Extracted 1 facial ROIs from frame_0013: ['frame_0013_00']
# ------------------------------------------------------------------------------
# 0:03:35
# Extracted 1 facial ROIs from frame_0014: ['frame_0014_00']
# ------------------------------------------------------------------------------
# 0:03:45
# Extracted 1 facial ROIs from frame_0015: ['frame_0015_00']
# ------------------------------------------------------------------------------
# 0:03:55
# Extracted 1 facial ROIs from frame_0016: ['frame_0016_00']
# ------------------------------------------------------------------------------
# 0:04:05
# Extracted 1 facial ROIs from frame_0017: ['frame_0017_00']
# ------------------------------------------------------------------------------
# 0:04:15
# Extracted 1 facial ROIs from frame_0018: ['frame_0018_00']
# ------------------------------------------------------------------------------
# 0:04:25
# Extracted 1 facial ROIs from frame_0019: ['frame_0019_00']
# ------------------------------------------------------------------------------
# 0:04:35
# Extracted 1 facial ROIs from frame_0020: ['frame_0020_00']
# ------------------------------------------------------------------------------
# 0:04:45
# Extracted 1 facial ROIs from frame_0021: ['frame_0021_00']
# ------------------------------------------------------------------------------
# 0:04:55
# Extracted 1 facial ROIs from frame_0022: ['frame_0022_00']
# ------------------------------------------------------------------------------
# 0:05:05
# Extracted 1 facial ROIs from frame_0023: ['frame_0023_00']
# ------------------------------------------------------------------------------
# 0:05:15
# Extracted 1 facial ROIs from frame_0024: ['frame_0024_00']
# ------------------------------------------------------------------------------
# A total of 27 facial ROIs for video_1 have been saved in test_face_rois_dt_ml\video_1
